# %% [markdown]
# # COSC2671 Social Media and Network Analytics
#
# ## Workshop 4
#
# Jeffrey Chan, RMIT University, 2023

# %%
# import the ReddditProcess class python script that are based on the RedditProcessing class python script,
#  but also add additional funcitons
from RedditProcess import RedditProcess

# importing packages and nltk data libraries
import string
import json
import codecs
import re

import nltk
from nltk.tokenize import TweetTokenizer
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.sentiment.vader import SentimentIntensityAnalyzer
nltk.download('vader_lexicon')

from colorama import Fore, Back, Style
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/siriuslam/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %% [markdown]
# ### Vader based approach to sentiment analysis.

# %%
def vaderPrintTokens(lTokens, dSentimentScores):
    """
    Print out the tokens and sentiment score.
    
    @param lTokens: List of tokens to print and colour.
    @dSentimentScores: Dictionary of sentiment from Vader.

    """
    print(*lTokens, sep=', ')
    for cat,score in dSentimentScores.items():
        print('{0}: {1}, '.format(cat, score), end='')
    print()

# %%
def vaderSentimentAnalysis(sTweetsFilename, bPrint, redditProcessor):
    """
    Use Vader lexicons instead of a raw positive and negative word count.

    @param sTweetsFilename: name of input file containing a json formated tweet dump
    @param bPrint: whether to print the stream of tokens and sentiment.  Uses colorama to highlight sentiment words.
    @param redditProcessor: TweetProcessing object, used to pre-process each tweet.

    @returns: list of tweets, in the format of [date, sentiment]
    """

    # this is the vader sentiment analyser, part of nltk
    sentAnalyser = SentimentIntensityAnalyzer()


    vSentiment = []
    # open file and process tweets, one by one
    with open(sTweetsFilename, 'r',encoding='utf-8') as f:
        YouTubeVideoData = json.load(f)

        # process reddit submissions - title and content
        for video in YouTubeVideoData:
            postText = video['Title']
            postDate = video['Timestamp']
            
            # pre-process the post text
            lTokens = redditProcessor.process(postText)

            # this computes the sentiment scores (called polarity score in nltk, but mean same thing essentially)
            # see workshop sheet for what dSentimentScores holds
            dSentimentScores = sentAnalyser.polarity_scores(postText)

            # save the date and sentiment of each post (used for time series)
            vSentiment.append([pd.to_datetime(postDate, unit='s'), 
                               dSentimentScores['neg'], 
                               dSentimentScores['neu'], 
                               dSentimentScores['pos'], 
                               dSentimentScores['compound']])

            # if we are printing, we print the tokens then the sentiment scores.  Because we don't have the list
            # of positive and negative words, we cannot use colorama to label each token
            if bPrint:
                vaderPrintTokens(lTokens, dSentimentScores)

        for video in YouTubeVideoData:
            postText = video['Description'] # For submission's content
            postDate = video['Timestamp']
            lTokens = redditProcessor.process(postText)
            dSentimentScores = sentAnalyser.polarity_scores(postText)
            vSentiment.append([pd.to_datetime(postDate, unit='s'), 
                               dSentimentScores['neg'], 
                               dSentimentScores['neu'], 
                               dSentimentScores['pos'], 
                               dSentimentScores['compound']])
            if bPrint:
                vaderPrintTokens(lTokens, dSentimentScores) 
                
                
            # process the comments
            for comment in video['Comments']:
                postText = comment['text']
                postDate = comment['timestamp']
                lTokens = redditProcessor.process(postText)
                dSentimentScores = sentAnalyser.polarity_scores(postText)
                vSentiment.append([pd.to_datetime(postDate, unit='s'), 
                                   dSentimentScores['neg'], 
                                   dSentimentScores['neu'], 
                                   dSentimentScores['pos'], 
                                   dSentimentScores['compound']])
                if bPrint:
                    vaderPrintTokens(lTokens, dSentimentScores)

                # process the replies
                if 'replies' in comment:
                    for reply in comment['replies']:
                        postText = reply['text']
                        postDate = reply['timestamp']
                        lTokens = redditProcessor.process(postText)
                        dSentimentScores = sentAnalyser.polarity_scores(postText)
                        vSentiment.append([pd.to_datetime(postDate, unit='s'), 
                                           dSentimentScores['neg'], 
                                           dSentimentScores['neu'], 
                                           dSentimentScores['pos'], 
                                           dSentimentScores['compound']])
                        if bPrint:
                            vaderPrintTokens(lTokens, dSentimentScores) 
                    
                    
    return vSentiment

# %% [markdown]
# Arguments for this notebook
# Modify as needed if you want to do similar analaysis for other purposes

# %%
# input file of set of youtube videos (json format)
youtubeFile = 'youtube_maleficent.json'
# flag to determine whether to print out tweets and their sentiment
flagPrint = True

# %% [markdown]
# Then following calls the functions we have written above. First do the pre-processing, then calls the functions to do the sentiment analysis.

# %%
# Construct the reddit pro-processing object
# Use tweet tokenizer
tweetTokenizer = TweetTokenizer()

# Build punctuation list and stopwords list
lPunct = list(string.punctuation)
# # standard 'English' stopwords plus we want to remove things like 'rt' (retweet) etc
lStopwords = stopwords.words('english') + lPunct + ['rt', 'via', '...', '…', '"', "'", '`', '’','@']

# Create a stemmer instance
stemmer = PorterStemmer()

# Call the RedditProcess class python script
redditProcessor = RedditProcess(tweetTokenizer, lStopwords, stemmer)

# %% [markdown]
# ### Reference: Codes above are from COSC2671 Social Media and Network Analytics Workshop 4, created by Jeffrey Chan, RMIT University, 2023.

# %% [markdown]
# ## Compute Sentiment by Vader Model

# %%
vaderSentiment = []
vaderSentiment = vaderSentimentAnalysis(youtubeFile, flagPrint, redditProcessor)
# Out:
# disney', malefic, dream, trailer
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# maleficent', curs, scene, malefic
# neg: 0.538, neu: 0.462, pos: 0.0, compound: -0.5423,
# malefic, movi, review
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# malefic, play, theater, get, ticket, like, malefic, facebook, facebook.com/disneymalefic, follow, disney, twitter, @disneypictur, instagram, pinterest, tumblr, www.disney.tumblr.com, download, upon, dream, googl, play, #malefic, award-win, american, singer-songwrit, lana, del, rey, record, uniqu, reimagin, renown, fairy-tal, tune, disney', anim, film, sleep, beauti, featur, end, credit, upcom, disney, film
# neg: 0.0, neu: 0.808, pos: 0.192, compound: 0.9186,
# back, re-watch, awesom, trailer, rememb, disney, live, action, actual, good, start, :)
# neg: 0.0, neu: 0.582, pos: 0.418, compound: 0.8951,
# trailer, trick, think, get, someth, awesom
# neg: 0.102, neu: 0.637, pos: 0.261, compound: 0.5423,
# good, trailer, mediocr, movi
# neg: 0.0, neu: 0.508, pos: 0.492, compound: 0.4404,
# angelina, joli, ell, fan, fantast, tho
# neg: 0.0, neu: 0.66, pos: 0.34, compound: 0.5574,
# witch
# neg: 0.714, neu: 0.286, pos: 0.0, compound: -0.3612,
# truli, anti-heroin, film, walt, disney, movi
# neg: 0.0, neu: 0.734, pos: 0.266, compound: 0.4404,
# happi, anniversari, malefic, love, movi, much
# neg: 0.0, neu: 0.469, pos: 0.531, compound: 0.877,
# like, tri, make, hero
# neg: 0.0, neu: 0.596, pos: 0.404, compound: 0.7269,
# live, action, disney, movi, one, somehow, hold, realli, done, off-shoot, stori, like, instead, remak, classic, alreadi, perfect
# neg: 0.0, neu: 0.829, pos: 0.171, compound: 0.7351,
# anyon, happen, know, find, orchestra, use, background, trailer
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# maléfica, cruella, ❤
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# trailer, made, love, lana, young, age
# neg: 0.0, neu: 0.656, pos: 0.344, compound: 0.6369,
# ell, fan, parec, sailor, moon, protagonista, de, anim, tien, novio, tuxedo, mask, mi, amiga, sailor, mercuri, sailor, mar, sailor, júpiter, sailor, venu, helio, mi, prima, mini, moon, conoc, sailor, uranu, sailor, neptun, sailor, pluto, sailor, saturn
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# ell, fannig, parec, mini, moon, tien, sailor, moon, vive, casa, con, ella, tien, novio, helio, conoc, sailor, mercuri, sailor, mar, sailor, jupit, sailor, venu, tuxedo, mask, conoció, sailor, uranu, sailor, neptun, sailor, plutón, amiga, sailor, saturn
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# guiootgibgunn, ❤, fhjoggiin
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# lana, del, reyyy
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# 美しい女王の夜, 暗い邪悪な少女, 美しさのエミリー
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# one
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# 😊
# neg: 1.0, neu: 0.0, pos: 0.0, compound: -0.296,
# lana, del, ret, voic, make, better
# neg: 0.0, neu: 0.674, pos: 0.326, compound: 0.4404,
# trailer, channel
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# still, wait, theme, version, releas, 😅
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# quien, vino, solo, por, la, voz, de, lana, 🍷
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# one, favorit, disney, movi, ever, hope, make, movi, like, one, 😊, ❤
# neg: 0.0, neu: 0.633, pos: 0.367, compound: 0.8261,
# would, love, see, disney, make, dark, fairi, tale, movi
# neg: 0.0, neu: 0.682, pos: 0.318, compound: 0.6369,
# ok, pero, lana, de, fondo, 🛐, 🛐, 🛐
# neg: 0.0, neu: 0.694, pos: 0.306, compound: 0.296,
# big, wing, 🪽, carolina, talk, malefic, big, wing, 🪽, real, hedgehog, carolina, big, wing, carolina, hedgehog, hug, malefic, thank, malefic, magic, power, big, wing, carolina, hedgehog, malefic, listen, call, carolina, right, carolina, malefic, messag, letter, carolina
# neg: 0.0, neu: 0.869, pos: 0.131, compound: 0.6808,
# hfbhhdychrjdxhhfjdjfjc, ❤
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# know, better, te, movi, upon, dream, lana, del, rey, 😿, 💗
# neg: 0.0, neu: 0.741, pos: 0.259, compound: 0.5994,
# rhdhfyf, hj, fnfhhfnfchjf, fhcnffnnfnfnfnfnfb, ❤
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# lana, no, dió, art
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# rememb, trailer, scare, 😅
# neg: 0.314, neu: 0.686, pos: 0.0, compound: -0.4939,
# esto, si, es, live, action, la, que, hacen, ahora, ❤
# neg: 0.18, neu: 0.82, pos: 0.0, compound: -0.296,
# recien, entero, q, lo, canta, lana
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# angelina, joli, nail, role, malefic
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# lana, del, reyyyi
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# lana, del, rey, de, fondo, 😩, 😩, ♥, ️
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# liter, best, live, action, remak, disney, ever, made, 🖤, 💚
# neg: 0.0, neu: 0.704, pos: 0.296, compound: 0.6369,
# rightt, along, cinderella
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# grow, favourit, disney, movi, aladin, cinderella, snow-whit
# neg: 0.0, neu: 0.892, pos: 0.108, compound: 0.1779,
# bad, thing, suck, 😥, 🔥
# neg: 0.619, neu: 0.381, pos: 0.0, compound: -0.7579,
# mediocr, movi, cast, perform, good
# neg: 0.0, neu: 0.722, pos: 0.278, compound: 0.5927,
# dark
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# today, year, old, found, lana, del, rey, sang, trailer, absolut, speechless, thought, actual, angelina, malefic, sing, lana, wonder, job, voic, suit, eeri, aura, malefic, perfectli
# neg: 0.056, neu: 0.766, pos: 0.178, compound: 0.7506,
# like, almost, saw, thiss
# neg: 0.0, neu: 0.706, pos: 0.294, compound: 0.3612,
# sameee
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# @labio, roto, oh, ur, base, ur, comment, thought, u, least, ish
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# lol, style, talk, write, littl, know, advanc
# neg: 0.0, neu: 0.877, pos: 0.123, compound: 0.4215,
# let, go, back, eight, year, 😢
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# castl, begin, give, chill, everytim
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# cant, swift, magic, sdafat
# neg: 0.285, neu: 0.715, pos: 0.0, compound: -0.1511,
# film, yet, rate
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# aurora, first, live, action, disney, princess, 👸
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# best, movi, ever
# neg: 0.0, neu: 0.323, pos: 0.677, compound: 0.6369,
# amaz, 🔥
# neg: 0.0, neu: 0.0, pos: 1.0, compound: 0.5859,
# lana, perfect
# neg: 0.0, neu: 0.559, pos: 0.441, compound: 0.6948,
# показать, весь, фильм, или
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# plot, dess, film, é, incrível
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# perfect
# neg: 0.0, neu: 0.0, pos: 1.0, compound: 0.5719,
# want
# neg: 0.0, neu: 0.435, pos: 0.565, compound: 0.0772,
# malefic, favorit, live, action, disney, film, cruella, angela, joli, perfect, choic, malefic, also, one, best, movi, trailer, ever, get, chill, everi, singl, time
# neg: 0.0, neu: 0.728, pos: 0.272, compound: 0.9041,
# angelina, joli, parec, reina, herenia, enemiga, de, sailor, moon, villana
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# ell, fan, parec, sailor, moon
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# four, season, one, name, remain, three, 🎲, pokerfac
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# barhoush, tummi, name, hercul
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# diana
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# чертовкам, миньонам, руководство, к, раскаянью
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# trailer, better, movi
# neg: 0.0, neu: 0.633, pos: 0.367, compound: 0.4404,
# best, movi, ever
# neg: 0.0, neu: 0.323, pos: 0.677, compound: 0.6369,
# disney, experto, en, trailer
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# rememb, scare, trailer, child, horn, lol
# neg: 0.155, neu: 0.695, pos: 0.15, compound: -0.0258,
# jungl, book, 💎, edit, thor, frozen, 📀, amc, lego, 🎥, peabodi, sherman, muppet, want
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# gorgeou
# neg: 0.0, neu: 0.334, pos: 0.666, compound: 0.7901,
# buena, película, de, drama
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# honestli, still, manag, live, action, disney, film, made, go, useless, happi, made
# neg: 0.102, neu: 0.716, pos: 0.182, compound: 0.3257,
# ye, true, malefic
# neg: 0.0, neu: 0.421, pos: 0.579, compound: 0.6705,
# nonstop, attack, 😍
# neg: 0.492, neu: 0.508, pos: 0.0, compound: -0.4404,
# em, hỡi, yêu, nhau, chẳng, muộn, màng, lửa, bền, trong, đá, mấi, muôn, năm, lửa, đôi, ta, chẳng, cùng, nhau, đượm, sẽ, đốt, lòng, ta, ra, bụi, huy, cận
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# still, wish, kid, everi, night, open, window, miracl, come, 😀, 😀, 😀
# neg: 0.0, neu: 0.629, pos: 0.371, compound: 0.7579,
# reveng, forgiv
# neg: 0.737, neu: 0.263, pos: 0.0, compound: -0.6808,
# angelina, joli, admit, still, pair, horn, home, angelina, joli, pick, lana, del, rey, sing, sleep, beauti, upon, dream, end, credit, maleficent', magic, chang, colour, good, magic, gold, evil, magic, green, diaval', make-up, human, form, consist, crow', feet, face, bodi, actor, actress, malefic, partli, chosen, movi, base, uncanni, resembl, like, respect, charact, counterpart, disney', sleep, beauti, maleficent', horn, angelina, joli, wore, sever, headpiec, differ, weight, one, headpiec, heavi, angelina, would, neck, pain, right, therefor, appropri, physic, intens, scene, flight, battl, scene, malefic, fairi, notabl, resembl, harpi, hybrid, wing, creatur, greek, roman, mytholog, part, woman, bird, last, major, film, special, makeup, effect, artist, rick, baker, film, retir, industri, due, lack, good, work, maleficent', prosthet, make-up, inspir, singer, ladi, gaga, particularli, born, way, album, cover, angelina, jolie', disney, debut, film', cast, includ, one, oscar, winner, angelina, joli, two, oscar, nomine, imelda, staunton, lesley, manvil, pax, jolie-pitt, zahara, jolie-pitt, angelina, jolie', children, appear, briefli, cower, fear, malefic, christen, scene, name, malefic, deriv, latin, liter, mean, evil, doer, reason, given, film, malefic, young, good, fairi, name, start, becom, destruct, name, match
# neg: 0.084, neu: 0.815, pos: 0.101, compound: 0.4215,
# who
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# moral, lesson, invit, everi, gather, 🤣, 🤣, 🤣
# neg: 0.0, neu: 0.789, pos: 0.211, compound: 0.1531,
# love, forev, angi, 💋, ❤, ️, 💖, 🌹, 💕
# neg: 0.0, neu: 0.488, pos: 0.512, compound: 0.6369,
# good, ye
# neg: 0.0, neu: 0.0, pos: 1.0, compound: 0.6808,
# lawan, ya, hebat, peri, yang, baik, ☺, 🌷, 🌹
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# nice, idea, turn, love, song, gave, goosebump, love
# neg: 0.0, neu: 0.498, pos: 0.502, compound: 0.902,
# uzowastvuzh
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# disney, made, right, choic, chose, angelina, role, lana, sing, song, 💯
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# qaeyztudatuxoreardtftxrvixotsaswsstslksdrzofssdyxhssrgofdzigzfyd
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# first, taught, song, sang, malefic, 🙄, 🙄, 🙄
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# wauxosufotasrsyewswahorzrsptqqswetcxuxdqqesefydycogisrfyxdyx
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# wauxosufotasrsyewswahorzrsptqqswetcxuxdqqesefydycogisrfyxdyx
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# aigkgizpofsyapywrsoiasitaawtehidduguf
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# watch, like, year, old, im, watch, year, old, favoirit, movi, malifi, soo, beauti, love, face, 🖤, 🖤, 🖤
# neg: 0.0, neu: 0.882, pos: 0.118, compound: 0.4738,
# best, disney, trailer
# neg: 0.0, neu: 0.283, pos: 0.717, compound: 0.7249,
# heard, song, credit, idea, lana, del, rey, 🤯
# neg: 0.112, neu: 0.761, pos: 0.127, compound: 0.0772,
# angelina, angelina, angelina, ❤, ❤, ❤, 👏, 👏, 👏, 🔥, 🔥, 🔥
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# thought, video, malefic, beauti, 🥰
# neg: 0.0, neu: 0.656, pos: 0.344, compound: 0.6361,
# lana, del, rey, ❣, ️
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# say, film, trailer, among, greatest
# neg: 0.0, neu: 0.734, pos: 0.266, compound: 0.7783,
# love, dark, side, disney, els
# neg: 0.0, neu: 0.704, pos: 0.296, compound: 0.6369,
# เคยได้เจอ, ได้เคียงข้างกับเธอในฝันรื่นรมย์, เคยพบเธอ, และแววตาที่เห็นคุ้นเคยยังจำได้ไม่ลืม, และจะคอยสักวันความฝันจะเป็นจริง, สุขใจชื่นชม, หากพบเธออีกครั้งเธอฉันคงชื่นชู, แรกพบก็รักกัน, เป็นรักชั่วนิรันดร์, รักเราไม่เลือน, หากพบเธออีกครั้งเธอฉันคงชื่นชู, แรกพบก็รักกัน, เป็นรักชั่วนิรันดร์, รักเราไม่เลือน
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# alway, come, back, trailer, damn, great, choic, market, drew, back, thought, old, disney, one, greatest, movi, trailer
# neg: 0.063, neu: 0.744, pos: 0.193, compound: 0.765,
# rememb, see, trailer, theater, could, hear, whole, theater, go, oooooooh, shiiiiiii
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# hail, queen, angelin, joli
# neg: 0.0, neu: 0.794, pos: 0.206, compound: 0.0772,
# watch, movi, trailer, look, fabul, ❤, ️
# neg: 0.0, neu: 0.612, pos: 0.388, compound: 0.7717,
# villain, sing, much, better, princess, 😍, 😍, 😍
# neg: 0.265, neu: 0.543, pos: 0.192, compound: -0.3008,
# lana, del, rey, perfect, voic, song, haunt
# neg: 0.157, neu: 0.631, pos: 0.212, compound: 0.2403,
# like, disney, goe, live, action, movi, 😍, especi, da, villian, main, charact
# neg: 0.0, neu: 0.857, pos: 0.143, compound: 0.3612,
#
# neg: 0.0, neu: 0.0, pos: 0.0, compound: 0.0,
# glad, sing
# neg: 0.0, neu: 0.571, pos: 0.429, compound: 0.4588,
# prettiest, singer, prettiest, actress, movi, togeth, take
# neg: 0.0, neu: 0.539, pos: 0.461, compound: 0.8614,
# แต่ถ้ามีปันหาที่วัดนี้น่าจะตอนหนูเด็กๆกันแล้ว, .., จำไว้
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# คุณพ่อที่ช่วยงานศพของพี่ชายลูกยังอยู่ที่วัดนักบุญลูกาหรือไม่, .., เพราะคุณพระองค์นี้คือผู้มีพระคุณที่ลูกคนบาปต้องก้มกราบ, อาแมน
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# that', one, dark, gloomi, trailer, appropri, movi, alright
# neg: 0.103, neu: 0.769, pos: 0.128, compound: 0.1027,
# man, sorri, thought, suppos, sleep, beauti
# neg: 0.076, neu: 0.702, pos: 0.222, compound: 0.5423,
# slept, movi, amaz
# neg: 0.0, neu: 0.678, pos: 0.322, compound: 0.5859,
# trailer, better, actual, movi, gave, cooler, creepier, vibe
# neg: 0.0, neu: 0.818, pos: 0.182, compound: 0.4404,
# best, trailer
# neg: 0.0, neu: 0.488, pos: 0.512, compound: 0.6369,
# malefic, creepi, sassi
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# gunna, lie, trailer, done, well, gave, chill, first, saw
# neg: 0.0, neu: 0.854, pos: 0.146, compound: 0.4101,
# favorit, disney, movi
# neg: 0.0, neu: 0.4, pos: 0.6, compound: 0.4588,
# ahí, quedó, lo, que, pudo, ser, 😔
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# love, malefic, orora
# neg: 0.0, neu: 0.417, pos: 0.583, compound: 0.6369,
# angelina, joli, ❤, ️, ❤, ️, ❤, ️, sexi, face, none, like
# neg: 0.183, neu: 0.521, pos: 0.295, compound: 0.316,
# sing, freak
# neg: 0.355, neu: 0.645, pos: 0.0, compound: -0.296,
# still, favorit, movi, one, come, malefic, mistress, evil
# neg: 0.216, neu: 0.637, pos: 0.147, compound: -0.34,
# notic, bit, sneaki, remov, cgi, wing, scene, trailer, would, make, peopl, abl, see, wing, second, trailer, came, lol
# neg: 0.046, neu: 0.887, pos: 0.067, compound: 0.2263,
# still, best, stori, malefic, also, good
# neg: 0.0, neu: 0.65, pos: 0.35, compound: 0.7543,
# icon, well, well, angelina, born, role, gorgeou, 😍
# neg: 0.0, neu: 0.574, pos: 0.426, compound: 0.8135,
# 😍, 😍, 😍
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# angelina, joli, born, play, role, lana, del, ray, born, sing, song
# neg: 0.0, neu: 0.87, pos: 0.13, compound: 0.34,
# mani, seen, malefic, mistress, evil
# neg: 0.355, neu: 0.645, pos: 0.0, compound: -0.6597,
# rewatch, sequel
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# lana', voic, magic
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# malefici, well, well, caption, know, tale
# neg: 0.0, neu: 0.556, pos: 0.444, compound: 0.5837,
# can't, believ, year, ago, damn, ok
# neg: 0.209, neu: 0.62, pos: 0.171, compound: -0.128,
# love
# neg: 0.0, neu: 0.288, pos: 0.712, compound: 0.7125,
# walk, school, yard
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# trailer, still, good
# neg: 0.0, neu: 0.408, pos: 0.592, compound: 0.4404,
# love, trailer, unfortun, movi, live, hype, expect
# neg: 0.175, neu: 0.678, pos: 0.147, compound: -0.128,
# walt, disney, pictur, malefic, angelina, joli, soundtrack, movi, lana, del, rey', cover, colabor, beauti, woman, world, 💖, 💖, 💖
# neg: 0.0, neu: 0.87, pos: 0.13, compound: 0.6361,
# 😜, 😝, 😌
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# lana, 😍, ❤
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# would, love, version, song
# neg: 0.0, neu: 0.572, pos: 0.428, compound: 0.6696,
# play, time, lana, del, rey
# neg: 0.0, neu: 0.714, pos: 0.286, compound: 0.34,
# make, want, write, horror, fairi, tale, lol, :d
# neg: 0.22, neu: 0.536, pos: 0.244, compound: -0.1531,
# agre
# neg: 0.0, neu: 0.0, pos: 1.0, compound: 0.3612,
# one, best, movi, ever, great, cast
# neg: 0.0, neu: 0.482, pos: 0.518, compound: 0.8622,
# final, movi, true, love, kiss, princ, meet, kiss, anoth, kind, love
# neg: 0.0, neu: 0.547, pos: 0.453, compound: 0.9201,
# make, sens, year, ago, dont, even, know, mean
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# malefic, trailer
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# angelina, said, “, well, well, ”, gay, cultur
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# game, throne, meet, disney
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# angelina, fuck, phenomen
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# came, back, new, trailer
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# malefic, 🔥, 🔥, 🔥
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# bye, lesbo
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# billion, dollar, blue, light, show, 🏥, 🦆, 🎅, 🌉, 🥋, 🏢
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# brad, thank, 🏭, 🙏, bless, me.beyh, said, nah, nah, 🙏, 🌉, 🌃, ⛺, 🏥, new, york, yall, hit, billionair, ⛺, 🏥, 🦆
# neg: 0.137, neu: 0.585, pos: 0.278, compound: 0.5994,
# angi, bless, beyhiv, isnt, nah, beyhiv, away, dread.her, nah, cread, ye, 🏭, 🙏, see, importance.of, help, men, ye, do.cnn, beyhiv, bey
# neg: 0.0, neu: 0.649, pos: 0.351, compound: 0.8748,
# lana, del, rey, movi, beauti, 💕, ✝, ️
# neg: 0.0, neu: 0.63, pos: 0.37, compound: 0.7417,
# movi, exact, tone, trailer, promis, would, dark, grown, think, that', disappoint, film, mani, thing, grant, effect, action, sequenc, nice, look, angelina, joli, especi, realli, good, role, think, well, rest, cast, deserv, better, script, better, direct, much, potenti, wast, laughabl, bad, charact, develop, piss, poor, rewrit, stori, villain, alreadi, fantast, unfocus, tone, honestli, one, worst, film, disney, done, lazi, attempt, cash, wicked', success
# neg: 0.169, neu: 0.646, pos: 0.185, compound: 0.1672,
# simpli, reason, chang, stori, much, malefic, becam, popular, disney, villain, ofc, make, good, money--profit, angelina, awesom, realli, dislik, kept, evil, even, dislik, good, charm, fairi, origin, top, best, known, disney, fairi, togeth, fairygodmoth, tinkerbel, turn, stupid, idiot, version, also, realli, miss, aurora', forev, color, chang, dress, movi, angelina, everyth, arrang, maleficent', innoc
# neg: 0.137, neu: 0.597, pos: 0.266, compound: 0.9499,
# kid, hate, movi, cartoon, one, actual, icon
# neg: 0.163, neu: 0.837, pos: 0.0, compound: -0.5719,
# upon, dream, becam, malefic
# neg: 0.0, neu: 0.714, pos: 0.286, compound: 0.25,
# who, hear
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# anyon
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# oh, god
# neg: 0.0, neu: 0.488, pos: 0.512, compound: 0.2732,
# sleep, beauti
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# great, movi, thank, creator
# neg: 0.0, neu: 0.301, pos: 0.699, compound: 0.9559,
# origin, disney, classic, made, realli, gothic, tale, milleni, version
# neg: 0.0, neu: 0.859, pos: 0.141, compound: 0.3182,
# one, thought, angelina, joli, sing, song, trailer
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# shame, angelina, never, oscar, brilliant, portray
# neg: 0.323, neu: 0.476, pos: 0.201, compound: -0.3178,
# kind, look, like, game, throne, pg
# neg: 0.0, neu: 0.821, pos: 0.179, compound: 0.1901,
# fico, imaginando, os, bastidor, pra, fazer, um, film, tão, bem, feito, como, ess
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# เคยได้เจอ, ได้เคียงข้างกับเธอในฝันรื่นรมย์, เคยพบเธอ, และแววตาที่เห็นคุ้นเคยยังจำได้ไม่ลืม, และจะคอยสักวันความฝันจะเป็นจริง, สุขใจชื่นชม, หากพบเธออีกครั้งเธอฉันคงชื่นชู, แรกพบก็รักกัน, เป็นรักชั่วนิรันดร์, รักเราไม่เลือน, หากพบเธออีกครั้งเธอฉันคงชื่นชู, แรกพบก็รักกัน, เป็นรักชั่วนิรันดร์, รักเราไม่เลือน
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# well, well
# neg: 0.0, neu: 0.323, pos: 0.677, compound: 0.2732,
# awesom, trailer, disappoint, movi, like, serious, award, trailer, turn, garbag, diamond
# neg: 0.151, neu: 0.554, pos: 0.295, compound: 0.6908,
# watch
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# amaz, rememb, movi, actor, special, effect, environ, anim, creatur, music, made, peopl, us, —, entir, univers
# neg: 0.0, neu: 0.822, pos: 0.178, compound: 0.7579,
# turn, back, angelina
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# purrrdi
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# know, want, stay, stick, winner
# neg: 0.073, neu: 0.655, pos: 0.272, compound: 0.6173,
# take, love, long, wonder, hair, maiden
# neg: 0.0, neu: 0.724, pos: 0.276, compound: 0.6369,
# tk
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# shitti, movi
# neg: 0.783, neu: 0.217, pos: 0.0, compound: -0.5574,
#
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
#
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# rumplestilkin, time
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# love, movi, though, still, say, ell, bad, cast, choic
# neg: 0.195, neu: 0.556, pos: 0.25, compound: 0.2481,
#
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# best, version, song, ever, heard
# neg: 0.0, neu: 0.704, pos: 0.296, compound: 0.6369,
# enjoy, movi, anim, one
# neg: 0.0, neu: 0.652, pos: 0.348, compound: 0.4939,
# version, much, better, ❤, ️
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# see, malefic, stori, need, know, ursula, never, trust, bitch, ariel
# neg: 0.151, neu: 0.65, pos: 0.199, compound: 0.2047,
# anyon, know, song, besid, song, lana, del, rey, trailer, consist
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# hope, one, day, live, action, version, sleep, beauti
# neg: 0.0, neu: 0.573, pos: 0.427, compound: 0.7717,
# like, movi, person, like, sleep, beauti, better, sinc, aurora, second, favorit, princess, snow, white
# neg: 0.0, neu: 0.435, pos: 0.565, compound: 0.9595,
# ❤, ❤, ❤, 👍, 👍, 👍, 💜, 💜, 💜, 💞, 💖, 💋, 💗, 💖, 💖, 💖, 💋, 💋, 💋
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
#
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# realli, like, film, thought, amaz, give, damn, critic, say
# neg: 0.097, neu: 0.486, pos: 0.417, compound: 0.8043,
# lana, del, rey, angelina, joli, made, movi
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# ♡
# neg: 0.0, neu: 0.0, pos: 0.0, compound: 0.0,
# man, love, trailer, probabl, movi, look, dark, end, mom, daughter, relationship, sappi, film, :(, like, great, come, trailer, made, look, evil, hope, she, malefic
# neg: 0.197, neu: 0.555, pos: 0.248, compound: 0.4939,
# hope, ya'll, know, that', lana, del, rey, sing, da, best
# neg: 0.0, neu: 0.549, pos: 0.451, compound: 0.8122,
# disney, dark, 😮
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# love, caus, made, like, horror, movi, lol
# neg: 0.193, neu: 0.312, pos: 0.495, compound: 0.7003,
# ini, like, angelina, ​, joli, 😅, 😘, 😘, 😘, 😱, 😱
# neg: 0.0, neu: 0.667, pos: 0.333, compound: 0.3612,
# wow, angelina, joli
# neg: 0.0, neu: 0.345, pos: 0.655, compound: 0.5859,
# peopl, stupid, mani, thought, stori, line, think, clearli, king, stole, wing, broke, heart, left, rot, swear, piss, curs, daughter, reveng, realli, good, bet, half, peopl, text, movi
# neg: 0.166, neu: 0.66, pos: 0.174, compound: 0.3801,
# wow
# neg: 0.0, neu: 0.0, pos: 1.0, compound: 0.6884,
# els, disappoint, die, end, like, cartoon
# neg: 0.157, neu: 0.557, pos: 0.286, compound: 0.3707,
# beauti, thing, turn, one, disney, fear, villain, made, hero, twist, stori, that', real, art, yet, mani, peopl, bash, want, someth, predict, thank, peopl, star, war, ruin, mani, movi, one, want, take, chanc, anymor, can't, appreci, art, watch, listen, pay, attent
# neg: 0.215, neu: 0.653, pos: 0.132, compound: -0.7927,
# la, cancion, la, canta, lana, del, rey, 😘, 😘, song, lana, del, rey
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# person, think, live, action, remak, great, one, definit, best, 👍
# neg: 0.0, neu: 0.541, pos: 0.459, compound: 0.9169,
# ell, fan
# neg: 0.0, neu: 0.408, pos: 0.592, compound: 0.4404,
# malefica, sei, grand
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# came, new, beauti, beast, trailer, .., watch, disney, live, action, remak, think, beauti, beast, best
# neg: 0.0, neu: 0.679, pos: 0.321, compound: 0.9153,
# ye, think, ❤
# neg: 0.0, neu: 0.526, pos: 0.474, compound: 0.4019,
# watch, disney, remak, trailer, obsses, beauti, beast, upcom, remak
# neg: 0.0, neu: 0.765, pos: 0.235, compound: 0.7117,
# omg, 😂, ❤, ❤
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# mani, peopl, disappoint, malefic, portray, villain.tbh, surpris, think, littl, matur, approach, show, us, peopl, shape, consequ, stuff, teach, us, judg, peopl, quickli, even, disney', greatest, villain, stori, made, person, love, movi
# neg: 0.092, neu: 0.716, pos: 0.192, compound: 0.8204,
# oh, god, final, understand
# neg: 0.0, neu: 0.676, pos: 0.324, compound: 0.3382,
# movi, said, stori, quit, told, that', maleficent', back, stori, reveal, understand
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# agre, point, movi, disney, movi, purpos, specif, point, one, want, love, malefic, alway, interest, charact, sleep, beauti, one, best, villain, gener, made, sens, make, protagonist
# neg: 0.066, neu: 0.674, pos: 0.26, compound: 0.9184,
# woman, start, disney, live, action, movi, 😭, still, love, cinderella
# neg: 0.0, neu: 0.731, pos: 0.269, compound: 0.6988,
# amaz, watch, movi, rewatch, anim, version, cant, stop, disappoint, sleep, beauti, stori, becom, weird, know, titl, malefic, movi, tell, us, back, stori, continu, stori, sleep, beauti, lot, better, miss, scene, fairi, use, magic, make, aurora', dress, realli, wish, make, film, magic
# neg: 0.089, neu: 0.669, pos: 0.242, compound: 0.9485,
# hate, movi, malefic, suppos, mistress, evil, make, good, guy, make, becom, aurora', love, interest
# neg: 0.18, neu: 0.511, pos: 0.31, compound: 0.8335,
# lgbt, 😂
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# one, time, favorit, live, action, disney, movi, ugh, lana, del, rey, queen, voic, give, chill
# neg: 0.107, neu: 0.767, pos: 0.126, compound: 0.126,
# potenti, good, listen, take, disney', greatest, villain, turn, hero, never
# neg: 0.317, neu: 0.481, pos: 0.201, compound: -0.7638,
# film, guilti, pleasur, certainli, like, certain, part, peopl, onlin, point, flaw, think, oh, right
# neg: 0.067, neu: 0.673, pos: 0.26, compound: 0.5346,
# jessica, cortez, villian, natur, born, made, that', film, taught, time, chang, disney
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# alway, sound, like, sing, grit, teeth
# neg: 0.0, neu: 0.741, pos: 0.259, compound: 0.4215,
# who', readi, second, one
# neg: 0.0, neu: 0.642, pos: 0.358, compound: 0.4199,
# think, continu, second, one, also, dunno, continu
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# eeveeparti, june, angelina, joli, hint, possibl, sequel, june, disney, announc, sequel, linda, woolverton, return, write, screenplay, joe, roth, produc, film, april, confirm, joli, repris, role, malefic
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# sarah, h, say, want, sequel, unlik, mani, other, groan, movi, found, part, realli, like, film, cool, continu, know, continu
# neg: 0.0, neu: 0.816, pos: 0.184, compound: 0.6765,
# mae, borowski, well, malefic, mistress, evil, came, theater, awkward, situat
# neg: 0.248, neu: 0.67, pos: 0.083, compound: -0.636,
# well, well, dream, come, true
# neg: 0.0, neu: 0.171, pos: 0.829, compound: 0.8271,
# @brvqnz, lol
# neg: 0.0, neu: 0.263, pos: 0.737, compound: 0.4215,
# could, better, malefic
# neg: 0.286, neu: 0.714, pos: 0.0, compound: -0.3412,
# love, movi, trailer, damn, good, version, song, alway, come, back, watch
# neg: 0.121, neu: 0.623, pos: 0.256, compound: 0.5977,
# love, movi
# neg: 0.0, neu: 0.488, pos: 0.512, compound: 0.6369,
# wow, song
# neg: 0.0, neu: 0.208, pos: 0.792, compound: 0.5859,
# run, demon, lord
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# thank, share, rubybab
# neg: 0.0, neu: 0.205, pos: 0.795, compound: 0.8294,
# better, cinderella
# neg: 0.0, neu: 0.61, pos: 0.39, compound: 0.4926,
# 😷, 😗, 😗, 😗, 😙, 😘, 😂, f, schoolgirl, k
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# que, es
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# still, get, goosebump, hear, open, piano, note, pan, battlefield, hear, lana, sing, upon, dream
# neg: 0.102, neu: 0.82, pos: 0.078, compound: -0.1531,
# 👿, 💀, 💀, 👤
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# blu, ray, releas, north, america, 😢
# neg: 0.239, neu: 0.761, pos: 0.0, compound: -0.296,
# long, live, tchaikovski
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# know, could, use, wood, style, deep, forest, emerg, jutsu
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# shoutout, queen, lana, del, rey, cover, song, upon, dream, love
# neg: 0.0, neu: 0.683, pos: 0.317, compound: 0.7574,
# love, end, laugh
# neg: 0.0, neu: 0.351, pos: 0.649, compound: 0.8126,
# watch, trailer, thousand, time, unfortun, movi, dissapoint
# neg: 0.179, neu: 0.821, pos: 0.0, compound: -0.34,
#
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
#
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# ppl, imposs, pleas
# neg: 0.0, neu: 0.685, pos: 0.315, compound: 0.3182,
# theunderdog, imposs, pleas, movi, disappoint, said, everi, movi, world, deep, lol
# neg: 0.188, neu: 0.735, pos: 0.077, compound: -0.5158,
# movi, great, idj, els, pol, want, sesshh
# neg: 0.0, neu: 0.625, pos: 0.375, compound: 0.6597,
# jesusbar, that', opinion, b, x
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# oh, god, thank, thought, go, dark, mysteri, like, trailer, suggest, good, part, movi, malefic, act, like, well, malefic, complet, chang, stori, love, trailer, imagin, movi, could
# neg: 0.0, neu: 0.692, pos: 0.308, compound: 0.9636,
# came, good, zzz, ☺
# neg: 0.0, neu: 0.508, pos: 0.492, compound: 0.4404,
# would, differ
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# true, evil, born, creat, path, choos, defin, good, evil, must, rememb, devil, wasnt, alway, bad, angel, god, fact, lucif, name
# neg: 0.262, neu: 0.541, pos: 0.197, compound: -0.7023,
# movi, awesom
# neg: 0.0, neu: 0.423, pos: 0.577, compound: 0.6249,
# evil, 😖
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# wet, pant, 😧
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# love, movi, much, like, perfect, thank, angelina, perfect, mask, face, expres, simpli, love, alway, calm, see, movi, :), like, everi, time
# neg: 0.0, neu: 0.511, pos: 0.489, compound: 0.9718,
# #اصحاب_ثنيان, ✌🏻, ️
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# باقي, افتح, ثلاجتنا, القى, الهاشتاق
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# vcxjxjjjjjnnbbnnnnnnvbcvvxvc, fgk, gv, v, vbvchxc, cm, cm, vi, h, b, b, v, cm, b, bvv, b, vbv, b
# neg: 0.18, neu: 0.82, pos: 0.0, compound: -0.296,
# fxvxhfg, f, fsgdhdkhjg, zhang, fgk, cu, g, g, j, fgk, cu, g, hcxfvgxvv, vvgghggggb, h, k, fgk, hjjsjdfjfhddhdf, h, x, nb, kxkddnnssnsndjsdj, g, dhdjdjjddj, ruf, hrhdjdj, db, dhdjjdhdd, h, fb, fb, fb, db, dbdgndnggdnddnkdhgfdjdjdjdjdj, f, hd, f, djjdxnxmxkskkdkufhdhzg, cbbghhdggffgfbhhhvbjvfbvbvvg'bhh, kjjjj, hfhf, hi, gu, fgk, g, b, g, g, kjjjj, hf, g, ghggfgfggfgg
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# definit, best, disney, trailer, seen
# neg: 0.0, neu: 0.42, pos: 0.58, compound: 0.7845,
# lana, del, rey, yess
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# sao, k, co, nguyên, bộ, phim, nhỉ
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# malefic, lepor
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# longer, version, movi, one, copi, minut
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# background, music, first, stage, epic, mickey
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# kult, 😆
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# simpli, love, movi, alway, return, see, trailer, ..
# neg: 0.0, neu: 0.724, pos: 0.276, compound: 0.6369,
# awesom, trailer, aw, movi
# neg: 0.27, neu: 0.36, pos: 0.369, compound: 0.2732,
#
# neg: 0.524, neu: 0.476, pos: 0.0, compound: -0.296,
# look, evil, name, perla, 😯, 😯, 😯
# neg: 0.355, neu: 0.645, pos: 0.0, compound: -0.6597,
# lana, del, rey, upon, dream, voic, thoo
# neg: 0.0, neu: 0.8, pos: 0.2, compound: 0.25,
# puedo, ver, esto, mil, vese
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# 😈, 😈, mar, ovi, uvut
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# 😃
# neg: 0.0, neu: 0.0, pos: 0.0, compound: 0.0,
# ben
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# even, backstori, make, sens
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# well, well, line, never, get, old, hail, mistress, evil
# neg: 0.0, neu: 0.746, pos: 0.254, compound: 0.34,
# es.osojsfoossc, leieeltyx
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# mistress, evil
# neg: 0.688, neu: 0.312, pos: 0.0, compound: -0.6597,
#
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# creep
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
#
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# eeh, year, earli
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# omg, hahahahahhaha
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# u
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# heck, ..
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# dammn, u, predict, move, titl, gurlllll
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# wow
# neg: 0.0, neu: 0.208, pos: 0.792, compound: 0.5859,
# realli, got, emot, lost, wing
# neg: 0.226, neu: 0.589, pos: 0.185, compound: -0.1082,
# love, malefic, movi, emot
# neg: 0.0, neu: 0.496, pos: 0.504, compound: 0.7264,
# lana, del, rey, ❤, ️
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# cheekbon, could, kill, someon, 😂
# neg: 0.54, neu: 0.46, pos: 0.0, compound: -0.6908,
# perla, morant, juarez, let's_be_r, prosthet, cheekbon
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# way, hear, thear, black, mackup
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# gotta, pointer, spindl
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# juh, gf
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# animalart
# neg: 0.306, neu: 0.694, pos: 0.0, compound: -0.296,
# bumperstick, crumblebottom, cheekbone-off
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# power, maleficint
# neg: 0.0, neu: 0.393, pos: 0.607, compound: 0.4754,
# anyon, know, find, music, know, song, lana, upon, dream, part, song, soundtrack
# neg: 0.043, neu: 0.889, pos: 0.069, compound: 0.1803,
# probabl, score, movi
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# face, shade, much
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# riza, hariati, that', shade, prostet
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# chiniwand, ooohhhhhh, reliev, worri, becom, skinni, thank
# neg: 0.135, neu: 0.491, pos: 0.374, compound: 0.6583,
# omg, love, movi, love, song
# neg: 0.0, neu: 0.33, pos: 0.67, compound: 0.9213,
# malefic, movi, make, sens, sleep, beauti, malefic, girl, evil, stori, behind
# neg: 0.0, neu: 0.848, pos: 0.152, compound: 0.5659,
# malefec, awsom, 😈, 🏰, 🌷
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# new, movi, descedent
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# there', say, evil, born, made, wonder, peopl, turn, evil, creatur, look, back, stori
# neg: 0.306, neu: 0.694, pos: 0.0, compound: -0.8689,
# sociopath, murder, everyday, peopl
# neg: 0.323, neu: 0.677, pos: 0.0, compound: -0.6486,
# coolbanana, point, usual, person, would, never, suspect
# neg: 0.0, neu: 0.864, pos: 0.136, compound: 0.2235,
# hehe, ouat
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# yeah, true, nobodi, born, evil
# neg: 0.328, neu: 0.299, pos: 0.373, compound: -0.1027,
# yeap, demon, exil, angel, angel
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# oh, angi, angi, yet, prove, kick, ass, better, anyon, els, love, movi, think, watch, thousand, time
# neg: 0.0, neu: 0.747, pos: 0.253, compound: 0.7964,
# awsom
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# love, movi, malefic, malefic, mistress, evil, born, pure, dark, sadist, psychopath, care, peopl, direct, quot, sleep, beauti, movi, can't, bad, oooh, ye, origin, movi, sleep, beauti, malefic, curs, babi, die, later, find, curs, chang, sought, seek, aurora, lead, prick, finger, forc, fairi, make, kingdom, fall, deep, slumber, aurora, true, love, came, malefic, lock, away, forc, grow, old, aurora, sleep, etern, malefic, plan, let, go, princ, die, old, age, crawl, toward, aurora, die, old, age, flood, kingdom, terribl, tree, moor, turn, dragon, princ, close, tri, destroy
# neg: 0.168, neu: 0.695, pos: 0.137, compound: -0.8193,
# thecrazybritish, yea, disney, gonna, add, stuff, alway, leav, good, part, :(
# neg: 0.166, neu: 0.71, pos: 0.124, compound: -0.0772,
# love, malefic, ❤, ️, ❤, ️, ❤, ️, ❤, ️, ❤, ️, ❤, ️, ❤, ️, 💋, 💋, 💋
# neg: 0.0, neu: 0.417, pos: 0.583, compound: 0.6369,
# evil, 😨, 😨, 😨
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# perla, morant, juarez, return, evil
# neg: 0.569, neu: 0.431, pos: 0.0, compound: -0.765,
# lana
# neg: 0.0, neu: 0.256, pos: 0.744, compound: 0.4404,
# movi, beauti, tt, tt, love, u, angi
# neg: 0.0, neu: 0.405, pos: 0.595, compound: 0.87,
# mei, yue, fantast, piec, news, get, iphon, plu, free
# neg: 0.0, neu: 0.634, pos: 0.366, compound: 0.8429,
# anybodi, say, movi, good
# neg: 0.0, neu: 0.706, pos: 0.294, compound: 0.5777,
# класс
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# love, song
# neg: 0.0, neu: 0.192, pos: 0.808, compound: 0.6369,
# badthi, osng, never, movi
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# hillari, clinton, like, malefic
# neg: 0.0, neu: 0.667, pos: 0.333, compound: 0.3612,
# easili, best, trailer, movi, hand
# neg: 0.0, neu: 0.476, pos: 0.524, compound: 0.765,
# love, movi
# neg: 0.0, neu: 0.22, pos: 0.78, compound: 0.7964,
# best, trailer, ever
# neg: 0.0, neu: 0.323, pos: 0.677, compound: 0.6369,
#
# neg: 0.0, neu: 0.0, pos: 0.0, compound: 0.0,
# enjoy, movi, disappoint, felt, like, trailer, show, evil, person, bad, guy, find, valid, reason, go, nut, turn, good, movi, good, would, love, seen, evil, way
# neg: 0.215, neu: 0.614, pos: 0.172, compound: -0.6486,
# stand, point, still, like, movi, actual, realli, want, watch
# neg: 0.0, neu: 0.761, pos: 0.239, compound: 0.4754,
# bài, dream, nài, hay, thật
# neg: 0.0, neu: 0.667, pos: 0.333, compound: 0.25,
# lana, del, rey', voic, amaz, dark
# neg: 0.0, neu: 0.662, pos: 0.338, compound: 0.6239,
# majest, mysteri
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# beauti, movi, see, theater
# neg: 0.0, neu: 0.642, pos: 0.358, compound: 0.5994,
# instant, classic
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# dream
# neg: 0.0, neu: 0.304, pos: 0.696, compound: 0.3164,
# movi, feminist, rewrit, origin, malefic, evil, man, betray, god, forbid, femal, could, never, born, pure, evil, back, real, world, king, even, hug, daughter, seen, year, incap, anyth, product, meanwhil, men, love, care, even, children, nowaday, women, men, invent, build, maintain, repair, entir, fuck, world, women, shop, princ, even, wake, sleep, beauti, sleep, let, guess, men, capabl, true, love, malefic, woke, true, love, ass, let', tri, lesbian, love, implic, end, surpris, even, bother, even, throw, princ, back, moor, even, bother, accord, feminist, revis, femin, gener, men, even, necessari, incap, emot, anyth, els, even, matter, fuck, movi, horribl, children, watch, give, horribl, messag
# neg: 0.195, neu: 0.64, pos: 0.164, compound: -0.481,
# jeff, bridg, welp, doubt, mayb, realli, messag, realiti, liter, one, got, one, think, took, whole, new, extrem, sort, seem, like, sexist, realist, straight, sexist, littl, bitter, someth, still, agre, feminist, man, hater, gener
# neg: 0.226, neu: 0.694, pos: 0.081, compound: -0.8705,
# guess, quot, meanwhil, men, love, care, even, children, nowaday, women, men, invent, build, maintain, repair, entir, fuck, world, women, shop, pretti, sure, qualifi, sexist, dumbass, two, sound, like, ignor, prick, high, school, guess, probabl, go, back, loser, whole, die, three, know, talk, fuck, movi, interpret, man, hate, piec, shit, sure, could, interpret, way, would, disagre, say, one, benight, piec, shit, see, that', continu, say, meanwhil, men, love, care, even, children, nowaday, women, men, invent, build, maintain, repair, entir, fuck, world, women, shop, specif, can't, compar, hate, pedo, hate, women, women, gener, shitti, thing, pedo, nice, tri, analog, realli, requir, intellig, ye, lot, idiot, societi, today--includ, yourself--but, fact, one, interpret, horribl, extrem, feminist, movi, prove, much, idiot, piec, shit, obvious, problem, woman, gener, extrem, feminist, next, time, put, ignor, comment, youtub, expect, peopl, call, much, idiot
# neg: 0.173, neu: 0.71, pos: 0.117, compound: -0.9627,
# rachel, boaky, that', sexist, call, fact, everyth, room, sit, invent, man, stupid, mayb, need, go, back, high, school, start, complet, first, grade, use, word, pedophil, order, demonstr, provid, exampl, stupid, say, stupid, even, get, realli, simpl, understand, too.femin, made, extrem, stupid, show, idiocraci, come, u, women, far, stupidest, women, earth
# neg: 0.178, neu: 0.822, pos: 0.0, compound: -0.967,
# jeff, bridg, realli, feminist, gender, equal, man, hate, type, promot, kind, stuff, decid, take, look, profil, seem, problem, basic, everyth, everyon, els, okay, african-american, women, homosexu, judg, belief, end, togeth, exactli, sure, whether, troll, prop, otherwis, worthless, piec, shit, bye
# neg: 0.147, neu: 0.76, pos: 0.093, compound: -0.7536,
# lol, say, lot, women, anyth, societi, need, femin, like, cancer, patient, need, cigarett, need, extrem, opposit, femin, men, today, strip, right, marriag, divorc, child, custodi, abort, thrown, jail, lose, job, can't, pay, child, support, alimoni, go, jail, victim, assault, vawa, man, even, murder, woman, get, away, long, lie, say, abus, men, fals, accus, everi, singl, day, rape, even, claim, turn, fals, name, still, smear, life, basic, femin, go, fuck, joke, outdat, women, got, equal, right, stupid
# neg: 0.2, neu: 0.751, pos: 0.049, compound: -0.9826,
# hahaha, drown, self, piti, idiot, get, work, career, chang, legal, landscap, men, expos, feminist, like, misinform, fraud, cockroach, mra, except, men, regardless, lifestyl, stupid, talk, gay, men, time, haha, show, touch, date, femin, end, year, went, tie-dy, t-shirt, grate, dead, women, gain, equal, right, might, want, go, get, psychiatr, counsel, least, educ, histori, girl, western, countri, can't, get, educ, anyth, els, want, matter, feminist, realli, concern, goe, world, countri, would, go, stupid, complain, instead, pettiest, trivial, insan, thing, men, say, good, morn, street, video, game, petti, loser, life, like, besid, got, news, seen, documentari, even, talk, women, variou, world, countri, tell, even, want, femin, sick, pervers, cultur, famili, complet, broken, marriag, abomin, fall, apart, dysfunct, anyth, like, western, women, femin, caus, complet, societ, breakdown, half, mother, singl, welfar, would, intellig, women, want, live, like, call, women, like, idiot, trash, shameless, whore, that'
# neg: 0.19, neu: 0.699, pos: 0.111, compound: -0.9861,
# got, wrong, think, wast, time, read, text, haha, that', illiter, prob, can't, understand, anyway, take, women, serious, laugh, behind, back, hahaha, least, everyon, els, read, laugh, made, look, like, stupid, joke, hahaha
# neg: 0.148, neu: 0.593, pos: 0.259, compound: 0.8984,
# jeff, bridg, high, hors, say, contribut, societi, talk, anyon, around, thu, contribut, societi, attempt, insult, degrad, peopl, make, societi, must, idiot, think, women, born, evil, respons, villiag, idiot, say, somewher, texa, villag, miss
# neg: 0.257, neu: 0.743, pos: 0.0, compound: -0.9723,
# thumb, respect, member, society-y, :)
# neg: 0.0, neu: 0.576, pos: 0.424, compound: 0.7096,
# arthur, pendragon, must, idiot, think, women, born, evil, god, fuck, illiter, here', wrote, god, forbid, femal, could, never, born, pure, evil, back, real, world, women, born, pure, evil, moron, drool, imbecil, would, read, women, born, evil, herd, uneduc, brain, rins, illiter, useless, feeder, like, societi
# neg: 0.333, neu: 0.605, pos: 0.062, compound: -0.9845,
# jeff, bridg, funni, prove, idiot, insult, attempt, prove, worthless, worthless, person, planet, true, idiot, believ, woman, born, pure, evil, even, fail, comprehend, wrote, instead, spew, hate, illiteraci, youtub, yet, feel, sorri, never, knew, like, idiot, fact, explain, show, head, insult, peopl, call, other, moron, sign, intellig, though, fair, prove, far, well, insult, say, attempt, insult, anyon, els, prove, contradict, claim, make, intellig, superior, educ, help, sinc, resort, childish, attempt, insult, peopl, call, peopl, name, beyond, comprehend, fulli, anyon, els, wrote, write, quit, obviou, lower, even, quit, possibl, can't, redeem, qualiti, apolog, can't, help, attempt, possibl, unfortun, might, expect, repli, unless, repli, respect, way, without, use, swear, mention, write, anyth, consid, racist, demean, non, respect, manner, prove, follow, point, claim, void, due, attitud, use, childish, behavior, insult, inform, noth, help, want, right, learn, first, respect, argument, learn, also, insult, peopl, noth, remov, valid, claim, certainli, give, everyon, impress, iq, miss, point, peopl, youtub, actual, know, whether, onlin, person, talk, write, direct, represent, think, differ, onlin, person, friend, attempt, live, dual, life, never, work, best, one, two, peopl, retain
# neg: 0.166, neu: 0.742, pos: 0.091, compound: -0.9801,
# that', disrespect, fact, stupid, simpli, disagre, simpli, ever, get, tire, wrong, must, exhaust
# neg: 0.295, neu: 0.589, pos: 0.116, compound: -0.784,
# simpli, spread, hate, noth, femin, hate, pure, seeth, femal, hatr, jealousi, everyth, men, invent, built, achiev, women, achiev, noth, spend, energi, rail, imaginari, patriarchi, keep, women, iron, could, actual, use, energi, achiev, someth, life, lol, pathet, men, hate, women, except, mayb, ted, bundi, long, gone, noth, stupid, con, call, anyon, repuls, feminist, hate, misogynist, extrem, stupid, ultim, loser, woman, choos, see, beauti, worship, bodi, appar, unattract, anyon, worship, unattract, stupid, haha, lot, mental, health, issu, combin, extrem, stupid, child, birth, lead, caus, death, girl, age, fact, meanwhil, u, million, abort, sinc, greatest, holocaust, human, histori, billion, worldwid, femin, femin, murder, genocid, abort, also, reason, black, popul, stay, last, year, get, educ, fool, femin, old, dead, hippi, bullshit, hoax, dead, decad, caus, almost, societ, dysfunct, collaps, today
# neg: 0.232, neu: 0.68, pos: 0.088, compound: -0.9929,
# jeff, bridg, stupid, simplic, sake, fact, opinion, fact, matter, hard, tri, feel, sorri
# neg: 0.247, neu: 0.688, pos: 0.065, compound: -0.5083,
# jeff, bridg, well, seem, someth, wrong, life, women, shop, ´, know, thing, know, regular, day, woke, went, univers, class, iam, work, arriv, home, stuff, hous, well, great, day, shop, spend, men, ´, money, other, guilti, peopl, choic, peopl, differ, pleas, ´, say, men, good, evil, man, took, care, grandpa, alway, said, hous, place, lazzi, peopl, father, well, wasnt, nice, thing, said, men, opposit
# neg: 0.05, neu: 0.807, pos: 0.143, compound: 0.9215,
# mara, rodrigu, studi, done, show, everi, compani, everi, industri, women, real, actual, work, workplac, pay, attent, women, answer, phone, lowliest, floor, manag, job, dog, could, bark, peopl, realli, manag, meet, get, way, come, late, leav, earli, quit, altogeth, month, even, bother, fool, anyon, actual, work, except, fire, last, women, year, ago, noth, day, women, major, liber, art, fluff, graduat, worthless, trash, degre, hardli, studi, curriculum, noth, trash, realli, anyth, go, motion, tri, prove, pointless, point, might, well, stay, home, leav, go, shop, that', honest, thing, women, today, actual
# neg: 0.087, neu: 0.87, pos: 0.042, compound: -0.7274,
# realli, noth, answer, call, per, day, call-cent, noth, help, client, choos, better, way, save, money, noth, explain, someon, invoic, noth, tri, talk, someon, near, cri, babi, noth, job, account, offic, remind, client, pay, tax, even, energi, invoic, also, prepar, document, help, other, document, month, prepar, payment, worker, small, compani, also, answer, call, go, bank, visit, client, realli, noth, realli, ´, deserv, great, salari, per, month
# neg: 0.034, neu: 0.833, pos: 0.133, compound: 0.9217,
# jeff, bridg, sourc
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# ...
# msthesuitelif, true, villain, say, go, kill, someon, plain, word
# neg: 0.295, neu: 0.605, pos: 0.1, compound: -0.7579,
# anaya, lol, yeah, badass, better, scar
# neg: 0.119, neu: 0.296, pos: 0.585, compound: 0.743,
# msthesuitelif, ok, ok, gave, first, place, let', push
# neg: 0.0, neu: 0.694, pos: 0.306, compound: 0.5267,
# final, someon, agre, cgi, hit, prime, make, movi, scar, show, fuck, shit, happen
# neg: 0.237, neu: 0.71, pos: 0.053, compound: -0.802,
# loki
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# clair, mccrori, suck
# neg: 0.492, neu: 0.508, pos: 0.0, compound: -0.4404,
# favorit, disney, villain, horn, king, black, cauldron
# neg: 0.217, neu: 0.602, pos: 0.181, compound: -0.1531,
# thano
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# frollo, evil, villain, one, favorit
# neg: 0.426, neu: 0.426, pos: 0.149, compound: -0.7351,
# pixar, movi, count, gotta, lots-o'-huggin, bear
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# disney, go, rout, adapt, film, live-act, retel, villain, perspect, love, see, make, great, greek, epic, hade, involv, myth, god, came, power, even, ursula, stori, felt, back-stori, alway, pretti, vagu, also, love, see, underwat, effect, know, disney, alreadi, consid, cruella, devil, movi, somehow, think, kind, stori, would, work, sinc, motiv, alreadi, explor, reason, well
# neg: 0.064, neu: 0.815, pos: 0.121, compound: 0.7096,
# judg, frollo
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# alright, saw, screen, last, night, can't, hold, longer, disney, lost, ball, malefic, cri, loud, mistress, evil, jeremi, right, almost, like, way, shoot, movi, director, look, script, realiz, princ, philip, nowher, found, panick, quick, need, princ, ye, cater, truck, get
# neg: 0.152, neu: 0.764, pos: 0.083, compound: -0.8089,
# scar, pretti, sure, villain, disney, anim, film, actual, kill, someon, long, live, king
# neg: 0.279, neu: 0.537, pos: 0.185, compound: -0.5859,
# frollo, hunchback, notr, dame, kill, quasimodo', mother, start, crusad, look, esmeralda, burn, pari, process, also, want, extermin, gypsi, name, god
# neg: 0.116, neu: 0.797, pos: 0.087, compound: -0.4767,
# professor, ratigan, kill, two, charact, great, mous, detect, bartholomew, fidget
# neg: 0.199, neu: 0.619, pos: 0.181, compound: -0.1027,
# william, scar, lion, think, lion, get, pride, overthrow, curent, male, lion, leader, man, kill, bambi', mother, evil, queen, kill, snow, white, brought, back, still, murder, malefic, attempt, kill, aurora, cruella, want, kill, puppi, make, coat, shere, khan, tri, kill, mowgli.gaston, attempt, kill, beast, jafar, attempt, kill, jasmin, aladdin, sever, time, frollo, essenti, tri, kill, gypsi, succeed, kill, mani, hade, kill, meg, kill, make, btter, villain, someon, tri, kill
# neg: 0.452, neu: 0.526, pos: 0.022, compound: -0.998,
# total, scar, lion, king, long, live, king
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# mind, busi
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# top
# neg: 0.0, neu: 0.625, pos: 0.375, compound: 0.2023,
# scar, jafar
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# movi, look, pretti, interest, differ, trailer, know, quit, averag, meh, want, see, :/
# neg: 0.223, neu: 0.637, pos: 0.14, compound: -0.3293,
# favorit, disney, villain, scar
# neg: 0.419, neu: 0.233, pos: 0.349, compound: -0.1531,
# probabl, scar, malefic
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# awesom
# neg: 0.0, neu: 0.0, pos: 1.0, compound: 0.6588,
# scar, son, bitch, rest, peac, mufasa, young
# neg: 0.238, neu: 0.578, pos: 0.184, compound: -0.2577,
# fave, disney, villain, scar, lion, king, say, ultim, thing, murder, flesh, blood, ruler, kingdom, tell, nephew, fault, mufasa, die, also, fact, wreck, prideland, respect, circl, life, keep, everyth, balanc, say, scar, fave, villain, coolest, villain, ever, go, far, evil
# neg: 0.268, neu: 0.678, pos: 0.055, compound: -0.9739,
# well, sinc, disney, own, star, war, im, gonna, say, darth, vader, fav
# neg: 0.174, neu: 0.58, pos: 0.246, compound: 0.128,
# scar, cours
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# scar, lion, king, hook, peter, pan
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# probabl, yu, mulan, guy, soooo, menac
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# frollo
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# favourit, villain, definit, scar, :p, nice, kind, way, lol
# neg: 0.208, neu: 0.49, pos: 0.302, compound: 0.4021,
# malefic, favorit, disney, movi, kingdom, heart, hope, movi, ruin
# neg: 0.0, neu: 0.609, pos: 0.391, compound: 0.839,
# scar, awesom
# neg: 0.0, neu: 0.328, pos: 0.672, compound: 0.6249,
# hade, hercul
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# barbossa, count
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# wait, peopl, actual, give, fuck, movi, lol
# neg: 0.263, neu: 0.526, pos: 0.211, compound: -0.1779,
# ade
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# argh, thought, go, someth, unexpect, stori, sinc, villain, point, view, pg, disney, can't, someth, would, scare, kid, shitless, bummer, said, scar, shere, khan, favorit, villain, watch, classic, disney, movi, age, one, rememb, scar, mufasa', brother, mean, realli, evil, will, kill, blood, close, relationship, sibl, alway, avoid, dick, older, brother, scare, crack, joke, everi, even, though, power, hungri, lunat, lion, shere, khan, seem, like, funni, lad, afraid, mowgli, realli, harm, anybodi, els, afraid, human, right, terribl, thing, anim, harm, anim, eat, surviv
# neg: 0.248, neu: 0.672, pos: 0.079, compound: -0.9916,
# go, cinderella, oh, god, good, question, like, frollo, scar, ursula, hade, izma, ratigan, mother, gothel, love, what', disney, without, villain
# neg: 0.0, neu: 0.607, pos: 0.393, compound: 0.9383,
# yep, offici, disney, lost, ball
# neg: 0.242, neu: 0.526, pos: 0.232, compound: -0.0258,
# well, mean, technic, darth, vader, disney, villain, go
# neg: 0.183, neu: 0.711, pos: 0.107, compound: -0.3612,
# favorit, villain, scar, question, ask
# neg: 0.216, neu: 0.49, pos: 0.294, compound: 0.2023,
# frollo
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# gloofi, sympathi, quasimodo, scar, kill, brother, attempt, kill, nephew, jealou
# neg: 0.46, neu: 0.492, pos: 0.048, compound: -0.9587,
# nice, review, jeremi, angelina, joli, pitch-perfect, casting-wis, there', someth, cgi-mess, look, movi, turn, remind, burton', alic, wonderland, that', someth, one, want, remind
# neg: 0.066, neu: 0.89, pos: 0.044, compound: -0.2263,
# magic, gather, game, throne, refer, one, review
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# pete, best, villain, worst
# neg: 0.484, neu: 0.252, pos: 0.264, compound: -0.5423,
# scar, han
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# jafar, scar, love
# neg: 0.0, neu: 0.488, pos: 0.512, compound: 0.6369,
# scar, question, littl, fucker, kind, love
# neg: 0.191, neu: 0.559, pos: 0.25, compound: 0.5035,
# syndrom
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# turbo, wreck, ralph, guy, evil, took, children', race, game, dame
# neg: 0.146, neu: 0.854, pos: 0.0, compound: -0.4404,
# jeremi, know, nicol, bola, unsubscrib, resubscrib
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# magnific, alway, favorit, disney, villain, love, turn, dragon, outfit, ever, sinc, kid, main, thing, like, although, han, frozen, still, giant, dick, lol
# neg: 0.131, neu: 0.551, pos: 0.317, compound: 0.8689,
# scar, lion, king
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# scar, asshol
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# favorit, disney, villain, frollo, one, sick, bastard, charact, good, game, throne
# neg: 0.288, neu: 0.526, pos: 0.187, compound: -0.566,
# definit, best
# neg: 0.0, neu: 0.127, pos: 0.873, compound: 0.7845,
# favourit, king, candi, wreck, ralph, goofi, ass, bastard
# neg: 0.553, neu: 0.447, pos: 0.0, compound: -0.872,
# frollo, hunchback, notr, dame
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# everyon, keep, put, scar, frollo, much, love, . ..., hate
# neg: 0.2, neu: 0.554, pos: 0.246, compound: 0.2886,
# yep, get, wrong, love, scar, well, frollo, take, cake
# neg: 0.0, neu: 0.559, pos: 0.441, compound: 0.7714,
# mother, natur, happen, dumb, forc, need, take, care, earth, mean, might, well, made, kid
# neg: 0.119, neu: 0.732, pos: 0.149, compound: 0.0152,
# can't, wait, jj', review, edg, tomorrow, saw, trailer, xmen, dofp, thought, look, badass
# neg: 0.071, neu: 0.929, pos: 0.0, compound: -0.1531,
# check, shmoe, know, review, appar, great, movi, also, frick, rotten, tomato, know, there', lot, review, yet, holi, shit, that, dark, knight, ..
# neg: 0.172, neu: 0.767, pos: 0.061, compound: -0.684,
# judg, trailer, think, one, gonna, awesom, kittywarrior, trailer, sucker, punch, made, believ, go, best, movi, ever, made, haha, guess, see, eot', fate, soon, enough
# neg: 0.066, neu: 0.716, pos: 0.219, compound: 0.836,
# hade, flawless
# neg: 0.0, neu: 0.377, pos: 0.623, compound: 0.5106,
# make, claud, frodo, movi, charact, follow, victor, hugo, stori
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# frollo
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# oh, god, ye
# neg: 0.0, neu: 0.294, pos: 0.706, compound: 0.5859,
# hade, hand
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# jeremi, best, movi, review, ever, listen, keep, buddi, everi, movi, review, agre, opinion
# neg: 0.0, neu: 0.758, pos: 0.242, compound: 0.7717,
# lol, what', point, keep, movi, review, everyth, say, defeat, whole, point
# neg: 0.088, neu: 0.805, pos: 0.107, compound: 0.128,
# rememb, min, sex, scene
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# scar, lion, king
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# would, peopl, think, see, jeremi, movi, theatr, watch, kind, film, xd
# neg: 0.0, neu: 0.817, pos: 0.183, compound: 0.5859,
# thrax
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# gotta, say, corella, crazi, anim, killer
# neg: 0.626, neu: 0.374, pos: 0.0, compound: -0.7717,
# oh, get, sleep, that', like, everi, teenag, dream, xd
# neg: 0.109, neu: 0.544, pos: 0.348, compound: 0.7034,
# long, john, silver
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# malefic, awesom, kingdom, heart, game
# neg: 0.0, neu: 0.631, pos: 0.369, compound: 0.6249,
# thu, favorit, disney, villain, xd
# neg: 0.207, neu: 0.402, pos: 0.391, compound: 0.4939,
# gaston, captain, hook
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# watch, hope, wont, make, good, like, right, evil
# neg: 0.216, neu: 0.532, pos: 0.252, compound: 0.0,
# walk, movi, hour, min, good, first, minut
# neg: 0.112, neu: 0.888, pos: 0.0, compound: -0.3412,
# boob
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# chernobog
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# scar
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# know, play, magic, also, nicol, bola, head, cannot, unseen, thank, jeremi
# neg: 0.106, neu: 0.728, pos: 0.166, compound: 0.286,
# film, actual, pretti, good, realli, like, differ, yeah, differ, good, sometim, :)
# neg: 0.0, neu: 0.414, pos: 0.586, compound: 0.9266,
# love, x, men, spoiler, talk, love, vid, rock
# neg: 0.0, neu: 0.519, pos: 0.481, compound: 0.8825,
# mean, get, loki, movi, think
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# plz, watch
# neg: 0.0, neu: 0.606, pos: 0.394, compound: 0.0772,
# also, make, spidey, fan, film, come, week
# neg: 0.0, neu: 0.813, pos: 0.187, compound: 0.3182,
# plz, make, reweiv, krish, bollywood, film, pleas, beg, you.you, would, understand, it.it, subtitl, eng.just, see, trailer, plz
# neg: 0.0, neu: 0.803, pos: 0.197, compound: 0.4404,
# actual, line, sun, set, sixteenth, birthday, prick, finger, spindl, spin, wheel, fall, sleep, like, death
# neg: 0.069, neu: 0.805, pos: 0.126, compound: 0.459,
# thought, death, fairi, chang, sleep
# neg: 0.159, neu: 0.841, pos: 0.0, compound: -0.3506,
# tak, go, trailer, seen, movi
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# well, given, origin, stori, intend, child, die, fairi, abl, lessen, curs, etern, sleep, still, bad
# neg: 0.182, neu: 0.734, pos: 0.084, compound: -0.5789,
# tak, origin, yeah, america, chang
# neg: 0.0, neu: 0.789, pos: 0.211, compound: 0.1531,
# either, way, make, bit, joke
# neg: 0.0, neu: 0.784, pos: 0.216, compound: 0.296,
# still, copout, though
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# angelina, say, death, like, sleep, actual, still, copout
# neg: 0.315, neu: 0.484, pos: 0.202, compound: -0.34,
# jack, drewitt, say, death, origin, disney, cartoon, actual, look, stuff, claim, someth, total, true
# neg: 0.154, neu: 0.672, pos: 0.174, compound: 0.162,
# jeremi, plz, subscrib, plz
# neg: 0.0, neu: 0.606, pos: 0.394, compound: 0.1531,
# shut
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# wtf, even, video, subscrib
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# know, ask, peopl, subscrib, would, nice, oh, know, get, channel, upload, content
# neg: 0.0, neu: 0.891, pos: 0.109, compound: 0.4215,
# hell, would, anyon, subscrib, channel, video
# neg: 0.247, neu: 0.753, pos: 0.0, compound: -0.6808,
# thought, whore, post, twilight, princess, walkthrough, legend, zelda, page, even, video
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# like, post, genuin, entertain, content, form, video, relat, content, share, ya, know
# neg: 0.0, neu: 0.647, pos: 0.353, compound: 0.802,
# love, entertain, peopl, play, video, game, xd
# neg: 0.0, neu: 0.321, pos: 0.679, compound: 0.9136,
# bolt, shut
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# pmsl, anim, live, action, comparison, true
# neg: 0.0, neu: 0.721, pos: 0.279, compound: 0.4754,
# njaaaaaaa
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# ..
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# jeremi, plz, make, reweiv, spider, man, plz
# neg: 0.0, neu: 0.698, pos: 0.302, compound: 0.1531,
# fuck
# neg: 1.0, neu: 0.0, pos: 0.0, compound: -0.5423,
# thought, actual, one, best, movi, along, x, men, day, futur, past, captain, america
# neg: 0.0, neu: 0.833, pos: 0.167, compound: 0.6369,
# saw, x-men, yesterday, pretti, sweet, although, spoiler, apocalyps, look, like
# neg: 0.0, neu: 0.58, pos: 0.42, compound: 0.8271,
# cant, see, close, x-men, pure, epic
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# acjub
# neg: 0.423, neu: 0.577, pos: 0.0, compound: -0.296,
# apocalyps, next, movi
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# bradley, cude, doubt, film, better, x-men, year, honest
# neg: 0.121, neu: 0.58, pos: 0.3, compound: 0.5719,
# say, best, movi, simpli, say, alon, thought, one, best, movi, year, differ, :p
# neg: 0.0, neu: 0.714, pos: 0.286, compound: 0.8957,
# forget, lego, movi
# neg: 0.0, neu: 0.75, pos: 0.25, compound: 0.1695,
# bradley, cude, worst, attempt, spoil, someth, good, god
# neg: 0.417, neu: 0.449, pos: 0.135, compound: -0.6604,
# tri, spoil
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# bradley, cude, make, douch, put, spoiler
# neg: 0.185, neu: 0.815, pos: 0.0, compound: -0.3612,
# bradley, cude, worri, bryan, singer, ain't, keep, apocalyps, apocalyps, young, get, better, one, next, movi
# neg: 0.0, neu: 0.806, pos: 0.194, compound: 0.6492,
# watch, edg, tomorrow, worth
# neg: 0.0, neu: 0.826, pos: 0.174, compound: 0.2263,
# realli, worth, wanna, see, sure
# neg: 0.174, neu: 0.712, pos: 0.114, compound: -0.2135,
# epikercov, total, best, action, film, seen, year, best, concept, origin, stori, year, ..
# neg: 0.0, neu: 0.572, pos: 0.428, compound: 0.9048,
# theadarsh, origin, aktual, inspiret, japaneas, novel, sooo, yeah, .., manga, sorri, bad, english
# neg: 0.142, neu: 0.769, pos: 0.089, compound: -0.3182,
# shayan, khan, yeah, meant, origin, shitti, movi, spew, hollywood, everyth, base, someth, nowaday, .., biographi, book, tv, show, event, histori, comic, etc, oscar, nomin, film, base, adapt
# neg: 0.069, neu: 0.845, pos: 0.086, compound: -0.0258,
# theadarsh, ﻿, aahh, understand, :-d
# neg: 0.0, neu: 0.464, pos: 0.536, compound: 0.6825,
# theadarsh, care, long, final, product, good, valuabl, motion, pictur, realli, matter, sourc, materi
# neg: 0.041, neu: 0.64, pos: 0.32, compound: 0.9095,
# idea, say, intro, jeremi
# neg: 0.196, neu: 0.804, pos: 0.0, compound: -0.296,
# first, minut, movi, better, fall, grace, due, botch, love, entireti, star, war, prequel, could, gotta, like, someth, like
# neg: 0.083, neu: 0.575, pos: 0.343, compound: 0.8834,
# thank, usual, keep, jeremi, super, fast
# neg: 0.0, neu: 0.612, pos: 0.388, compound: 0.8221,
# first
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,

# %% [markdown]
# # Sentiment plot for Vader Approach

# %%
# Get it into a pandas data frame structure 
vaderSeries = pd.DataFrame(vaderSentiment, columns=['date', 'neg', 'neu', 'pos', 'compound'])

# Tell pandas that the column is the one we use for indexing (or x-axis)
vaderSeries.set_index('date', inplace=True)

# Set the compound coulumn to floats
vaderSeries[['compound']] = vaderSeries[['compound']].apply(pd.to_numeric)

nVaderSeries = vaderSeries.resample('24h').sum() # score ranging from -1 (negative) to +1 (positive), so apply mean()

# Plot overall compound sentiment
plt.figure(figsize=(10, 7))
plt.plot(nVaderSeries['compound'], color='slateblue') 
plt.title("Vader Approach Sentiment per Day",fontsize=15)
plt.ylabel("Semtiment (Vader Appraoch)",fontsize=13)
plt.xlabel("Date", fontsize=13)
plt.show()

# %%
# Total no. of overall Positive, Neutral and Negative in vaderSeries
pos_count = (vaderSeries['compound'] > 0).sum()
neu_count = (vaderSeries['compound'] == 0).sum()
neg_count = (vaderSeries['compound'] < 0).sum()

VaderCount = {
    'Positive': pos_count,
    'Neutral': neu_count,
    'Negative': neg_count
}
VaderCount
# Out:
# {'Positive': 6328, 'Neutral': 3585, 'Negative': 3137}

# %%
# Plot the overall sentiment counts
plt.figure(figsize=(10, 7))
plt.bar(VaderCount.keys(), VaderCount.values(), color=['crimson', 'seagreen', 'royalblue'])
plt.title("Vader Approach Sentiment Counts of Maleficent Movie on YouTube",fontsize=15)
plt.ylabel("Counts",fontsize=13)
plt.xlabel("Sentiment", fontsize=13)
plt.show()

# calculate the average sentiment score
average_sentiment = vaderSeries['compound'].mean()
print("Average Sentiment Score of Maleficent Movie on YouTube: ", average_sentiment)
# Out:
# Average Sentiment Score of Maleficent Movie on YouTube:  0.15603853639846743

# %%
nVaderSeries = vaderSeries.resample('12h').sum()

# Create a figure and a set of subplots (3 rows, 1 column)
fig, axes = plt.subplots(nrows=3, ncols=1, figsize=(10, 6), sharex=True)
fig.suptitle('Vader Approach Sentiment of Maleficent Movie on Youtube per 12 Hours', fontsize=14)

# Plot: Negative Score
axes[0].plot(nVaderSeries['neg'], color='royalblue', label='Negative')
axes[0].set_ylabel('Negative Score')
axes[0].legend()
axes[0].grid(True)

# Plot: Neutral Score
axes[1].plot(nVaderSeries['neu'], color='seagreen', label='Neutral')
axes[1].set_ylabel('Neutral Score')
axes[1].legend()
axes[1].grid(True)

# Plot: Positive Score
axes[2].plot(nVaderSeries['pos'], color='crimson', label='Positive')
axes[2].set_ylabel('Positive Score')
axes[2].legend()
axes[2].grid(True)
axes[2].set_xlabel('Date')

plt.tight_layout(rect=[0, -0.1, 1, 1])
plt.show()
