# %%
import json
import os
import re
from yt_dlp import YoutubeDL

# To extract YouTube video ID from URL
def extract_video_id(url):
    m = re.search(r"v=([^&]+)", url)
    if m:
        return m.group(1)
    m = re.search(r"youtu\.be/([^?&]+)", url)
    if m:
        return m.group(1)
    return None

# Sanitize titles for filenames
def sanitize_filename(name):
    return re.sub(r"[\\\\/:*?\"<>|]", "_", name)

# Load video URLs from JSON search results
def load_video_urls(path):
    with open(path, "r", encoding="utf-8") as f:
        data = json.load(f)
    return [item.get("link") for item in data if item.get("link")]

# Build parent-reply hierarchy in comments
def structure_comments(comments):
    cmap = {c['id']: c for c in comments if c.get('id')}
    roots = []
    for c in comments:
        pid = c.get('parent_id')
        if pid and pid in cmap:
            cmap[pid].setdefault('replies', []).append(c)
        else:
            roots.append(c)
    return roots


def main():
    # Ensure output directory exists
    os.makedirs("output", exist_ok=True)

    # Read URLs
    urls = load_video_urls('videossearch-aliceinwonderland.json')

    for url in urls:
        vid = extract_video_id(url)
        if not vid:
            print(f"Invalid URL skipped: {url}")
            continue
        video_url = f"https://www.youtube.com/watch?v={vid}"

        # Scrape metadata + comments
        ydl_opts = {"getcomments": True}
        with YoutubeDL(ydl_opts) as ydl:
            info = ydl.extract_info(video_url, download=False)

        # Meta fields
        meta = {
            "Title": info.get("title"),
            "Description": info.get("description"),
            "Uploader": info.get("uploader"),
            "View Count": info.get("view_count"),
            "Likes": info.get("like_count"),
            "Dislikes": info.get("dislike_count"),
            "Thumbnail": info.get("thumbnail"),
            "Tags": info.get("tags"),
        }

        # Process comments
        raw = info.get("comments") or []
        comments = []
        for c in raw:
            comments.append({
                "id": c.get("id"),
                "parent_id": c.get("parent"),
                "author": c.get("author"),
                "text": c.get("text"),
                "timestamp": c.get("timestamp"),
            })
        structured = structure_comments(comments)
        meta["Comments"] = structured

        # Statistics
        top_comments = len(structured)
        replies = sum(len(c.get("replies", [])) for c in structured)
        unique_authors = len({c.get("author") for c in comments if c.get("author")})

        # Save JSON
        title_safe = sanitize_filename(info.get("title", vid))
        outfile = os.path.join("output", f"{title_safe}_{vid}.json")
        with open(outfile, "w", encoding="utf-8") as fout:
            json.dump(meta, fout, ensure_ascii=False, indent=2)

        print(f"{outfile}: {top_comments} comments, {replies} replies, {unique_authors} unique authors")

if __name__ == '__main__':
    main()
# Out:
# [youtube] Extracting URL: https://www.youtube.com/watch?v=9POCgSRVvf0
# [youtube] 9POCgSRVvf0: Downloading webpage
# [youtube] 9POCgSRVvf0: Downloading tv client config
# [youtube] 9POCgSRVvf0: Downloading tv player API JSON
# [youtube] 9POCgSRVvf0: Downloading ios player API JSON
# [youtube] 9POCgSRVvf0: Downloading m3u8 information
# [youtube] Downloading comment section API JSON
# [youtube] Downloading ~1412 comments
# [youtube] Sorting comments by newest first
# [youtube] Downloading comment API JSON page 1 (0/~1412)
# [youtube] Downloading comment API JSON page 2 (20/~1412)
# [youtube] Downloading comment API JSON page 3 (40/~1412)
# [youtube] Downloading comment API JSON page 4 (60/~1412)
# [youtube] Downloading comment API JSON page 5 (80/~1412)
# [youtube] Downloading comment API JSON page 6 (100/~1412)
# [youtube] Downloading comment API JSON page 7 (120/~1412)
# [youtube] Downloading comment API JSON page 8 (140/~1412)
# [youtube] Downloading comment API JSON page 9 (159/~1412)
# [youtube] Downloading comment API JSON page 10 (179/~1412)
# [youtube] Downloading comment API JSON page 11 (199/~1412)
# [youtube] Downloading comment API JSON page 12 (219/~1412)
# [youtube] Downloading comment API JSON page 13 (239/~1412)
# [youtube] Downloading comment API JSON page 14 (259/~1412)
# [youtube] Downloading comment API JSON page 15 (279/~1412)
# [youtube] Downloading comment API JSON page 16 (299/~1412)
# [youtube] Downloading comment API JSON page 17 (319/~1412)
# [youtube] Downloading comment API JSON page 18 (339/~1412)
# [youtube] Downloading comment API JSON page 19 (359/~1412)
# [youtube] Downloading comment API JSON page 20 (379/~1412)
# [youtube] Downloading comment API JSON page 21 (399/~1412)
# [youtube] Downloading comment API JSON page 22 (419/~1412)
# [youtube] Downloading comment API JSON page 23 (439/~1412)
# [youtube] Downloading comment API JSON page 24 (459/~1412)
# [youtube] Downloading comment API JSON page 25 (479/~1412)
# [youtube] Downloading comment API JSON page 26 (499/~1412)
# [youtube] Downloading comment API JSON page 27 (519/~1412)
# [youtube] Downloading comment API JSON page 28 (539/~1412)
# [youtube] Downloading comment API JSON page 29 (559/~1412)
# [youtube] Downloading comment API JSON page 30 (579/~1412)
# [youtube] Downloading comment API JSON page 31 (599/~1412)
# [youtube] Downloading comment API JSON page 32 (619/~1412)
# [youtube] Downloading comment API JSON page 33 (639/~1412)
# [youtube] Downloading comment API JSON page 34 (659/~1412)
# [youtube] Downloading comment API JSON page 35 (679/~1412)
# [youtube] Downloading comment API JSON page 36 (699/~1412)
# [youtube] Downloading comment API JSON page 37 (719/~1412)
# [youtube] Downloading comment API JSON page 38 (739/~1412)
# [youtube] Downloading comment API JSON page 39 (759/~1412)
# WARNING: [youtube] Incomplete data received. Retrying (1/3)...
# [youtube] Downloading comment API JSON page 39 (759/~1412)
# [youtube] Downloading comment API JSON page 40 (779/~1412)
# [youtube] Downloading comment API JSON page 41 (799/~1412)
# [youtube] Downloading comment API JSON page 42 (819/~1412)
# [youtube] Downloading comment API JSON page 43 (839/~1412)
# [youtube] Downloading comment API JSON page 44 (859/~1412)
# [youtube] Downloading comment API JSON page 45 (879/~1412)
# [youtube] Downloading comment API JSON page 46 (899/~1412)
# [youtube] Downloading comment API JSON page 47 (919/~1412)
# [youtube] Downloading comment API JSON page 48 (939/~1412)
# [youtube] Downloading comment API JSON page 49 (959/~1412)
# [youtube] Downloading comment API JSON page 50 (979/~1412)
# [youtube] Downloading comment API JSON page 51 (999/~1412)
# [youtube] Downloading comment API JSON page 52 (1019/~1412)
# [youtube] Downloading comment API JSON page 53 (1039/~1412)
# [youtube] Downloading comment API JSON page 54 (1059/~1412)
# [youtube] Downloading comment API JSON page 55 (1079/~1412)
# [youtube] Downloading comment API JSON page 56 (1099/~1412)
# [youtube] Downloading comment API JSON page 57 (1119/~1412)
# [youtube] Downloading comment API JSON page 58 (1139/~1412)
# [youtube] Downloading comment API JSON page 59 (1159/~1412)
# [youtube] Downloading comment API JSON page 60 (1179/~1412)
# [youtube] Downloading comment API JSON page 61 (1199/~1412)
# [youtube] Downloading comment API JSON page 62 (1219/~1412)
# [youtube] Downloading comment API JSON page 63 (1239/~1412)
# [youtube] Downloading comment API JSON page 64 (1259/~1412)
# [youtube] Downloading comment API JSON page 65 (1279/~1412)
# [youtube] Downloading comment API JSON page 66 (1299/~1412)
# [youtube] Downloading comment API JSON page 67 (1319/~1412)
# [youtube] Downloading comment API JSON page 68 (1339/~1412)
# [youtube] Downloading comment API JSON page 69 (1359/~1412)
# [youtube] Downloading comment API JSON page 70 (1379/~1412)
# [youtube] Downloading comment API JSON page 71 (1399/~1412)
# [youtube] Extracted 1411 comments
# output/ALICE IN WONDERLAND _ New Official Full Trailer (HQ) _ Official Disney UK_9POCgSRVvf0.json: 1411 comments, 0 replies, 1269 unique authors
# [youtube] Extracting URL: https://www.youtube.com/watch?v=EWH_XT6yXv8
# [youtube] EWH_XT6yXv8: Downloading webpage
# [youtube] EWH_XT6yXv8: Downloading tv client config
# [youtube] EWH_XT6yXv8: Downloading tv player API JSON
# [youtube] EWH_XT6yXv8: Downloading ios player API JSON
# [youtube] EWH_XT6yXv8: Downloading m3u8 information
# [youtube] Downloading comment section API JSON
# [youtube] Downloading ~4553 comments
# [youtube] Sorting comments by newest first
# [youtube] Downloading comment API JSON page 1 (0/~4553)
# [youtube] Downloading comment API JSON page 2 (20/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (21/~4553)
# [youtube] Downloading comment API JSON page 3 (42/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (51/~4553)
# [youtube]     Downloading comment API JSON reply thread 2 (60/~4553)
# [youtube]     Downloading comment API JSON reply thread 3 (63/~4553)
# [youtube] Downloading comment API JSON page 4 (65/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (72/~4553)
# [youtube]     Downloading comment API JSON reply thread 2 (87/~4553)
# [youtube] Downloading comment API JSON page 5 (88/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (90/~4553)
# [youtube] Downloading comment API JSON page 6 (109/~4553)
# [youtube] Downloading comment API JSON page 7 (129/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (141/~4553)
# [youtube] Downloading comment API JSON page 8 (152/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (155/~4553)
# [youtube] Downloading comment API JSON page 9 (173/~4553)
# [youtube] Downloading comment API JSON page 10 (193/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (204/~4553)
# [youtube] Downloading comment API JSON page 11 (215/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (216/~4553)
# [youtube] Downloading comment API JSON page 12 (236/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (240/~4553)
# [youtube] Downloading comment API JSON page 13 (257/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (259/~4553)
# [youtube]     Downloading comment API JSON reply thread 2 (277/~4553)
# [youtube] Downloading comment API JSON page 14 (280/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (298/~4553)
# [youtube] Downloading comment API JSON page 15 (301/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (302/~4553)
# [youtube]     Downloading comment API JSON reply thread 2 (306/~4553)
# [youtube]     Downloading comment API JSON reply thread 3 (308/~4553)
# [youtube]        Downloading comment replies API JSON page 1 (318/~4553)
# [youtube]     Downloading comment API JSON reply thread 4 (324/~4553)
# [youtube]     Downloading comment API JSON reply thread 5 (343/~4553)
# [youtube] Downloading comment API JSON page 16 (344/~4553)
# [youtube] Downloading comment API JSON page 17 (364/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (366/~4553)
# [youtube]     Downloading comment API JSON reply thread 2 (370/~4553)
# [youtube]     Downloading comment API JSON reply thread 3 (380/~4553)
# [youtube] Downloading comment API JSON page 18 (389/~4553)
# [youtube] Downloading comment API JSON page 19 (409/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (415/~4553)
# [youtube] Downloading comment API JSON page 20 (430/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (432/~4553)
# [youtube]        Downloading comment replies API JSON page 1 (442/~4553)
# [youtube]     Downloading comment API JSON reply thread 2 (458/~4553)
# [youtube]     Downloading comment API JSON reply thread 3 (463/~4553)
# [youtube] Downloading comment API JSON page 21 (476/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (484/~4553)
# [youtube] Downloading comment API JSON page 22 (497/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (510/~4553)
# [youtube]     Downloading comment API JSON reply thread 2 (515/~4553)
# [youtube] Downloading comment API JSON page 23 (522/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (535/~4553)
# [youtube] Downloading comment API JSON page 24 (546/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (565/~4553)
# [youtube] Downloading comment API JSON page 25 (567/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (581/~4553)
# [youtube]     Downloading comment API JSON reply thread 2 (583/~4553)
# [youtube] Downloading comment API JSON page 26 (589/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (597/~4553)
# [youtube]     Downloading comment API JSON reply thread 2 (603/~4553)
# [youtube]     Downloading comment API JSON reply thread 3 (605/~4553)
# [youtube]     Downloading comment API JSON reply thread 4 (609/~4553)
# [youtube] Downloading comment API JSON page 27 (614/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (621/~4553)
# [youtube]     Downloading comment API JSON reply thread 2 (626/~4553)
# [youtube] Downloading comment API JSON page 28 (636/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (649/~4553)
# [youtube] Downloading comment API JSON page 29 (659/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (672/~4553)
# [youtube]     Downloading comment API JSON reply thread 2 (680/~4553)
# [youtube] Downloading comment API JSON page 30 (683/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (687/~4553)
# [youtube]     Downloading comment API JSON reply thread 2 (693/~4553)
# [youtube] Downloading comment API JSON page 31 (705/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (719/~4553)
# [youtube] Downloading comment API JSON page 32 (726/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (729/~4553)
# [youtube]     Downloading comment API JSON reply thread 2 (748/~4553)
# [youtube]     Downloading comment API JSON reply thread 3 (750/~4553)
# [youtube] Downloading comment API JSON page 33 (751/~4553)
# [youtube] Downloading comment API JSON page 34 (771/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (776/~4553)
# [youtube] Downloading comment API JSON page 35 (793/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (799/~4553)
# [youtube]     Downloading comment API JSON reply thread 2 (806/~4553)
# [youtube] Downloading comment API JSON page 36 (815/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (819/~4553)
# [youtube]     Downloading comment API JSON reply thread 2 (829/~4553)
# [youtube]     Downloading comment API JSON reply thread 3 (835/~4553)
# [youtube] Downloading comment API JSON page 37 (845/~4553)
# [youtube] Downloading comment API JSON page 38 (865/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (875/~4553)
# [youtube] Downloading comment API JSON page 39 (886/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (891/~4553)
# [youtube] Downloading comment API JSON page 40 (907/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (911/~4553)
# [youtube]     Downloading comment API JSON reply thread 2 (913/~4553)
# [youtube]     Downloading comment API JSON reply thread 3 (915/~4553)
# [youtube]     Downloading comment API JSON reply thread 4 (928/~4553)
# [youtube]     Downloading comment API JSON reply thread 5 (930/~4553)
# [youtube]     Downloading comment API JSON reply thread 6 (937/~4553)
# [youtube] Downloading comment API JSON page 41 (942/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (948/~4553)
# [youtube]     Downloading comment API JSON reply thread 2 (952/~4553)
# [youtube]     Downloading comment API JSON reply thread 3 (965/~4553)
# [youtube] Downloading comment API JSON page 42 (968/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (969/~4553)
# [youtube]     Downloading comment API JSON reply thread 2 (992/~4553)
# [youtube]     Downloading comment API JSON reply thread 3 (1000/~4553)
# [youtube] Downloading comment API JSON page 43 (1008/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (1011/~4553)
# [youtube]     Downloading comment API JSON reply thread 2 (1017/~4553)
# [youtube] Downloading comment API JSON page 44 (1031/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (1034/~4553)
# [youtube]     Downloading comment API JSON reply thread 2 (1042/~4553)
# [youtube]        Downloading comment replies API JSON page 1 (1052/~4553)
# [youtube]     Downloading comment API JSON reply thread 3 (1071/~4553)
# [youtube] Downloading comment API JSON page 45 (1081/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (1091/~4553)
# [youtube]     Downloading comment API JSON reply thread 2 (1094/~4553)
# [youtube]     Downloading comment API JSON reply thread 3 (1096/~4553)
# [youtube]     Downloading comment API JSON reply thread 4 (1101/~4553)
# [youtube] Downloading comment API JSON page 46 (1106/~4553)
# [youtube] Downloading comment API JSON page 47 (1126/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (1138/~4553)
# [youtube]     Downloading comment API JSON reply thread 2 (1147/~4553)
# [youtube] Downloading comment API JSON page 48 (1150/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (1152/~4553)
# [youtube]     Downloading comment API JSON reply thread 2 (1159/~4553)
# [youtube]     Downloading comment API JSON reply thread 3 (1163/~4553)
# [youtube]     Downloading comment API JSON reply thread 4 (1168/~4553)
# [youtube] Downloading comment API JSON page 49 (1175/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (1182/~4553)
# [youtube] Downloading comment API JSON page 50 (1196/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (1207/~4553)
# [youtube]        Downloading comment replies API JSON page 1 (1217/~4553)
# [youtube]     Downloading comment API JSON reply thread 2 (1225/~4553)
# [youtube] Downloading comment API JSON page 51 (1233/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (1243/~4553)
# [youtube]     Downloading comment API JSON reply thread 2 (1252/~4553)
# [youtube] Downloading comment API JSON page 52 (1257/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (1269/~4553)
# [youtube] Downloading comment API JSON page 53 (1278/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (1283/~4553)
# [youtube]     Downloading comment API JSON reply thread 2 (1286/~4553)
# [youtube]     Downloading comment API JSON reply thread 3 (1289/~4553)
# [youtube] Downloading comment API JSON page 54 (1301/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (1303/~4553)
# [youtube]     Downloading comment API JSON reply thread 2 (1321/~4553)
# [youtube] Downloading comment API JSON page 55 (1329/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (1335/~4553)
# [youtube]     Downloading comment API JSON reply thread 2 (1340/~4553)
# [youtube]     Downloading comment API JSON reply thread 3 (1344/~4553)
# [youtube]     Downloading comment API JSON reply thread 4 (1351/~4553)
# [youtube] Downloading comment API JSON page 56 (1355/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (1362/~4553)
# [youtube]     Downloading comment API JSON reply thread 2 (1365/~4553)
# [youtube]     Downloading comment API JSON reply thread 3 (1368/~4553)
# [youtube]     Downloading comment API JSON reply thread 4 (1375/~4553)
# [youtube] Downloading comment API JSON page 57 (1380/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (1388/~4553)
# [youtube]     Downloading comment API JSON reply thread 2 (1400/~4553)
# [youtube] Downloading comment API JSON page 58 (1403/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (1408/~4553)
# [youtube]     Downloading comment API JSON reply thread 2 (1421/~4553)
# [youtube] Downloading comment API JSON page 59 (1431/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (1433/~4553)
# [youtube]     Downloading comment API JSON reply thread 2 (1445/~4553)
# [youtube] Downloading comment API JSON page 60 (1454/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (1455/~4553)
# [youtube]     Downloading comment API JSON reply thread 2 (1458/~4553)
# [youtube]     Downloading comment API JSON reply thread 3 (1461/~4553)
# [youtube]        Downloading comment replies API JSON page 1 (1471/~4553)
# [youtube]        Downloading comment replies API JSON page 2 (1521/~4553)
# [youtube]     Downloading comment API JSON reply thread 4 (1531/~4553)
# [youtube]     Downloading comment API JSON reply thread 5 (1539/~4553)
# [youtube]     Downloading comment API JSON reply thread 6 (1549/~4553)
# [youtube] Downloading comment API JSON page 61 (1552/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (1571/~4553)
# [youtube] Downloading comment API JSON page 62 (1573/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (1581/~4553)
# [youtube]     Downloading comment API JSON reply thread 2 (1592/~4553)
# [youtube] Downloading comment API JSON page 63 (1603/~4553)
# [youtube] Downloading comment API JSON page 64 (1623/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (1628/~4553)
# [youtube]     Downloading comment API JSON reply thread 2 (1630/~4553)
# [youtube]     Downloading comment API JSON reply thread 3 (1634/~4553)
# [youtube]        Downloading comment replies API JSON page 1 (1644/~4553)
# [youtube]     Downloading comment API JSON reply thread 4 (1652/~4553)
# [youtube]     Downloading comment API JSON reply thread 5 (1659/~4553)
# [youtube] Downloading comment API JSON page 65 (1662/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (1677/~4553)
# [youtube]     Downloading comment API JSON reply thread 2 (1681/~4553)
# [youtube]        Downloading comment replies API JSON page 1 (1691/~4553)
# [youtube] Downloading comment API JSON page 66 (1699/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (1705/~4553)
# [youtube]     Downloading comment API JSON reply thread 2 (1713/~4553)
# [youtube]     Downloading comment API JSON reply thread 3 (1720/~4553)
# [youtube] Downloading comment API JSON page 67 (1726/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (1732/~4553)
# [youtube]     Downloading comment API JSON reply thread 2 (1750/~4553)
# [youtube] Downloading comment API JSON page 68 (1759/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (1767/~4553)
# [youtube]     Downloading comment API JSON reply thread 2 (1773/~4553)
# [youtube]     Downloading comment API JSON reply thread 3 (1782/~4553)
# [youtube] Downloading comment API JSON page 69 (1784/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (1786/~4553)
# [youtube]     Downloading comment API JSON reply thread 2 (1792/~4553)
# [youtube]        Downloading comment replies API JSON page 1 (1802/~4553)
# [youtube]     Downloading comment API JSON reply thread 3 (1816/~4553)
# [youtube]     Downloading comment API JSON reply thread 4 (1820/~4553)
# [youtube]        Downloading comment replies API JSON page 1 (1830/~4553)
# [youtube]     Downloading comment API JSON reply thread 5 (1854/~4553)
# [youtube] Downloading comment API JSON page 70 (1867/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (1873/~4553)
# [youtube] Downloading comment API JSON page 71 (1897/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (1908/~4553)
# [youtube]     Downloading comment API JSON reply thread 2 (1916/~4553)
# [youtube] Downloading comment API JSON page 72 (1923/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (1940/~4553)
# [youtube] Downloading comment API JSON page 73 (1944/~4553)
# [youtube] Downloading comment API JSON page 74 (1964/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (1979/~4553)
# [youtube]     Downloading comment API JSON reply thread 2 (1983/~4553)
# [youtube]        Downloading comment replies API JSON page 1 (1993/~4553)
# [youtube] Downloading comment API JSON page 75 (2002/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (2021/~4553)
# [youtube] Downloading comment API JSON page 76 (2028/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (2033/~4553)
# [youtube]     Downloading comment API JSON reply thread 2 (2036/~4553)
# [youtube]     Downloading comment API JSON reply thread 3 (2039/~4553)
# [youtube]     Downloading comment API JSON reply thread 4 (2041/~4553)
# [youtube]     Downloading comment API JSON reply thread 5 (2045/~4553)
# [youtube] Downloading comment API JSON page 77 (2054/~4553)
# [youtube] Downloading comment API JSON page 78 (2074/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (2089/~4553)
# [youtube] Downloading comment API JSON page 79 (2101/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (2116/~4553)
# [youtube] Downloading comment API JSON page 80 (2122/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (2131/~4553)
# [youtube] Downloading comment API JSON page 81 (2144/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (2151/~4553)
# [youtube] Downloading comment API JSON page 82 (2167/~4553)
# [youtube] Downloading comment API JSON page 83 (2187/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (2199/~4553)
# [youtube]     Downloading comment API JSON reply thread 2 (2209/~4553)
# [youtube]     Downloading comment API JSON reply thread 3 (2221/~4553)
# [youtube] Downloading comment API JSON page 84 (2222/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (2223/~4553)
# [youtube]     Downloading comment API JSON reply thread 2 (2227/~4553)
# [youtube]     Downloading comment API JSON reply thread 3 (2230/~4553)
# [youtube]     Downloading comment API JSON reply thread 4 (2234/~4553)
# [youtube]     Downloading comment API JSON reply thread 5 (2244/~4553)
# [youtube] Downloading comment API JSON page 85 (2248/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (2249/~4553)
# [youtube] Downloading comment API JSON page 86 (2269/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (2282/~4553)
# [youtube]     Downloading comment API JSON reply thread 2 (2290/~4553)
# [youtube] Downloading comment API JSON page 87 (2295/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (2311/~4553)
# [youtube]     Downloading comment API JSON reply thread 2 (2316/~4553)
# [youtube] Downloading comment API JSON page 88 (2320/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (2327/~4553)
# [youtube]     Downloading comment API JSON reply thread 2 (2335/~4553)
# [youtube]     Downloading comment API JSON reply thread 3 (2341/~4553)
# [youtube] Downloading comment API JSON page 89 (2343/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (2344/~4553)
# [youtube]     Downloading comment API JSON reply thread 2 (2353/~4553)
# [youtube] Downloading comment API JSON page 90 (2365/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (2379/~4553)
# [youtube]     Downloading comment API JSON reply thread 2 (2382/~4553)
# [youtube] Downloading comment API JSON page 91 (2391/~4553)
# [youtube] Downloading comment API JSON page 92 (2411/~4553)
# [youtube] Downloading comment API JSON page 93 (2431/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (2432/~4553)
# [youtube] Downloading comment API JSON page 94 (2454/~4553)
# [youtube] Downloading comment API JSON page 95 (2474/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (2476/~4553)
# [youtube]     Downloading comment API JSON reply thread 2 (2481/~4553)
# [youtube]     Downloading comment API JSON reply thread 3 (2484/~4553)
# [youtube]     Downloading comment API JSON reply thread 4 (2487/~4553)
# [youtube] Downloading comment API JSON page 96 (2500/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (2504/~4553)
# [youtube]     Downloading comment API JSON reply thread 2 (2522/~4553)
# [youtube] Downloading comment API JSON page 97 (2523/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (2533/~4553)
# [youtube]     Downloading comment API JSON reply thread 2 (2540/~4553)
# [youtube] Downloading comment API JSON page 98 (2545/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (2552/~4553)
# [youtube]     Downloading comment API JSON reply thread 2 (2555/~4553)
# [youtube] Downloading comment API JSON page 99 (2567/~4553)
# [youtube] Downloading comment API JSON page 100 (2587/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (2596/~4553)
# [youtube]     Downloading comment API JSON reply thread 2 (2602/~4553)
# [youtube]     Downloading comment API JSON reply thread 3 (2605/~4553)
# [youtube] Downloading comment API JSON page 101 (2611/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (2624/~4553)
# [youtube] Downloading comment API JSON page 102 (2633/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (2642/~4553)
# [youtube] Downloading comment API JSON page 103 (2655/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (2658/~4553)
# [youtube]     Downloading comment API JSON reply thread 2 (2669/~4553)
# [youtube]     Downloading comment API JSON reply thread 3 (2674/~4553)
# [youtube]     Downloading comment API JSON reply thread 4 (2679/~4553)
# [youtube] Downloading comment API JSON page 104 (2681/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (2684/~4553)
# [youtube]     Downloading comment API JSON reply thread 2 (2689/~4553)
# [youtube]     Downloading comment API JSON reply thread 3 (2701/~4553)
# [youtube]     Downloading comment API JSON reply thread 4 (2703/~4553)
# [youtube]     Downloading comment API JSON reply thread 5 (2710/~4553)
# [youtube]     Downloading comment API JSON reply thread 6 (2712/~4553)
# [youtube]     Downloading comment API JSON reply thread 7 (2717/~4553)
# [youtube] Downloading comment API JSON page 105 (2721/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (2722/~4553)
# [youtube]     Downloading comment API JSON reply thread 2 (2726/~4553)
# [youtube]     Downloading comment API JSON reply thread 3 (2730/~4553)
# [youtube] Downloading comment API JSON page 106 (2749/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (2750/~4553)
# [youtube]     Downloading comment API JSON reply thread 2 (2762/~4553)
# [youtube]     Downloading comment API JSON reply thread 3 (2767/~4553)
# [youtube] Downloading comment API JSON page 107 (2785/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (2794/~4553)
# [youtube]     Downloading comment API JSON reply thread 2 (2805/~4553)
# [youtube]        Downloading comment replies API JSON page 1 (2815/~4553)
# [youtube] Downloading comment API JSON page 108 (2826/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (2831/~4553)
# [youtube]     Downloading comment API JSON reply thread 2 (2836/~4553)
# [youtube]     Downloading comment API JSON reply thread 3 (2844/~4553)
# [youtube]     Downloading comment API JSON reply thread 4 (2850/~4553)
# [youtube]     Downloading comment API JSON reply thread 5 (2853/~4553)
# [youtube]     Downloading comment API JSON reply thread 6 (2857/~4553)
# [youtube]     Downloading comment API JSON reply thread 7 (2863/~4553)
# [youtube] Downloading comment API JSON page 109 (2868/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (2876/~4553)
# [youtube]     Downloading comment API JSON reply thread 2 (2878/~4553)
# [youtube]        Downloading comment replies API JSON page 1 (2888/~4553)
# [youtube]     Downloading comment API JSON reply thread 3 (2910/~4553)
# [youtube]     Downloading comment API JSON reply thread 4 (2914/~4553)
# [youtube]        Downloading comment replies API JSON page 1 (2924/~4553)
# [youtube]     Downloading comment API JSON reply thread 5 (2951/~4553)
# [youtube] Downloading comment API JSON page 110 (2956/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (2962/~4553)
# [youtube]     Downloading comment API JSON reply thread 2 (2973/~4553)
# [youtube]     Downloading comment API JSON reply thread 3 (2985/~4553)
# [youtube]        Downloading comment replies API JSON page 1 (2995/~4553)
# [youtube]     Downloading comment API JSON reply thread 4 (2999/~4553)
# [youtube] Downloading comment API JSON page 111 (3001/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (3009/~4553)
# [youtube] Downloading comment API JSON page 112 (3025/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (3027/~4553)
# [youtube]     Downloading comment API JSON reply thread 2 (3031/~4553)
# [youtube]     Downloading comment API JSON reply thread 3 (3033/~4553)
# [youtube]     Downloading comment API JSON reply thread 4 (3036/~4553)
# [youtube]     Downloading comment API JSON reply thread 5 (3040/~4553)
# [youtube]     Downloading comment API JSON reply thread 6 (3052/~4553)
# [youtube] Downloading comment API JSON page 113 (3056/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (3060/~4553)
# [youtube]        Downloading comment replies API JSON page 1 (3070/~4553)
# [youtube] Downloading comment API JSON page 114 (3092/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (3102/~4553)
# [youtube]        Downloading comment replies API JSON page 1 (3112/~4553)
# [youtube] Downloading comment API JSON page 115 (3134/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (3135/~4553)
# [youtube]     Downloading comment API JSON reply thread 2 (3144/~4553)
# [youtube]     Downloading comment API JSON reply thread 3 (3163/~4553)
# [youtube]     Downloading comment API JSON reply thread 4 (3171/~4553)
# [youtube]        Downloading comment replies API JSON page 1 (3181/~4553)
# [youtube]     Downloading comment API JSON reply thread 5 (3190/~4553)
# [youtube] Downloading comment API JSON page 116 (3194/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (3196/~4553)
# [youtube]     Downloading comment API JSON reply thread 2 (3206/~4553)
# [youtube] Downloading comment API JSON page 117 (3220/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (3222/~4553)
# [youtube]     Downloading comment API JSON reply thread 2 (3234/~4553)
# [youtube]     Downloading comment API JSON reply thread 3 (3237/~4553)
# [youtube]     Downloading comment API JSON reply thread 4 (3244/~4553)
# [youtube] Downloading comment API JSON page 118 (3254/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (3260/~4553)
# [youtube]     Downloading comment API JSON reply thread 2 (3262/~4553)
# [youtube] Downloading comment API JSON page 119 (3277/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (3285/~4553)
# [youtube]        Downloading comment replies API JSON page 1 (3295/~4553)
# [youtube]     Downloading comment API JSON reply thread 2 (3299/~4553)
# [youtube]     Downloading comment API JSON reply thread 3 (3311/~4553)
# WARNING: [youtube] Incomplete data received. Retrying (1/3)...
# [youtube]     Downloading comment API JSON reply thread 3 (3311/~4553)
# [youtube] Downloading comment API JSON page 120 (3319/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (3320/~4553)
# [youtube]        Downloading comment replies API JSON page 1 (3330/~4553)
# [youtube] Downloading comment API JSON page 121 (3353/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (3361/~4553)
# [youtube]     Downloading comment API JSON reply thread 2 (3365/~4553)
# [youtube]     Downloading comment API JSON reply thread 3 (3374/~4553)
# [youtube] Downloading comment API JSON page 122 (3390/~4553)
# [youtube] Downloading comment API JSON page 123 (3410/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (3415/~4553)
# [youtube]     Downloading comment API JSON reply thread 2 (3419/~4553)
# [youtube] Downloading comment API JSON page 124 (3433/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (3451/~4553)
# [youtube]     Downloading comment API JSON reply thread 2 (3456/~4553)
# [youtube]        Downloading comment replies API JSON page 1 (3466/~4553)
# [youtube] Downloading comment API JSON page 125 (3467/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (3468/~4553)
# [youtube]     Downloading comment API JSON reply thread 2 (3472/~4553)
# [youtube]        Downloading comment replies API JSON page 1 (3482/~4553)
# [youtube]     Downloading comment API JSON reply thread 3 (3510/~4553)
# [youtube]     Downloading comment API JSON reply thread 4 (3513/~4553)
# [youtube]     Downloading comment API JSON reply thread 5 (3517/~4553)
# [youtube] Downloading comment API JSON page 126 (3519/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (3527/~4553)
# [youtube]     Downloading comment API JSON reply thread 2 (3530/~4553)
# [youtube]     Downloading comment API JSON reply thread 3 (3533/~4553)
# [youtube]     Downloading comment API JSON reply thread 4 (3537/~4553)
# [youtube]     Downloading comment API JSON reply thread 5 (3549/~4553)
# [youtube]     Downloading comment API JSON reply thread 6 (3560/~4553)
# [youtube] Downloading comment API JSON page 127 (3567/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (3574/~4553)
# [youtube]     Downloading comment API JSON reply thread 2 (3577/~4553)
# [youtube]     Downloading comment API JSON reply thread 3 (3587/~4553)
# [youtube]     Downloading comment API JSON reply thread 4 (3596/~4553)
# [youtube]        Downloading comment replies API JSON page 1 (3606/~4553)
# [youtube] Downloading comment API JSON page 128 (3618/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (3622/~4553)
# [youtube]     Downloading comment API JSON reply thread 2 (3641/~4553)
# [youtube]     Downloading comment API JSON reply thread 3 (3648/~4553)
# [youtube] Downloading comment API JSON page 129 (3650/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (3660/~4553)
# [youtube]     Downloading comment API JSON reply thread 2 (3664/~4553)
# [youtube]     Downloading comment API JSON reply thread 3 (3673/~4553)
# [youtube] Downloading comment API JSON page 130 (3679/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (3685/~4553)
# [youtube]     Downloading comment API JSON reply thread 2 (3690/~4553)
# [youtube]        Downloading comment replies API JSON page 1 (3700/~4553)
# [youtube]     Downloading comment API JSON reply thread 3 (3711/~4553)
# [youtube] Downloading comment API JSON page 131 (3715/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (3716/~4553)
# [youtube]     Downloading comment API JSON reply thread 2 (3720/~4553)
# [youtube]     Downloading comment API JSON reply thread 3 (3731/~4553)
# [youtube]     Downloading comment API JSON reply thread 4 (3735/~4553)
# [youtube]     Downloading comment API JSON reply thread 5 (3738/~4553)
# [youtube]     Downloading comment API JSON reply thread 6 (3749/~4553)
# [youtube] Downloading comment API JSON page 132 (3751/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (3767/~4553)
# [youtube]     Downloading comment API JSON reply thread 2 (3775/~4553)
# [youtube] Downloading comment API JSON page 133 (3778/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (3780/~4553)
# [youtube]     Downloading comment API JSON reply thread 2 (3788/~4553)
# [youtube]     Downloading comment API JSON reply thread 3 (3794/~4553)
# [youtube]     Downloading comment API JSON reply thread 4 (3797/~4553)
# [youtube]     Downloading comment API JSON reply thread 5 (3802/~4553)
# [youtube]        Downloading comment replies API JSON page 1 (3812/~4553)
# [youtube] Downloading comment API JSON page 134 (3844/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (3855/~4553)
# [youtube]     Downloading comment API JSON reply thread 2 (3860/~4553)
# [youtube]     Downloading comment API JSON reply thread 3 (3866/~4553)
# [youtube] Downloading comment API JSON page 135 (3872/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (3873/~4553)
# [youtube]     Downloading comment API JSON reply thread 2 (3876/~4553)
# [youtube]     Downloading comment API JSON reply thread 3 (3883/~4553)
# [youtube]        Downloading comment replies API JSON page 1 (3893/~4553)
# [youtube]     Downloading comment API JSON reply thread 4 (3896/~4553)
# [youtube]     Downloading comment API JSON reply thread 5 (3899/~4553)
# [youtube]     Downloading comment API JSON reply thread 6 (3903/~4553)
# [youtube]     Downloading comment API JSON reply thread 7 (3911/~4553)
# [youtube]     Downloading comment API JSON reply thread 8 (3916/~4553)
# [youtube]     Downloading comment API JSON reply thread 9 (3918/~4553)
# [youtube] Downloading comment API JSON page 136 (3920/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (3926/~4553)
# [youtube]     Downloading comment API JSON reply thread 2 (3930/~4553)
# [youtube]     Downloading comment API JSON reply thread 3 (3935/~4553)
# [youtube]     Downloading comment API JSON reply thread 4 (3942/~4553)
# [youtube]     Downloading comment API JSON reply thread 5 (3944/~4553)
# [youtube]     Downloading comment API JSON reply thread 6 (3946/~4553)
# [youtube]        Downloading comment replies API JSON page 1 (3956/~4553)
# [youtube]     Downloading comment API JSON reply thread 7 (3966/~4553)
# [youtube]     Downloading comment API JSON reply thread 8 (3976/~4553)
# [youtube] Downloading comment API JSON page 137 (3985/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (3993/~4553)
# [youtube]     Downloading comment API JSON reply thread 2 (4001/~4553)
# [youtube]     Downloading comment API JSON reply thread 3 (4006/~4553)
# [youtube] Downloading comment API JSON page 138 (4016/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (4017/~4553)
# [youtube]     Downloading comment API JSON reply thread 2 (4024/~4553)
# [youtube]     Downloading comment API JSON reply thread 3 (4031/~4553)
# [youtube]     Downloading comment API JSON reply thread 4 (4036/~4553)
# [youtube]     Downloading comment API JSON reply thread 5 (4043/~4553)
# [youtube] Downloading comment API JSON page 139 (4047/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (4054/~4553)
# [youtube] Downloading comment API JSON page 140 (4068/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (4083/~4553)
# [youtube]     Downloading comment API JSON reply thread 2 (4090/~4553)
# [youtube] Downloading comment API JSON page 141 (4092/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (4111/~4553)
# [youtube] Downloading comment API JSON page 142 (4116/~4553)
# [youtube] Downloading comment API JSON page 143 (4136/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (4138/~4553)
# [youtube]     Downloading comment API JSON reply thread 2 (4140/~4553)
# [youtube]     Downloading comment API JSON reply thread 3 (4142/~4553)
# [youtube]     Downloading comment API JSON reply thread 4 (4148/~4553)
# [youtube] Downloading comment API JSON page 144 (4163/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (4167/~4553)
# [youtube]     Downloading comment API JSON reply thread 2 (4170/~4553)
# [youtube]     Downloading comment API JSON reply thread 3 (4183/~4553)
# [youtube]     Downloading comment API JSON reply thread 4 (4187/~4553)
# [youtube] Downloading comment API JSON page 145 (4188/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (4199/~4553)
# [youtube] Downloading comment API JSON page 146 (4212/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (4213/~4553)
# [youtube]     Downloading comment API JSON reply thread 2 (4237/~4553)
# [youtube]        Downloading comment replies API JSON page 1 (4247/~4553)
# [youtube] Downloading comment API JSON page 147 (4250/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (4253/~4553)
# [youtube]     Downloading comment API JSON reply thread 2 (4255/~4553)
# [youtube]     Downloading comment API JSON reply thread 3 (4261/~4553)
# [youtube]     Downloading comment API JSON reply thread 4 (4267/~4553)
# [youtube] Downloading comment API JSON page 148 (4278/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (4279/~4553)
# [youtube]     Downloading comment API JSON reply thread 2 (4294/~4553)
# [youtube] Downloading comment API JSON page 149 (4305/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (4315/~4553)
# [youtube]     Downloading comment API JSON reply thread 2 (4320/~4553)
# [youtube]     Downloading comment API JSON reply thread 3 (4326/~4553)
# [youtube]     Downloading comment API JSON reply thread 4 (4337/~4553)
# [youtube]        Downloading comment replies API JSON page 1 (4347/~4553)
# [youtube] Downloading comment API JSON page 150 (4351/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (4359/~4553)
# [youtube]     Downloading comment API JSON reply thread 2 (4365/~4553)
# [youtube]     Downloading comment API JSON reply thread 3 (4367/~4553)
# [youtube]     Downloading comment API JSON reply thread 4 (4370/~4553)
# [youtube]        Downloading comment replies API JSON page 1 (4380/~4553)
# [youtube]     Downloading comment API JSON reply thread 5 (4384/~4553)
# [youtube]        Downloading comment replies API JSON page 1 (4394/~4553)
# [youtube]     Downloading comment API JSON reply thread 6 (4396/~4553)
# [youtube]     Downloading comment API JSON reply thread 7 (4405/~4553)
# [youtube]     Downloading comment API JSON reply thread 8 (4412/~4553)
# [youtube] Downloading comment API JSON page 151 (4421/~4553)
# [youtube]     Downloading comment API JSON reply thread 1 (4426/~4553)
# [youtube]     Downloading comment API JSON reply thread 2 (4430/~4553)
# [youtube]     Downloading comment API JSON reply thread 3 (4435/~4553)
# [youtube]        Downloading comment replies API JSON page 1 (4445/~4553)
# [youtube]     Downloading comment API JSON reply thread 4 (4474/~4553)
# [youtube]        Downloading comment replies API JSON page 1 (4484/~4553)
# [youtube]     Downloading comment API JSON reply thread 5 (4534/~4553)
# [youtube]        Downloading comment replies API JSON page 1 (4544/~4553)
# [youtube]     Downloading comment API JSON reply thread 6 (4548/~4553)
# [youtube]     Downloading comment API JSON reply thread 7 (4550/~4553)
# [youtube] Extracted 4553 comments
# output/Alice in Wonderland (2010) - Nostalgia Critic_EWH_XT6yXv8.json: 3016 comments, 1537 replies, 3364 unique authors
# [youtube] Extracting URL: https://www.youtube.com/watch?v=I7IaW7I1YWs
# [youtube] I7IaW7I1YWs: Downloading webpage
# [youtube] I7IaW7I1YWs: Downloading tv client config
# [youtube] I7IaW7I1YWs: Downloading tv player API JSON
# [youtube] I7IaW7I1YWs: Downloading ios player API JSON
# [youtube] I7IaW7I1YWs: Downloading m3u8 information
# [youtube] Downloading comment section API JSON
# [youtube] Downloading ~7728 comments
# [youtube] Sorting comments by newest first
# [youtube] Downloading comment API JSON page 1 (0/~7728)
# [youtube]     Downloading comment API JSON reply thread 1 (10/~7728)
# [youtube] Downloading comment API JSON page 2 (21/~7728)
# [youtube]     Downloading comment API JSON reply thread 1 (41/~7728)
# [youtube] Downloading comment API JSON page 3 (42/~7728)
# [youtube]     Downloading comment API JSON reply thread 1 (53/~7728)
# [youtube] Downloading comment API JSON page 4 (65/~7728)
# [youtube] Downloading comment API JSON page 5 (85/~7728)
# [youtube]     Downloading comment API JSON reply thread 1 (96/~7728)
# [youtube] Downloading comment API JSON page 6 (106/~7728)
# [youtube]     Downloading comment API JSON reply thread 1 (108/~7728)
# [youtube]     Downloading comment API JSON reply thread 2 (116/~7728)
# [youtube] Downloading comment API JSON page 7 (128/~7728)
# [youtube]     Downloading comment API JSON reply thread 1 (129/~7728)
# [youtube]     Downloading comment API JSON reply thread 2 (141/~7728)
# [youtube] Downloading comment API JSON page 8 (150/~7728)
# [youtube]     Downloading comment API JSON reply thread 1 (156/~7728)
# [youtube] Downloading comment API JSON page 9 (172/~7728)
# [youtube]     Downloading comment API JSON reply thread 1 (173/~7728)
# [youtube]     Downloading comment API JSON reply thread 2 (185/~7728)
# [youtube]     Downloading comment API JSON reply thread 3 (188/~7728)
# [youtube]     Downloading comment API JSON reply thread 4 (192/~7728)
# [youtube] Downloading comment API JSON page 10 (196/~7728)
# [youtube] Downloading comment API JSON page 11 (216/~7728)
# [youtube]     Downloading comment API JSON reply thread 1 (219/~7728)
# [youtube] Downloading comment API JSON page 12 (237/~7728)
# [youtube]     Downloading comment API JSON reply thread 1 (242/~7728)
# [youtube]     Downloading comment API JSON reply thread 2 (258/~7728)
# [youtube] Downloading comment API JSON page 13 (259/~7728)
# [youtube]     Downloading comment API JSON reply thread 1 (261/~7728)
# [youtube] Downloading comment API JSON page 14 (280/~7728)
# [youtube]     Downloading comment API JSON reply thread 1 (285/~7728)
# [youtube] Downloading comment API JSON page 15 (301/~7728)
# [youtube] Downloading comment API JSON page 16 (321/~7728)
# [youtube] Downloading comment API JSON page 17 (341/~7728)
# [youtube]     Downloading comment API JSON reply thread 1 (355/~7728)
# [youtube]        Downloading comment replies API JSON page 1 (365/~7728)
# [youtube]     Downloading comment API JSON reply thread 2 (368/~7728)
# [youtube]        Downloading comment replies API JSON page 1 (378/~7728)
# [youtube] Downloading comment API JSON page 18 (389/~7728)
# [youtube]     Downloading comment API JSON reply thread 1 (390/~7728)
# [youtube]        Downloading comment replies API JSON page 1 (400/~7728)
# [youtube]     Downloading comment API JSON reply thread 2 (413/~7728)
# [youtube] Downloading comment API JSON page 19 (428/~7728)
# [youtube] Downloading comment API JSON page 20 (448/~7728)
# [youtube]     Downloading comment API JSON reply thread 1 (454/~7728)
# [youtube]        Downloading comment replies API JSON page 1 (464/~7728)
# [youtube]     Downloading comment API JSON reply thread 2 (477/~7728)
# [youtube]     Downloading comment API JSON reply thread 3 (481/~7728)
# [youtube]     Downloading comment API JSON reply thread 4 (487/~7728)
# [youtube] Downloading comment API JSON page 21 (492/~7728)
# [youtube]     Downloading comment API JSON reply thread 1 (499/~7728)
# [youtube]     Downloading comment API JSON reply thread 2 (505/~7728)
# [youtube] Downloading comment API JSON page 22 (517/~7728)
# [youtube]     Downloading comment API JSON reply thread 1 (531/~7728)
# [youtube]     Downloading comment API JSON reply thread 2 (539/~7728)
# [youtube] Downloading comment API JSON page 23 (541/~7728)
# [youtube] Downloading comment API JSON page 24 (561/~7728)
# [youtube]     Downloading comment API JSON reply thread 1 (565/~7728)
# [youtube]     Downloading comment API JSON reply thread 2 (567/~7728)
# [youtube]     Downloading comment API JSON reply thread 3 (574/~7728)
# [youtube] Downloading comment API JSON page 25 (584/~7728)
# [youtube]     Downloading comment API JSON reply thread 1 (598/~7728)
# [youtube] Downloading comment API JSON page 26 (605/~7728)
# [youtube]     Downloading comment API JSON reply thread 1 (611/~7728)
# [youtube]     Downloading comment API JSON reply thread 2 (624/~7728)
# [youtube] Downloading comment API JSON page 27 (627/~7728)
# [youtube]     Downloading comment API JSON reply thread 1 (639/~7728)
# [youtube]     Downloading comment API JSON reply thread 2 (643/~7728)
# [youtube] Downloading comment API JSON page 28 (649/~7728)
# ...
# [youtube] Downloading comment API JSON page 182 (5106/~7728)
# [youtube]     Downloading comment API JSON reply thread 1 (5124/~7728)
# [youtube] Downloading comment API JSON page 183 (5129/~7728)
# [youtube] Downloading comment API JSON page 184 (5149/~7728)
# [youtube]     Downloading comment API JSON reply thread 1 (5169/~7728)
# [youtube] Downloading comment API JSON page 185 (5170/~7728)
# [youtube] Downloading comment API JSON page 186 (5190/~7728)
# [youtube]     Downloading comment API JSON reply thread 1 (5200/~7728)
# [youtube] Downloading comment API JSON page 187 (5213/~7728)
# [youtube]     Downloading comment API JSON reply thread 1 (5214/~7728)
# [youtube]     Downloading comment API JSON reply thread 2 (5231/~7728)
# [youtube] Downloading comment API JSON page 188 (5240/~7728)
# [youtube]     Downloading comment API JSON reply thread 1 (5242/~7728)
# [youtube] Downloading comment API JSON page 189 (5262/~7728)
# [youtube] Downloading comment API JSON page 190 (5282/~7728)
# [youtube] Downloading comment API JSON page 191 (5302/~7728)
# [youtube]     Downloading comment API JSON reply thread 1 (5322/~7728)
# [youtube] Downloading comment API JSON page 192 (5328/~7728)
# [youtube]     Downloading comment API JSON reply thread 1 (5341/~7728)
# [youtube] Downloading comment API JSON page 193 (5350/~7728)
# [youtube] Downloading comment API JSON page 194 (5370/~7728)
# [youtube]     Downloading comment API JSON reply thread 1 (5384/~7728)
# [youtube] Downloading comment API JSON page 195 (5391/~7728)
# [youtube]     Downloading comment API JSON reply thread 1 (5392/~7728)
# [youtube] Downloading comment API JSON page 196 (5418/~7728)
# [youtube] Downloading comment API JSON page 197 (5438/~7728)
# [youtube]     Downloading comment API JSON reply thread 1 (5440/~7728)
# [youtube]     Downloading comment API JSON reply thread 2 (5452/~7728)
# [youtube]     Downloading comment API JSON reply thread 3 (5458/~7728)
# [youtube] Downloading comment API JSON page 198 (5463/~7728)
# [youtube]     Downloading comment API JSON reply thread 1 (5477/~7728)
# [youtube] Downloading comment API JSON page 199 (5490/~7728)
# [youtube] Downloading comment API JSON page 200 (5510/~7728)
# [youtube]     Downloading comment API JSON reply thread 1 (5515/~7728)
# [youtube]     Downloading comment API JSON reply thread 2 (5526/~7728)
# [youtube]     Downloading comment API JSON reply thread 3 (5531/~7728)
# [youtube] Downloading comment API JSON page 201 (5543/~7728)
# [youtube]     Downloading comment API JSON reply thread 1 (5547/~7728)
# [youtube]     Downloading comment API JSON reply thread 2 (5551/~7728)
# [youtube] Downloading comment API JSON page 202 (5574/~7728)
# [youtube] Downloading comment API JSON page 203 (5594/~7728)
# [youtube]     Downloading comment API JSON reply thread 1 (5595/~7728)
# [youtube]        Downloading comment replies API JSON page 1 (5605/~7728)
# [youtube]     Downloading comment API JSON reply thread 2 (5619/~7728)
# [youtube] Downloading comment API JSON page 204 (5635/~7728)
# [youtube]     Downloading comment API JSON reply thread 1 (5637/~7728)
# [youtube] Downloading comment API JSON page 205 (5656/~7728)
# [youtube]     Downloading comment API JSON reply thread 1 (5661/~7728)
# [youtube]     Downloading comment API JSON reply thread 2 (5663/~7728)
# [youtube]     Downloading comment API JSON reply thread 3 (5666/~7728)
# [youtube]     Downloading comment API JSON reply thread 4 (5677/~7728)
# [youtube] Downloading comment API JSON page 206 (5683/~7728)
# [youtube]     Downloading comment API JSON reply thread 1 (5692/~7728)
# [youtube]     Downloading comment API JSON reply thread 2 (5700/~7728)
# [youtube]     Downloading comment API JSON reply thread 3 (5711/~7728)
# [youtube] Downloading comment API JSON page 207 (5712/~7728)
# [youtube]     Downloading comment API JSON reply thread 1 (5727/~7728)
# [youtube]     Downloading comment API JSON reply thread 2 (5735/~7728)
# [youtube] Downloading comment API JSON page 208 (5741/~7728)
# [youtube]     Downloading comment API JSON reply thread 1 (5744/~7728)
# [youtube]     Downloading comment API JSON reply thread 2 (5749/~7728)
# [youtube] Downloading comment API JSON page 209 (5765/~7728)
# [youtube] Downloading comment API JSON page 210 (5785/~7728)
# [youtube]     Downloading comment API JSON reply thread 1 (5799/~7728)
# [youtube] Downloading comment API JSON page 211 (5806/~7728)
# [youtube]     Downloading comment API JSON reply thread 1 (5808/~7728)
# [youtube]     Downloading comment API JSON reply thread 2 (5820/~7728)
# [youtube]     Downloading comment API JSON reply thread 3 (5830/~7728)
# [youtube]     Downloading comment API JSON reply thread 4 (5839/~7728)
# [youtube] Downloading comment API JSON page 212 (5840/~7728)
# [youtube] Downloading comment API JSON page 213 (5860/~7728)
# [youtube] Downloading comment API JSON page 214 (5880/~7728)
# [youtube] Downloading comment API JSON page 215 (5900/~7728)
# [youtube]     Downloading comment API JSON reply thread 1 (5912/~7728)
# [youtube] Downloading comment API JSON page 216 (5921/~7728)
# [youtube]     Downloading comment API JSON reply thread 1 (5922/~7728)
# [youtube] Downloading comment API JSON page 217 (5943/~7728)
# [youtube]     Downloading comment API JSON reply thread 1 (5946/~7728)
# [youtube]     Downloading comment API JSON reply thread 2 (5958/~7728)
# [youtube] Downloading comment API JSON page 218 (5968/~7728)
# [youtube]     Downloading comment API JSON reply thread 1 (5977/~7728)
# [youtube]        Downloading comment replies API JSON page 1 (5987/~7728)
# [youtube]     Downloading comment API JSON reply thread 2 (5995/~7728)
# [youtube]        Downloading comment replies API JSON page 1 (6005/~7728)
# [youtube] Downloading comment API JSON page 219 (6022/~7728)
# [youtube]     Downloading comment API JSON reply thread 1 (6042/~7728)
# [youtube] Downloading comment API JSON page 220 (6050/~7728)
# [youtube]     Downloading comment API JSON reply thread 1 (6065/~7728)
# [youtube]        Downloading comment replies API JSON page 1 (6075/~7728)
# [youtube] Downloading comment API JSON page 221 (6083/~7728)
# [youtube]     Downloading comment API JSON reply thread 1 (6092/~7728)
# [youtube]     Downloading comment API JSON reply thread 2 (6111/~7728)
# [youtube] Downloading comment API JSON page 222 (6114/~7728)
# [youtube]     Downloading comment API JSON reply thread 1 (6115/~7728)
# [youtube] Downloading comment API JSON page 223 (6137/~7728)
# [youtube]     Downloading comment API JSON reply thread 1 (6152/~7728)
# [youtube] Downloading comment API JSON page 224 (6159/~7728)
# [youtube]     Downloading comment API JSON reply thread 1 (6160/~7728)
# [youtube] Downloading comment API JSON page 225 (6185/~7728)
# [youtube]     Downloading comment API JSON reply thread 1 (6189/~7728)
# [youtube] Downloading comment API JSON page 226 (6208/~7728)
# [youtube]     Downloading comment API JSON reply thread 1 (6217/~7728)
# [youtube]     Downloading comment API JSON reply thread 2 (6224/~7728)
# [youtube]     Downloading comment API JSON reply thread 3 (6227/~7728)
# [youtube] Downloading comment API JSON page 227 (6234/~7728)
# [youtube]     Downloading comment API JSON reply thread 1 (6244/~7728)
# [youtube] Downloading comment API JSON page 228 (6258/~7728)
# [youtube]     Downloading comment API JSON reply thread 1 (6266/~7728)
# [youtube]        Downloading comment replies API JSON page 1 (6276/~7728)
# [youtube]     Downloading comment API JSON reply thread 2 (6286/~7728)
# [youtube] Downloading comment API JSON page 229 (6300/~7728)
# [youtube]     Downloading comment API JSON reply thread 1 (6313/~7728)
# [youtube]        Downloading comment replies API JSON page 1 (6323/~7728)
# [youtube] Downloading comment API JSON page 230 (6334/~7728)
# [youtube]     Downloading comment API JSON reply thread 1 (6349/~7728)
# [youtube]        Downloading comment replies API JSON page 1 (6359/~7728)
# [youtube]     Downloading comment API JSON reply thread 2 (6376/~7728)
# [youtube]        Downloading comment replies API JSON page 1 (6386/~7728)
# [youtube]        Downloading comment replies API JSON page 2 (6436/~7728)
# [youtube] Downloading comment API JSON page 231 (6455/~7728)
# [youtube] Downloading comment API JSON page 232 (6475/~7728)
# [youtube] Downloading comment API JSON page 233 (6495/~7728)
# [youtube] Downloading comment API JSON page 234 (6515/~7728)
# [youtube]     Downloading comment API JSON reply thread 1 (6516/~7728)
# [youtube]        Downloading comment replies API JSON page 1 (6526/~7728)
# [youtube]     Downloading comment API JSON reply thread 2 (6552/~7728)
# [youtube]     Downloading comment API JSON reply thread 3 (6568/~7728)
# [youtube]     Downloading comment API JSON reply thread 4 (6582/~7728)
# [youtube] Downloading comment API JSON page 235 (6590/~7728)
# [youtube]     Downloading comment API JSON reply thread 1 (6603/~7728)
# [youtube] Downloading comment API JSON page 236 (6614/~7728)
# [youtube]     Downloading comment API JSON reply thread 1 (6615/~7728)
# [youtube]     Downloading comment API JSON reply thread 2 (6624/~7728)
# [youtube] Downloading comment API JSON page 237 (6638/~7728)
# [youtube]     Downloading comment API JSON reply thread 1 (6653/~7728)
# [youtube]     Downloading comment API JSON reply thread 2 (6662/~7728)
# [youtube]        Downloading comment replies API JSON page 1 (6672/~7728)
# [youtube] Downloading comment API JSON page 238 (6690/~7728)
# [youtube]     Downloading comment API JSON reply thread 1 (6695/~7728)
# [youtube]        Downloading comment replies API JSON page 1 (6705/~7728)
# [youtube]     Downloading comment API JSON reply thread 2 (6735/~7728)
# [youtube]     Downloading comment API JSON reply thread 3 (6743/~7728)
# [youtube]        Downloading comment replies API JSON page 1 (6753/~7728)
# [youtube] Downloading comment API JSON page 239 (6762/~7728)
# [youtube]     Downloading comment API JSON reply thread 1 (6765/~7728)
# [youtube] Downloading comment API JSON page 240 (6790/~7728)
# [youtube]     Downloading comment API JSON reply thread 1 (6805/~7728)
# [youtube] Downloading comment API JSON page 241 (6811/~7728)
# [youtube]     Downloading comment API JSON reply thread 1 (6813/~7728)
# [youtube]        Downloading comment replies API JSON page 1 (6823/~7728)
# [youtube]     Downloading comment API JSON reply thread 2 (6857/~7728)
# [youtube] Downloading comment API JSON page 242 (6858/~7728)
# [youtube]     Downloading comment API JSON reply thread 1 (6863/~7728)
# [youtube] Downloading comment API JSON page 243 (6882/~7728)
# [youtube]     Downloading comment API JSON reply thread 1 (6895/~7728)
# [youtube]        Downloading comment replies API JSON page 1 (6905/~7728)
# [youtube] Downloading comment API JSON page 244 (6933/~7728)
# [youtube]     Downloading comment API JSON reply thread 1 (6935/~7728)
# [youtube] Downloading comment API JSON page 245 (6963/~7728)
# [youtube]     Downloading comment API JSON reply thread 1 (6969/~7728)
# [youtube]     Downloading comment API JSON reply thread 2 (6978/~7728)
# [youtube]        Downloading comment replies API JSON page 1 (6988/~7728)
# [youtube]     Downloading comment API JSON reply thread 3 (7003/~7728)
# [youtube] Downloading comment API JSON page 246 (7005/~7728)
# [youtube]     Downloading comment API JSON reply thread 1 (7011/~7728)
# [youtube] Downloading comment API JSON page 247 (7026/~7728)
# [youtube]     Downloading comment API JSON reply thread 1 (7033/~7728)
# [youtube]        Downloading comment replies API JSON page 1 (7043/~7728)
# [youtube]     Downloading comment API JSON reply thread 2 (7069/~7728)
# [youtube] Downloading comment API JSON page 248 (7080/~7728)
# [youtube]     Downloading comment API JSON reply thread 1 (7086/~7728)
# [youtube] Downloading comment API JSON page 249 (7110/~7728)
# [youtube]     Downloading comment API JSON reply thread 1 (7112/~7728)
# [youtube] Downloading comment API JSON page 250 (7131/~7728)
# [youtube]     Downloading comment API JSON reply thread 1 (7142/~7728)
# [youtube] Downloading comment API JSON page 251 (7152/~7728)
# [youtube]     Downloading comment API JSON reply thread 1 (7156/~7728)
# [youtube]     Downloading comment API JSON reply thread 2 (7159/~7728)
# [youtube]        Downloading comment replies API JSON page 1 (7169/~7728)
# [youtube] Downloading comment API JSON page 252 (7204/~7728)
# [youtube]     Downloading comment API JSON reply thread 1 (7206/~7728)
# [youtube]     Downloading comment API JSON reply thread 2 (7212/~7728)
# [youtube]     Downloading comment API JSON reply thread 3 (7222/~7728)
# [youtube]        Downloading comment replies API JSON page 1 (7232/~7728)
# [youtube]     Downloading comment API JSON reply thread 4 (7260/~7728)
# [youtube] Downloading comment API JSON page 253 (7262/~7728)
# [youtube]     Downloading comment API JSON reply thread 1 (7274/~7728)
# [youtube]     Downloading comment API JSON reply thread 2 (7280/~7728)
# [youtube] Downloading comment API JSON page 254 (7285/~7728)
# [youtube]     Downloading comment API JSON reply thread 1 (7295/~7728)
# [youtube]     Downloading comment API JSON reply thread 2 (7308/~7728)
# [youtube] Downloading comment API JSON page 255 (7317/~7728)
# [youtube]     Downloading comment API JSON reply thread 1 (7321/~7728)
# [youtube]        Downloading comment replies API JSON page 1 (7331/~7728)
# [youtube]        Downloading comment replies API JSON page 2 (7381/~7728)
# [youtube] Downloading comment API JSON page 256 (7400/~7728)
# [youtube]     Downloading comment API JSON reply thread 1 (7402/~7728)
# [youtube]     Downloading comment API JSON reply thread 2 (7411/~7728)
# [youtube]     Downloading comment API JSON reply thread 3 (7417/~7728)
# [youtube] Downloading comment API JSON page 257 (7426/~7728)
# [youtube]     Downloading comment API JSON reply thread 1 (7428/~7728)
# [youtube]     Downloading comment API JSON reply thread 2 (7435/~7728)
# [youtube]     Downloading comment API JSON reply thread 3 (7440/~7728)
# [youtube]     Downloading comment API JSON reply thread 4 (7452/~7728)
# [youtube]        Downloading comment replies API JSON page 1 (7462/~7728)
# [youtube] Downloading comment API JSON page 258 (7479/~7728)
# [youtube]     Downloading comment API JSON reply thread 1 (7487/~7728)
# [youtube]        Downloading comment replies API JSON page 1 (7497/~7728)
# [youtube]     Downloading comment API JSON reply thread 2 (7500/~7728)
# [youtube]     Downloading comment API JSON reply thread 3 (7505/~7728)
# [youtube]     Downloading comment API JSON reply thread 4 (7509/~7728)
# [youtube]     Downloading comment API JSON reply thread 5 (7513/~7728)
# [youtube]        Downloading comment replies API JSON page 1 (7523/~7728)
# [youtube] Downloading comment API JSON page 259 (7529/~7728)
# [youtube]     Downloading comment API JSON reply thread 1 (7533/~7728)
# [youtube]     Downloading comment API JSON reply thread 2 (7535/~7728)
# [youtube]        Downloading comment replies API JSON page 1 (7545/~7728)
# [youtube]     Downloading comment API JSON reply thread 3 (7554/~7728)
# [youtube]     Downloading comment API JSON reply thread 4 (7567/~7728)
# [youtube] Downloading comment API JSON page 260 (7571/~7728)
# [youtube]     Downloading comment API JSON reply thread 1 (7576/~7728)
# [youtube]        Downloading comment replies API JSON page 1 (7586/~7728)
# [youtube]     Downloading comment API JSON reply thread 2 (7597/~7728)
# [youtube]     Downloading comment API JSON reply thread 3 (7601/~7728)
# [youtube]     Downloading comment API JSON reply thread 4 (7607/~7728)
# [youtube]     Downloading comment API JSON reply thread 5 (7609/~7728)
# [youtube]        Downloading comment replies API JSON page 1 (7619/~7728)
# [youtube]        Downloading comment replies API JSON page 2 (7669/~7728)
# [youtube] Downloading comment API JSON page 261 (7698/~7728)
# [youtube]     Downloading comment API JSON reply thread 1 (7716/~7728)
# [youtube] Downloading comment API JSON page 262 (7719/~7728)
# [youtube]     Downloading comment API JSON reply thread 1 (7725/~7728)
# [youtube]     Downloading comment API JSON reply thread 2 (7727/~7728)
# [youtube] Extracted 7728 comments
# output/Everything Wrong With Alice In Wonderland_I7IaW7I1YWs.json: 5227 comments, 2501 replies, 6021 unique authors
