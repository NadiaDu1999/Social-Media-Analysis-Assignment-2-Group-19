# %%
import networkx as nx
# python-louvain
import community
import random
import csv
import community as community_louvain
import matplotlib.pyplot as plt

# %%
! pip install python-louvain
# Out:
# Requirement already satisfied: python-louvain in /opt/anaconda3/lib/python3.12/site-packages (0.16)
# Requirement already satisfied: networkx in /opt/anaconda3/lib/python3.12/site-packages (from python-louvain) (3.2.1)
# Requirement already satisfied: numpy in /opt/anaconda3/lib/python3.12/site-packages (from python-louvain) (1.26.4)

# %%
sFilename = "youtube_reply_graph.graphml"
replyGraph = nx.readwrite.read_graphml(sFilename)

# %%
import community.community_louvain as community_louvain

dLouvainComms = community_louvain.best_partition(nx.to_undirected(replyGraph))

# %%
! pip install python-louvain
# Out:
# Requirement already satisfied: python-louvain in /opt/anaconda3/lib/python3.12/site-packages (0.16)
# Requirement already satisfied: networkx in /opt/anaconda3/lib/python3.12/site-packages (from python-louvain) (3.2.1)
# Requirement already satisfied: numpy in /opt/anaconda3/lib/python3.12/site-packages (from python-louvain) (1.26.4)

# %%
# filename of graph to read in
sFilename = "youtube_reply_graph.graphml"

# %%
def dictToSetFormat(comm_dict, num_communities):
    comm_list = [set() for _ in range(num_communities)]
    for node, comm_id in comm_dict.items():
        comm_list[comm_id].add(node)
    return comm_list

# %%
sFilename = "youtube_reply_graph.graphml"
# read the reply graph in
replyGraph = nx.readwrite.read_graphml(sFilename)

#
# compute communities
#

#
# TODO: Implement CPM
#

# k (clique size)
k = 3
# placeholder.  Add the implementation to the right, but maintain the variable name.
lCpmComms = list(nx.algorithms.community.k_clique_communities(nx.to_undirected(replyGraph), k))
print(lCpmComms)

#
# TODO: Implement louvain
#

# louvain
# Placeholder, replace right hand side
dLouvainComms = community_louvain.best_partition(nx.to_undirected(replyGraph))
print(dLouvainComms)

# this code converts output of Louvain to the same format as CPM (makes it easier to have one consistent interface
louvanCommNum = max([y for (x,y) in dLouvainComms.items()]) + 1
lLouvainComms = dictToSetFormat(dLouvainComms, louvanCommNum)


#
# TODO: Write out cpm and Louvain values to node attributes of graph
#

# cpm labels, stored in node attribute 'cpmClusId'
for clusId, lComms in enumerate(lCpmComms):
    for nodeId in lComms:
        replyGraph.nodes[nodeId]['cpmClusId'] = clusId

# louvain labels, stored in node attribute 'louvain'
for clusId, lComms in enumerate(lLouvainComms):
    for nodeId in lComms:
        replyGraph.nodes[nodeId]['louvain'] = clusId

output_filename = 'mod2' + sFilename
print("Saving graph to:", output_filename)
nx.readwrite.write_graphml(replyGraph, output_filename, infer_numeric_types=True)
# Out:
# [frozenset({'@Anonymousbeing7', '@StompDeni42', '@zoey_96'}), frozenset({'@kms08711', '@Kvothe_The_Bloodless', '@zoey_96'}), frozenset({'@vertabray5064', '@Kinosis79', '@zoey_96'}), frozenset({'@banyakakal4299', '@zoey_96', '@BCRivers', '@Noodle_Salsinha', '@MrDamnLag'}), frozenset({'@jaguar-s9t', '@CaliforniaDreamin.', '@TheWailingWumpus'}), frozenset({'@Ayelet.M', '@gapanda8984', '@fabianking6670', '@tonynelson2262', '@AJVillanueva2030', '@sergioflores6826', '@chickensandwich9977', '@Figgy20000'}), frozenset({'@joshhickeysmoviereviews', '@SeanChandlerTalksAbout', '@ReviewJunkee'}), frozenset({'@AJVillanueva2030', '@Jayteaseepiirturi', '@AnotherRandomGuest-cq6pc', '@SeanChandlerTalksAbout', '@EthanJury-c7q', '@AngelGMaxwell'}), frozenset({'@Carlos-artist-NYC', '@abdalrahmanyamany4946', '@epicationnl9669', '@F2SOnYouTube', '@AJVillanueva2030', '@GorgeousPenguin', '@PujaPatil-8199', '@Dee-ct5mm', '@Chocopie-nr8md', '@LPBineli', '@seank9122', '@matthew-g4i2i', '@NoNo-r4z1c', '@Meilk27', '@Trump_2024_USA', '@TeamWitherstorm', '@VictorGonzalez-xs9oc', '@Kiyoone', '@omegadragon9524', '@rogerrussell9544', '@Prime33-r4t', '@BatmanFan76', '@BryceEdwardBrown', '@ChromaticDragons101', '@SeanChandlerTalksAbout', '@TheWailingWumpus', '@takerhulk3163', '@bluegloriousgames', '@SitiAisyahUmrah', '@rabee53', '@PujaPatil-9199', '@chat.m', '@annirudhsajith', '@realquemulroy', '@acarter9277', '@gregorymurphy3234', '@darkmessiah1883', '@RedHall', '@Jojotubex', '@TheAngrySinger', '@Barricade379', '@juancarlosrivera5689', '@nolanhewitt2563', '@ToppyDreemurr', '@movielover7565', '@GeloYellow', '@JackiJing', '@thetwinscraft1675', '@chadwalker9804', '@LotSfan4Life', '@riorodgers618', '@Chaos_leee', '@hsd287', '@FireBomberBassist', '@kmtkmt1374', '@Ekene.Bricks', '@dolphincrescent54', '@Justyn2025', '@richardhaskell3151', '@Jaydennarh15', '@definitely.dustin', '@the1cardinal', '@itsnick5082', '@mihaelkeehl8650', '@lavender9844', '@Ze0do0Gas', '@George_Fl0yd', '@NinokeNinja', '@bigorange2082', '@thomaswatson1995', '@carlbonara602', '@ATAndreiThomas', '@Sato-sss', '@0_____Miss_Ayesha______', '@shivnathchaudhary3140', '@ethanhambert8732', '@tiefblau2780', '@Havocbuilder', '@BCRivers', '@blackpinklisa3615', '@user-sr6rm9yy1o', '@thekatiecage', '@brunnalima8201', '@Liquidcadmus', '@alfonsoperez4614', '@devastatorkvadat', '@lordsinister707'}), frozenset({'@Chaos_leee', '@toonami-jetix-4kids_fan_2002', '@kyuremnegro0686'}), frozenset({'@nolanhewitt2563', '@EzihChikamso', '@TheWailingWumpus'}), frozenset({'@Natmichelle14', '@justinkador2496', '@Jayteaseepiirturi'}), frozenset({'@isabella2513', '@hiswayservicesblog9288', '@nebvlae', '@tsarina24honolulu87', '@Nickydo-g1h'}), frozenset({'@hiswayservicesblog9288', '@Vyserane1220', '@babyamyxo-o6c', '@ReggieDahmer', '@TheAllanmeadows'}), frozenset({'@jadelecter', '@majorpwner241', '@josesanchez5981'}), frozenset({'@mang4260', '@jtrain5615', '@Lovyanddovy'}), frozenset({'@mikejunior211', '@jacobking4717', '@Blatsen'}), frozenset({'@BCRivers', '@blitzgerald', '@Kittykitty77729'}), frozenset({'@stephanie3087', '@kennedywestsideshark', '@Blueskies271', '@babyamyxo-o6c', '@tammilee4840'}), frozenset({'@xxkairzzxx1994', '@Chocopie-nr8md', '@ceasarsaran8573'}), frozenset({'@nickytommymancinelli8066', '@the1cardinal', '@jaredkippers8690', '@dope_humor', '@lifeinchina-hainan', '@xxkairzzxx1994', '@timberwolfe1645'}), frozenset({'@AJVillanueva2030', '@xxkairzzxx1994', '@ManJunk7'}), frozenset({'@n4k3d51', '@maryannclementiii-uw5pk', '@xxkairzzxx1994', '@Hollywood-b9f'}), frozenset({'@kurni-cx5do', '@Emptrix', '@sunnam819'}), frozenset({'@itsnick5082', '@RedHall', '@Ceeeeeeeeeeeeeee'}), frozenset({'@jaeminssocks', '@momof7kdz', '@SSheezCrafty'}), frozenset({'@valerieschomburgk4903', '@BryceEdwardBrown', '@annecarter6192', '@George7799-n7b', '@Jayteaseepiirturi'}), frozenset({'@Sgt_Turkigreyvi', '@0_____Miss_Ayesha______', '@MyungngStar'}), frozenset({'@joshhickeysmoviereviews', '@abbeyBominable123', '@jesterfairy3845', '@hsd2 ...
# {'@martinmato8': 0, '@bjnazerigaming8302': 1, '@javiermac381': 2, '@renchuba5509': 3, '@ServiceKusuka': 4, '@nicks9108': 5, '@gisoo_Plx': 6, '@actionman9451': 7, '@VROTIelrastudoLQ': 8, '@Mxchael37': 9, '@JASKIRATSINGHALLGAMING': 10, '@gozyufury': 11, '@louisworld6008': 12, '@Youfuktube': 13, '@missryanswers': 14, '@SitiAisyahUmrah': 15, '@CarlVasconcelos': 16, '@billbill1235': 17, '@Toy_and_Prop_Masters': 18, '@bender9222222222': 19, '@MoostachedSaiyanPrince': 20, '@danmarkaba8809': 21, '@sergiolima444': 22, '@mieta_book': 23, '@syedsaudkazmi': 24, '@alexandralaye41': 25, '@DrJ._.0': 26, '@kiowafourty964': 27, '@joydoodles12': 28, '@Zaytobyghostgod': 29, '@ECIOR-g1i': 30, '@cheese-wtermelon': 31, '@YoussefSable-v2s': 32, '@mysterygirl2635': 33, '@thisisme54': 34, '@Priscillandre': 35, '@abelbelete3935': 36, '@Yuna-j5b': 37, '@Bidiboe': 38, '@rodrickjames8914': 39, '@nerminsoufi9053': 40, '@wilder5': 41, '@Templarswordxx7': 42, '@janadostalova9886': 43, '@lilnahi555': 44, '@Dkzomboi': 45, '@ubaldodelarosa6624': 46, '@fatman-ss7ly': 47, '@pratikshrestha09': 48, '@193ksp': 49, '@elellatwins1424': 50, '@mulugetaayalew6445': 51, '@HasanShabbir-i7i': 52, '@julianjuellz': 53, '@belle-jc8qn': 54, '@marlaschotborgh5350': 55, '@joseroelprovido5133': 56, '@kerko899': 57, '@vikasmate-01': 15, '@faa504': 58, '@barbarareed9308': 59, '@memes4theppl79': 60, '@RookHouse73': 61, '@monicam34': 62, '@RodrigoMamani-vz3gt': 63, '@davidwong7452': 64, '@ywshbsbvshmdkhshmfdbjvwg': 65, '@ekkiazure': 66, '@yc6683': 67, '@Cryptovigilante100': 68, '@dretno': 69, '@keithk5071': 70, '@user-reianei-0': 71, '@darwen923': 72, '@morningstardick5785': 73, '@Wolverine.848': 15, '@MichaelFH7': 74, '@eddierams9516': 75, '@fearlessllama7227': 76, '@LukeFrankGreen': 77, '@victorialandry9280': 78, '@rightangle58': 79, '@eugene5481': 80, '@bearisbear': 81, '@奇源-n2b': 82, '@andretime14': 83, '@vdiddy7549': 84, '@akimohk5340': 85, '@greennick2025': 86, '@annar6394': 87, '@slmfreedom7137': 88, '@TrippyVerse': 89, '@monstersmiled648': 90, '@nanebueno382': 91, '@jduran2008': 92, '@ñàúlåk-l8c': 93, '@missinglink2416': 94, '@nicklee1027': 95, '@user-oq4wz6bt1p': 96, '@Goregreet': 97, '@jossjones3127': 98, '@jomish8719': 99, '@alfiemcqueen': 93, '@C0D97': 100, '@Clyde313X': 101, '@victoralfonsocastrocamaren1659': 102, '@MARTYMCFLY2015-n3s': 103, '@ilkiwi': 104, '@pup1008': 105, '@momiamok-v4y': 106, '@fredriknielsen8791': 107, '@blackkane7675': 105, '@Joe.Jy2025': 15, '@kathrin-mariasamarrastehle6538': 108, '@azul98-q3v0': 109, '@deny_boyohyahoo.comdeny847': 110, '@dragonsflame3777': 111, '@jusadude7162': 112, '@mateodubusdewarnaffe4541': 113, '@コダマンチャンネル-k9s': 114, '@cansidal4635': 115, '@alinotacchino2226': 116, '@burburchacha': 117, '@Blue_Esther': 118, '@modesonjaymanalastas916': 119, '@shauns1321': 120, '@Zyun-rei': 15, '@cristirlenegomes4709': 121, '@joba991': 122, '@faheemahmad3957': 123, '@BradleyHall-th2xu': 124, '@cristiaeneelohbarbosarebol4489': 125, '@tarboll7': 126, '@fabriciobengozi9650Railfan': 127, '@AradAtaeiazimi': 126, '@ajudartebruno': 126, '@ElTivi395': 128, '@GhostGod49': 126, '@Jalapeno2107': 129, '@aaproduction7948': 130, '@shauntiagaskins4655': 126, '@sumotiko': 126, '@MsCookieday': 131, '@petedog1017': 126, '@LegoLump': 132, '@FDR-ww6xz': 133, '@Lionnado': 134, '@yasielsuarez9047': 135, '@ayeshaakhtar4727': 136, '@marcelomatiello77': 137, '@Godrick131': 138, '@liamholton8937': 139, '@jagaloon216': 140, '@Iopthe5': 141, '@DyscoJen': 142, '@FkkfFkkf': 143, '@JL-wf2wp': 144, '@Matti3582': 126, '@LightLand-m4k': 145, '@homeastronaut5228': 146, '@kaylatangaere9912': 147, '@Hue-p1d': 148, '@acidsakurasyrup1106': 149, '@dannyducke': 150, '@ElizabethBaiden-h1h': 126, '@jackjhmc820': 151, '@frankiepadilla947': 126, '@Meilk27': 15, '@Dragon-Lander': 152, '@rebeccamyers5338': 153, '@mandalorianperseus4662': 126, '@Joshua-d1l': 126, '@yeye2848': 126, '@Bbjjij-h4f': 154, '@Akko1': 155, '@R_wir3': 15, '@dominiclacroix9489': 156, '@Yanuaradil': 157, '@alexanderappl ...
# Saving graph to: mod2youtube_reply_graph.graphml

# %%
sFilename = 'youtube_reply_graph.graphml'
replyGraph = nx.readwrite.read_graphml(sFilename)
G_undirected = nx.to_undirected(replyGraph)

partition = community.best_partition(G_undirected)

#drawing
size = float(len(set(partition.values())))
pos = nx.spring_layout(G_undirected)
count = 0.
for com in set(partition.values()) :
    count = count + 1.
    list_nodes = [nodes for nodes in partition.keys() if partition[nodes] == com]
    nx.draw_networkx_nodes(G_undirected, pos, list_nodes, node_size = 20, node_color = str(count / size))


nx.draw_networkx_edges(G_undirected, pos, alpha=0.1)

plt.show()
