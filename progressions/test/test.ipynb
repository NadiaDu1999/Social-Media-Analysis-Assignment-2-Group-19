# %%
import json
import os
import re
from yt_dlp import YoutubeDL

# Utility to extract YouTube video ID from URL
def extract_video_id(url):
    m = re.search(r"v=([^&]+)", url)
    if m:
        return m.group(1)
    m = re.search(r"youtu\.be/([^?&]+)", url)
    if m:
        return m.group(1)
    return None

# Sanitize titles for filenames
def sanitize_filename(name):
    return re.sub(r"[\\\\/:*?\"<>|]", "_", name)

# Load video URLs from JSON search results
def load_video_urls(path):
    with open(path, "r", encoding="utf-8") as f:
        data = json.load(f)
    return [item.get("link") for item in data if item.get("link")]

# Build parent-reply hierarchy in comments
def structure_comments(comments):
    cmap = {c['id']: c for c in comments if c.get('id')}
    roots = []
    for c in comments:
        pid = c.get('parent_id')
        if pid and pid in cmap:
            cmap[pid].setdefault('replies', []).append(c)
        else:
            roots.append(c)
    return roots


def main():
    # Ensure output directory exists
    os.makedirs("output", exist_ok=True)

    # Read URLs
    urls = load_video_urls('videossearch-snowwhite.json')

    for url in urls:
        vid = extract_video_id(url)
        if not vid:
            print(f"Invalid URL skipped: {url}")
            continue
        video_url = f"https://www.youtube.com/watch?v={vid}"

        # Scrape metadata + comments
        ydl_opts = {"getcomments": True}
        with YoutubeDL(ydl_opts) as ydl:
            info = ydl.extract_info(video_url, download=False)

        # Meta fields
        meta = {
            "Title": info.get("title"),
            "Description": info.get("description"),
            "Uploader": info.get("uploader"),
            "View Count": info.get("view_count"),
            "Likes": info.get("like_count"),
            "Dislikes": info.get("dislike_count"),
            "Thumbnail": info.get("thumbnail"),
            "Tags": info.get("tags"),
        }

        # Process comments
        raw = info.get("comments") or []
        comments = []
        for c in raw:
            comments.append({
                "id": c.get("id"),
                "parent_id": c.get("parent"),
                "author": c.get("author"),
                "text": c.get("text"),
            })
        structured = structure_comments(comments)
        meta["Comments"] = structured

        # Statistics
        top_comments = len(structured)
        replies = sum(len(c.get("replies", [])) for c in structured)
        unique_authors = len({c.get("author") for c in comments if c.get("author")})

        # Save JSON
        title_safe = sanitize_filename(info.get("title", vid))
        outfile = os.path.join("output", f"{title_safe}_{vid}.json")
        with open(outfile, "w", encoding="utf-8") as fout:
            json.dump(meta, fout, ensure_ascii=False, indent=2)

        print(f"{outfile}: {top_comments} comments, {replies} replies, {unique_authors} unique authors")

if __name__ == '__main__':
    main()
# Out:
# [youtube] Extracting URL: https://www.youtube.com/watch?v=iV46TJKL8cU
# [youtube] iV46TJKL8cU: Downloading webpage
# [youtube] iV46TJKL8cU: Downloading tv client config
# [youtube] iV46TJKL8cU: Downloading tv player API JSON
# [youtube] iV46TJKL8cU: Downloading ios player API JSON
# [youtube] iV46TJKL8cU: Downloading m3u8 information
# [youtube] Downloading comment section API JSON
# [youtube] Downloading ~125827 comments
# [youtube] Sorting comments by newest first
# [youtube] Downloading comment API JSON page 1 (0/~125827)
# [youtube] Downloading comment API JSON page 2 (20/~125827)
# [youtube] Downloading comment API JSON page 3 (40/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (45/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (47/~125827)
# [youtube]     Downloading comment API JSON reply thread 3 (51/~125827)
# [youtube]     Downloading comment API JSON reply thread 4 (58/~125827)
# [youtube]     Downloading comment API JSON reply thread 5 (66/~125827)
# [youtube] Downloading comment API JSON page 4 (67/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (84/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (86/~125827)
# [youtube] Downloading comment API JSON page 5 (90/~125827)
# [youtube] Downloading comment API JSON page 6 (110/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (124/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (131/~125827)
# [youtube] Downloading comment API JSON page 7 (133/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (142/~125827)
# [youtube] Downloading comment API JSON page 8 (154/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (155/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (163/~125827)
# [youtube]     Downloading comment API JSON reply thread 3 (175/~125827)
# [youtube] Downloading comment API JSON page 9 (180/~125827)
# [youtube] Downloading comment API JSON page 10 (200/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (204/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (207/~125827)
# [youtube]     Downloading comment API JSON reply thread 3 (214/~125827)
# [youtube] Downloading comment API JSON page 11 (223/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (225/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (230/~125827)
# [youtube]     Downloading comment API JSON reply thread 3 (237/~125827)
# [youtube]     Downloading comment API JSON reply thread 4 (240/~125827)
# [youtube]     Downloading comment API JSON reply thread 5 (245/~125827)
# [youtube]     Downloading comment API JSON reply thread 6 (248/~125827)
# [youtube] Downloading comment API JSON page 12 (249/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (254/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (259/~125827)
# [youtube]     Downloading comment API JSON reply thread 3 (262/~125827)
# [youtube]     Downloading comment API JSON reply thread 4 (264/~125827)
# [youtube]     Downloading comment API JSON reply thread 5 (275/~125827)
# [youtube] Downloading comment API JSON page 13 (276/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (284/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (290/~125827)
# [youtube] Downloading comment API JSON page 14 (299/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (308/~125827)
# [youtube] Downloading comment API JSON page 15 (320/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (328/~125827)
# [youtube] Downloading comment API JSON page 16 (341/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (346/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (357/~125827)
# [youtube] Downloading comment API JSON page 17 (364/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (369/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (377/~125827)
# [youtube] Downloading comment API JSON page 18 (388/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (391/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (401/~125827)
# [youtube] Downloading comment API JSON page 19 (410/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (413/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (424/~125827)
# [youtube] Downloading comment API JSON page 20 (432/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (439/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (451/~125827)
# [youtube] Downloading comment API JSON page 21 (454/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (457/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (459/~125827)
# [youtube]     Downloading comment API JSON reply thread 3 (466/~125827)
# [youtube]     Downloading comment API JSON reply thread 4 (471/~125827)
# [youtube]     Downloading comment API JSON reply thread 5 (475/~125827)
# [youtube]     Downloading comment API JSON reply thread 6 (477/~125827)
# [youtube] Downloading comment API JSON page 22 (483/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (486/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (494/~125827)
# [youtube] Downloading comment API JSON page 23 (505/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (510/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (515/~125827)
# [youtube] Downloading comment API JSON page 24 (527/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (545/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (547/~125827)
# [youtube] Downloading comment API JSON page 25 (549/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (551/~125827)
# [youtube] Downloading comment API JSON page 26 (570/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (583/~125827)
# [youtube] Downloading comment API JSON page 27 (591/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (592/~125827)
# [youtube] Downloading comment API JSON page 28 (614/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (623/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (631/~125827)
# [youtube] Downloading comment API JSON page 29 (638/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (643/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (647/~125827)
# [youtube]     Downloading comment API JSON reply thread 3 (661/~125827)
# [youtube] Downloading comment API JSON page 30 (670/~125827)
# [youtube] Downloading comment API JSON page 31 (690/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (694/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (706/~125827)
# [youtube] Downloading comment API JSON page 32 (712/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (717/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (725/~125827)
# [youtube]     Downloading comment API JSON reply thread 3 (729/~125827)
# [youtube]     Downloading comment API JSON reply thread 4 (732/~125827)
# [youtube]        Downloading comment replies API JSON page 1 (742/~125827)
# [youtube]     Downloading comment API JSON reply thread 5 (747/~125827)
# [youtube] Downloading comment API JSON page 33 (749/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (750/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (753/~125827)
# [youtube]     Downloading comment API JSON reply thread 3 (755/~125827)
# [youtube]     Downloading comment API JSON reply thread 4 (757/~125827)
# [youtube]     Downloading comment API JSON reply thread 5 (769/~125827)
# [youtube]     Downloading comment API JSON reply thread 6 (771/~125827)
# [youtube] Downloading comment API JSON page 34 (775/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (779/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (782/~125827)
# [youtube] Downloading comment API JSON page 35 (798/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (806/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (813/~125827)
# [youtube] Downloading comment API JSON page 36 (821/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (837/~125827)
# [youtube] Downloading comment API JSON page 37 (842/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (854/~125827)
# [youtube] Downloading comment API JSON page 38 (863/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (870/~125827)
# [youtube] Downloading comment API JSON page 39 (885/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (893/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (904/~125827)
# [youtube] Downloading comment API JSON page 40 (907/~125827)
# [youtube] Downloading comment API JSON page 41 (927/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (939/~125827)
# [youtube] Downloading comment API JSON page 42 (950/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (952/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (956/~125827)
# [youtube]     Downloading comment API JSON reply thread 3 (967/~125827)
# [youtube]     Downloading comment API JSON reply thread 4 (980/~125827)
# [youtube]     Downloading comment API JSON reply thread 5 (982/~125827)
# [youtube] Downloading comment API JSON page 43 (983/~125827)
# [youtube] Downloading comment API JSON page 44 (1003/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (1009/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (1019/~125827)
# [youtube]     Downloading comment API JSON reply thread 3 (1027/~125827)
# [youtube]     Downloading comment API JSON reply thread 4 (1033/~125827)
# [youtube]     Downloading comment API JSON reply thread 5 (1037/~125827)
# [youtube] Downloading comment API JSON page 45 (1038/~125827)
# [youtube] Downloading comment API JSON page 46 (1058/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (1061/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (1066/~125827)
# [youtube]     Downloading comment API JSON reply thread 3 (1070/~125827)
# [youtube]     Downloading comment API JSON reply thread 4 (1079/~125827)
# [youtube] Downloading comment API JSON page 47 (1084/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (1100/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (1105/~125827)
# [youtube] Downloading comment API JSON page 48 (1106/~125827)
# [youtube] Downloading comment API JSON page 49 (1126/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (1141/~125827)
# [youtube] Downloading comment API JSON page 50 (1147/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (1156/~125827)
# [youtube] Downloading comment API JSON page 51 (1174/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (1179/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (1189/~125827)
# [youtube]     Downloading comment API JSON reply thread 3 (1195/~125827)
# [youtube] Downloading comment API JSON page 52 (1197/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (1204/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (1210/~125827)
# [youtube]     Downloading comment API JSON reply thread 3 (1216/~125827)
# [youtube] Downloading comment API JSON page 53 (1226/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (1236/~125827)
# [youtube] Downloading comment API JSON page 54 (1247/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (1262/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (1269/~125827)
# [youtube] Downloading comment API JSON page 55 (1270/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (1275/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (1293/~125827)
# [youtube]     Downloading comment API JSON reply thread 3 (1297/~125827)
# [youtube]     Downloading comment API JSON reply thread 4 (1302/~125827)
# [youtube] Downloading comment API JSON page 56 (1304/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (1306/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (1316/~125827)
# [youtube] Downloading comment API JSON page 57 (1328/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (1331/~125827)
# [youtube] Downloading comment API JSON page 58 (1350/~125827)
# [youtube] Downloading comment API JSON page 59 (1370/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (1377/~125827)
# [youtube] Downloading comment API JSON page 60 (1391/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (1398/~125827)
# [youtube] Downloading comment API JSON page 61 (1412/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (1425/~125827)
# [youtube] Downloading comment API JSON page 62 (1434/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (1442/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (1449/~125827)
# [youtube] Downloading comment API JSON page 63 (1456/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (1468/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (1480/~125827)
# [youtube] Downloading comment API JSON page 64 (1482/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (1487/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (1489/~125827)
# [youtube] Downloading comment API JSON page 65 (1505/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (1509/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (1513/~125827)
# [youtube]     Downloading comment API JSON reply thread 3 (1521/~125827)
# [youtube]     Downloading comment API JSON reply thread 4 (1523/~125827)
# [youtube] Downloading comment API JSON page 66 (1530/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (1545/~125827)
# [youtube] Downloading comment API JSON page 67 (1551/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (1561/~125827)
# [youtube] Downloading comment API JSON page 68 (1572/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (1587/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (1590/~125827)
# [youtube] Downloading comment API JSON page 69 (1596/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (1598/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (1605/~125827)
# [youtube] Downloading comment API JSON page 70 (1620/~125827)
# [youtube] Downloading comment API JSON page 71 (1640/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (1646/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (1657/~125827)
# [youtube]     Downloading comment API JSON reply thread 3 (1659/~125827)
# [youtube]     Downloading comment API JSON reply thread 4 (1661/~125827)
# [youtube]     Downloading comment API JSON reply thread 5 (1666/~125827)
# [youtube] Downloading comment API JSON page 72 (1667/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (1673/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (1676/~125827)
# [youtube]     Downloading comment API JSON reply thread 3 (1685/~125827)
# [youtube] Downloading comment API JSON page 73 (1696/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (1705/~125827)
# [youtube] Downloading comment API JSON page 74 (1720/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (1724/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (1728/~125827)
# [youtube]     Downloading comment API JSON reply thread 3 (1741/~125827)
# [youtube] Downloading comment API JSON page 75 (1744/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (1759/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (1768/~125827)
# [youtube] Downloading comment API JSON page 76 (1773/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (1784/~125827)
# [youtube] Downloading comment API JSON page 77 (1796/~125827)
# [youtube] Downloading comment API JSON page 78 (1816/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (1819/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (1824/~125827)
# [youtube]     Downloading comment API JSON reply thread 3 (1832/~125827)
# [youtube]     Downloading comment API JSON reply thread 4 (1835/~125827)
# [youtube] Downloading comment API JSON page 79 (1841/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (1843/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (1857/~125827)
# [youtube]     Downloading comment API JSON reply thread 3 (1866/~125827)
# [youtube]     Downloading comment API JSON reply thread 4 (1872/~125827)
# [youtube] Downloading comment API JSON page 80 (1875/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (1877/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (1883/~125827)
# [youtube]     Downloading comment API JSON reply thread 3 (1893/~125827)
# [youtube]     Downloading comment API JSON reply thread 4 (1895/~125827)
# [youtube] Downloading comment API JSON page 81 (1900/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (1901/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (1909/~125827)
# [youtube]     Downloading comment API JSON reply thread 3 (1918/~125827)
# [youtube] Downloading comment API JSON page 82 (1923/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (1941/~125827)
# [youtube] Downloading comment API JSON page 83 (1947/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (1961/~125827)
# [youtube] Downloading comment API JSON page 84 (1968/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (1984/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (1986/~125827)
# [youtube]     Downloading comment API JSON reply thread 3 (1990/~125827)
# [youtube]     Downloading comment API JSON reply thread 4 (1993/~125827)
# [youtube] Downloading comment API JSON page 85 (2003/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (2012/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (2022/~125827)
# [youtube]     Downloading comment API JSON reply thread 3 (2025/~125827)
# [youtube] Downloading comment API JSON page 86 (2036/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (2040/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (2061/~125827)
# [youtube]     Downloading comment API JSON reply thread 3 (2065/~125827)
# [youtube] Downloading comment API JSON page 87 (2066/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (2069/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (2072/~125827)
# [youtube]     Downloading comment API JSON reply thread 3 (2075/~125827)
# [youtube]     Downloading comment API JSON reply thread 4 (2080/~125827)
# [youtube]     Downloading comment API JSON reply thread 5 (2083/~125827)
# [youtube] Downloading comment API JSON page 88 (2093/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (2101/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (2106/~125827)
# [youtube]     Downloading comment API JSON reply thread 3 (2108/~125827)
# [youtube]     Downloading comment API JSON reply thread 4 (2114/~125827)
# [youtube] Downloading comment API JSON page 89 (2123/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (2129/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (2135/~125827)
# [youtube]     Downloading comment API JSON reply thread 3 (2138/~125827)
# [youtube] Downloading comment API JSON page 90 (2147/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (2154/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (2157/~125827)
# [youtube]     Downloading comment API JSON reply thread 3 (2169/~125827)
# [youtube]     Downloading comment API JSON reply thread 4 (2172/~125827)
# [youtube] Downloading comment API JSON page 91 (2179/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (2182/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (2185/~125827)
# [youtube]     Downloading comment API JSON reply thread 3 (2188/~125827)
# [youtube]     Downloading comment API JSON reply thread 4 (2194/~125827)
# [youtube]     Downloading comment API JSON reply thread 5 (2201/~125827)
# [youtube] Downloading comment API JSON page 92 (2207/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (2209/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (2214/~125827)
# [youtube]     Downloading comment API JSON reply thread 3 (2223/~125827)
# [youtube]     Downloading comment API JSON reply thread 4 (2228/~125827)
# [youtube] Downloading comment API JSON page 93 (2247/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (2255/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (2257/~125827)
# [youtube]     Downloading comment API JSON reply thread 3 (2267/~125827)
# [youtube] Downloading comment API JSON page 94 (2274/~125827)
# [youtube] Downloading comment API JSON page 95 (2294/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (2295/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (2306/~125827)
# [youtube]     Downloading comment API JSON reply thread 3 (2309/~125827)
# [youtube] Downloading comment API JSON page 96 (2318/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (2319/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (2333/~125827)
# [youtube] Downloading comment API JSON page 97 (2341/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (2343/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (2349/~125827)
# [youtube]     Downloading comment API JSON reply thread 3 (2364/~125827)
# [youtube] Downloading comment API JSON page 98 (2367/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (2371/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (2375/~125827)
# [youtube]     Downloading comment API JSON reply thread 3 (2377/~125827)
# [youtube]     Downloading comment API JSON reply thread 4 (2382/~125827)
# [youtube]     Downloading comment API JSON reply thread 5 (2388/~125827)
# [youtube]        Downloading comment replies API JSON page 1 (2398/~125827)
# [youtube]     Downloading comment API JSON reply thread 6 (2442/~125827)
# [youtube] Downloading comment API JSON page 99 (2446/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (2447/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (2453/~125827)
# [youtube]     Downloading comment API JSON reply thread 3 (2456/~125827)
# [youtube]     Downloading comment API JSON reply thread 4 (2459/~125827)
# [youtube]     Downloading comment API JSON reply thread 5 (2470/~125827)
# [youtube]     Downloading comment API JSON reply thread 6 (2474/~125827)
# [youtube] Downloading comment API JSON page 100 (2475/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (2488/~125827)
# [youtube] Downloading comment API JSON page 101 (2496/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (2501/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (2511/~125827)
# [youtube]     Downloading comment API JSON reply thread 3 (2518/~125827)
# [youtube] Downloading comment API JSON page 102 (2522/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (2528/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (2535/~125827)
# [youtube]     Downloading comment API JSON reply thread 3 (2541/~125827)
# [youtube]     Downloading comment API JSON reply thread 4 (2543/~125827)
# [youtube] Downloading comment API JSON page 103 (2546/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (2558/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (2561/~125827)
# [youtube] Downloading comment API JSON page 104 (2570/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (2580/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (2586/~125827)
# [youtube] Downloading comment API JSON page 105 (2594/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (2597/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (2604/~125827)
# [youtube]     Downloading comment API JSON reply thread 3 (2608/~125827)
# [youtube] Downloading comment API JSON page 106 (2618/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (2624/~125827)
# [youtube] Downloading comment API JSON page 107 (2640/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (2646/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (2654/~125827)
# [youtube]     Downloading comment API JSON reply thread 3 (2661/~125827)
# [youtube] Downloading comment API JSON page 108 (2665/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (2670/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (2683/~125827)
# [youtube] Downloading comment API JSON page 109 (2689/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (2696/~125827)
# [youtube]        Downloading comment replies API JSON page 1 (2706/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (2715/~125827)
# [youtube]     Downloading comment API JSON reply thread 3 (2718/~125827)
# [youtube] Downloading comment API JSON page 110 (2725/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (2730/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (2737/~125827)
# [youtube]     Downloading comment API JSON reply thread 3 (2749/~125827)
# [youtube] Downloading comment API JSON page 111 (2751/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (2753/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (2756/~125827)
# [youtube]     Downloading comment API JSON reply thread 3 (2773/~125827)
# [youtube] Downloading comment API JSON page 112 (2777/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (2778/~125827)
# [youtube] Downloading comment API JSON page 113 (2799/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (2817/~125827)
# [youtube] Downloading comment API JSON page 114 (2820/~125827)
# [youtube] Downloading comment API JSON page 115 (2840/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (2847/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (2866/~125827)
# [youtube] Downloading comment API JSON page 116 (2868/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (2869/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (2878/~125827)
# [youtube]     Downloading comment API JSON reply thread 3 (2882/~125827)
# [youtube]     Downloading comment API JSON reply thread 4 (2891/~125827)
# [youtube]     Downloading comment API JSON reply thread 5 (2893/~125827)
# [youtube] Downloading comment API JSON page 117 (2895/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (2910/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (2919/~125827)
# [youtube] Downloading comment API JSON page 118 (2922/~125827)
# [youtube] Downloading comment API JSON page 119 (2942/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (2943/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (2949/~125827)
# [youtube]     Downloading comment API JSON reply thread 3 (2957/~125827)
# [youtube] Downloading comment API JSON page 120 (2965/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (2973/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (2979/~125827)
# [youtube]     Downloading comment API JSON reply thread 3 (2985/~125827)
# [youtube] Downloading comment API JSON page 121 (2990/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (2996/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (3002/~125827)
# [youtube] Downloading comment API JSON page 122 (3014/~125827)
# [youtube] Downloading comment API JSON page 123 (3034/~125827)
# [youtube] Downloading comment API JSON page 124 (3054/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (3058/~125827)
# [youtube] Downloading comment API JSON page 125 (3075/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (3076/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (3082/~125827)
# [youtube]     Downloading comment API JSON reply thread 3 (3085/~125827)
# [youtube] Downloading comment API JSON page 126 (3098/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (3106/~125827)
# [youtube] Downloading comment API JSON page 127 (3119/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (3124/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (3128/~125827)
# [youtube]     Downloading comment API JSON reply thread 3 (3143/~125827)
# [youtube] Downloading comment API JSON page 128 (3144/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (3145/~125827)
# [youtube] Downloading comment API JSON page 129 (3166/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (3167/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (3180/~125827)
# [youtube] Downloading comment API JSON page 130 (3189/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (3203/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (3205/~125827)
# [youtube] Downloading comment API JSON page 131 (3211/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (3212/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (3221/~125827)
# [youtube] Downloading comment API JSON page 132 (3234/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (3240/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (3252/~125827)
# [youtube] Downloading comment API JSON page 133 (3263/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (3277/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (3283/~125827)
# [youtube] Downloading comment API JSON page 134 (3285/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (3301/~125827)
# [youtube] Downloading comment API JSON page 135 (3306/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (3309/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (3314/~125827)
# [youtube]     Downloading comment API JSON reply thread 3 (3319/~125827)
# [youtube]     Downloading comment API JSON reply thread 4 (3324/~125827)
# [youtube]        Downloading comment replies API JSON page 1 (3334/~125827)
# [youtube] Downloading comment API JSON page 136 (3340/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (3344/~125827)
# [youtube] Downloading comment API JSON page 137 (3361/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (3381/~125827)
# [youtube] Downloading comment API JSON page 138 (3382/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (3386/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (3395/~125827)
# [youtube] Downloading comment API JSON page 139 (3404/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (3411/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (3415/~125827)
# [youtube]     Downloading comment API JSON reply thread 3 (3422/~125827)
# [youtube] Downloading comment API JSON page 140 (3427/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (3437/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (3442/~125827)
# [youtube] Downloading comment API JSON page 141 (3449/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (3452/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (3466/~125827)
# [youtube]     Downloading comment API JSON reply thread 3 (3471/~125827)
# [youtube] Downloading comment API JSON page 142 (3473/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (3488/~125827)
# [youtube] Downloading comment API JSON page 143 (3495/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (3496/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (3501/~125827)
# [youtube]     Downloading comment API JSON reply thread 3 (3514/~125827)
# [youtube] Downloading comment API JSON page 144 (3520/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (3529/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (3538/~125827)
# [youtube] Downloading comment API JSON page 145 (3542/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (3545/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (3549/~125827)
# [youtube] Downloading comment API JSON page 146 (3564/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (3573/~125827)
# [youtube] Downloading comment API JSON page 147 (3587/~125827)
# [youtube] Downloading comment API JSON page 148 (3607/~125827)
# [youtube] Downloading comment API JSON page 149 (3627/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (3630/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (3644/~125827)
# [youtube]     Downloading comment API JSON reply thread 3 (3653/~125827)
# [youtube] Downloading comment API JSON page 150 (3656/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (3670/~125827)
# [youtube] Downloading comment API JSON page 151 (3680/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (3695/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (3700/~125827)
# [youtube] Downloading comment API JSON page 152 (3702/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (3705/~125827)
# [youtube] Downloading comment API JSON page 153 (3724/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (3727/~125827)
# [youtube] Downloading comment API JSON page 154 (3746/~125827)
# [youtube] Downloading comment API JSON page 155 (3766/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (3767/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (3783/~125827)
# [youtube] Downloading comment API JSON page 156 (3788/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (3797/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (3815/~125827)
# [youtube] Downloading comment API JSON page 157 (3817/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (3828/~125827)
# [youtube] Downloading comment API JSON page 158 (3838/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (3843/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (3850/~125827)
# [youtube] Downloading comment API JSON page 159 (3870/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (3874/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (3882/~125827)
# [youtube] Downloading comment API JSON page 160 (3895/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (3899/~125827)
# [youtube] Downloading comment API JSON page 161 (3916/~125827)
# [youtube] Downloading comment API JSON page 162 (3936/~125827)
# [youtube] Downloading comment API JSON page 163 (3956/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (3959/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (3961/~125827)
# [youtube] Downloading comment API JSON page 164 (3978/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (3984/~125827)
# [youtube] Downloading comment API JSON page 165 (4000/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (4008/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (4016/~125827)
# [youtube] Downloading comment API JSON page 166 (4022/~125827)
# [youtube] Downloading comment API JSON page 167 (4042/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (4049/~125827)
# [youtube] Downloading comment API JSON page 168 (4063/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (4064/~125827)
# [youtube] Downloading comment API JSON page 169 (4084/~125827)
# [youtube] Downloading comment API JSON page 170 (4104/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (4112/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (4121/~125827)
# [youtube]     Downloading comment API JSON reply thread 3 (4126/~125827)
# [youtube] Downloading comment API JSON page 171 (4127/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (4139/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (4148/~125827)
# [youtube] Downloading comment API JSON page 172 (4149/~125827)
# [youtube] Downloading comment API JSON page 173 (4169/~125827)
# [youtube] Downloading comment API JSON page 174 (4189/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (4204/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (4210/~125827)
# [youtube] Downloading comment API JSON page 175 (4213/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (4215/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (4222/~125827)
# [youtube]     Downloading comment API JSON reply thread 3 (4233/~125827)
# [youtube]     Downloading comment API JSON reply thread 4 (4235/~125827)
# [youtube] Downloading comment API JSON page 176 (4237/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (4254/~125827)
# [youtube] Downloading comment API JSON page 177 (4258/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (4262/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (4267/~125827)
# [youtube]     Downloading comment API JSON reply thread 3 (4278/~125827)
# [youtube]     Downloading comment API JSON reply thread 4 (4282/~125827)
# [youtube] Downloading comment API JSON page 178 (4292/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (4294/~125827)
# [youtube]        Downloading comment replies API JSON page 1 (4304/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (4318/~125827)
# [youtube]        Downloading comment replies API JSON page 1 (4328/~125827)
# [youtube] Downloading comment API JSON page 179 (4344/~125827)
# [youtube] Downloading comment API JSON page 180 (4364/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (4377/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (4381/~125827)
# [youtube] Downloading comment API JSON page 181 (4387/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (4397/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (4408/~125827)
# [youtube] Downloading comment API JSON page 182 (4410/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (4415/~125827)
# [youtube] Downloading comment API JSON page 183 (4431/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (4446/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (4452/~125827)
# [youtube] Downloading comment API JSON page 184 (4454/~125827)
# [youtube] Downloading comment API JSON page 185 (4474/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (4480/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (4484/~125827)
# [youtube]     Downloading comment API JSON reply thread 3 (4486/~125827)
# [youtube]     Downloading comment API JSON reply thread 4 (4493/~125827)
# [youtube]     Downloading comment API JSON reply thread 5 (4495/~125827)
# [youtube] Downloading comment API JSON page 186 (4505/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (4514/~125827)
# [youtube] Downloading comment API JSON page 187 (4527/~125827)
# [youtube] Downloading comment API JSON page 188 (4547/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (4558/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (4565/~125827)
# [youtube]     Downloading comment API JSON reply thread 3 (4574/~125827)
# [youtube] Downloading comment API JSON page 189 (4577/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (4586/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (4589/~125827)
# [youtube] Downloading comment API JSON page 190 (4602/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (4604/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (4607/~125827)
# [youtube]     Downloading comment API JSON reply thread 3 (4611/~125827)
# [youtube]     Downloading comment API JSON reply thread 4 (4613/~125827)
# [youtube] Downloading comment API JSON page 191 (4628/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (4636/~125827)
# [youtube] Downloading comment API JSON page 192 (4651/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (4653/~125827)
# [youtube] Downloading comment API JSON page 193 (4679/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (4684/~125827)
# [youtube] Downloading comment API JSON page 194 (4702/~125827)
# [youtube] Downloading comment API JSON page 195 (4722/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (4725/~125827)
# [youtube] Downloading comment API JSON page 196 (4744/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (4753/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (4760/~125827)
# [youtube] Downloading comment API JSON page 197 (4769/~125827)
# [youtube] Downloading comment API JSON page 198 (4789/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (4800/~125827)
# [youtube] Downloading comment API JSON page 199 (4810/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (4819/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (4823/~125827)
# [youtube] Downloading comment API JSON page 200 (4833/~125827)
# [youtube] Downloading comment API JSON page 201 (4853/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (4856/~125827)
# [youtube] Downloading comment API JSON page 202 (4874/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (4881/~125827)
# [youtube] Downloading comment API JSON page 203 (4895/~125827)
# [youtube] Downloading comment API JSON page 204 (4915/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (4918/~125827)
# [youtube] Downloading comment API JSON page 205 (4936/~125827)
# [youtube] Downloading comment API JSON page 206 (4956/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (4963/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (4977/~125827)
# [youtube] Downloading comment API JSON page 207 (4979/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (4987/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (4989/~125827)
# [youtube]     Downloading comment API JSON reply thread 3 (4995/~125827)
# [youtube] Downloading comment API JSON page 208 (5005/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (5020/~125827)
# [youtube] Downloading comment API JSON page 209 (5026/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (5043/~125827)
# [youtube] Downloading comment API JSON page 210 (5047/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (5050/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (5056/~125827)
# [youtube]     Downloading comment API JSON reply thread 3 (5059/~125827)
# [youtube]     Downloading comment API JSON reply thread 4 (5072/~125827)
# [youtube] Downloading comment API JSON page 211 (5073/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (5078/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (5084/~125827)
# [youtube]     Downloading comment API JSON reply thread 3 (5086/~125827)
# [youtube]     Downloading comment API JSON reply thread 4 (5089/~125827)
# [youtube]        Downloading comment replies API JSON page 1 (5099/~125827)
# [youtube] Downloading comment API JSON page 212 (5118/~125827)
# [youtube] Downloading comment API JSON page 213 (5138/~125827)
# [youtube] Downloading comment API JSON page 214 (5158/~125827)
# [youtube] Downloading comment API JSON page 215 (5178/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (5188/~125827)
# [youtube] Downloading comment API JSON page 216 (5199/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (5201/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (5209/~125827)
# [youtube]     Downloading comment API JSON reply thread 3 (5212/~125827)
# [youtube] Downloading comment API JSON page 217 (5222/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (5223/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (5232/~125827)
# [youtube] Downloading comment API JSON page 218 (5244/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (5262/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (5264/~125827)
# [youtube]     Downloading comment API JSON reply thread 3 (5266/~125827)
# [youtube] Downloading comment API JSON page 219 (5267/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (5273/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (5281/~125827)
# [youtube] Downloading comment API JSON page 220 (5291/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (5299/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (5307/~125827)
# [youtube] Downloading comment API JSON page 221 (5318/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (5321/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (5330/~125827)
# [youtube]     Downloading comment API JSON reply thread 3 (5338/~125827)
# [youtube] Downloading comment API JSON page 222 (5347/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (5351/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (5356/~125827)
# [youtube]     Downloading comment API JSON reply thread 3 (5362/~125827)
# [youtube]     Downloading comment API JSON reply thread 4 (5370/~125827)
# [youtube] Downloading comment API JSON page 223 (5371/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (5372/~125827)
# [youtube]        Downloading comment replies API JSON page 1 (5382/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (5396/~125827)
# [youtube] Downloading comment API JSON page 224 (5407/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (5409/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (5412/~125827)
# [youtube] Downloading comment API JSON page 225 (5429/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (5440/~125827)
# [youtube] Downloading comment API JSON page 226 (5450/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (5454/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (5468/~125827)
# [youtube] Downloading comment API JSON page 227 (5472/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (5477/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (5489/~125827)
# [youtube] Downloading comment API JSON page 228 (5495/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (5505/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (5515/~125827)
# [youtube] Downloading comment API JSON page 229 (5517/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (5531/~125827)
# [youtube] Downloading comment API JSON page 230 (5539/~125827)
# [youtube]     Downloading comment API JSON reply thread 1 (5541/~125827)
# [youtube]     Downloading comment API JSON reply thread 2 (5545/~125827)
# ...
# [youtube] Downloading comment API JSON page 186 (4390/~7065)
# [youtube]     Downloading comment API JSON reply thread 1 (4400/~7065)
# [youtube]        Downloading comment replies API JSON page 1 (4410/~7065)
# [youtube]     Downloading comment API JSON reply thread 2 (4417/~7065)
# [youtube]     Downloading comment API JSON reply thread 3 (4419/~7065)
# [youtube]     Downloading comment API JSON reply thread 4 (4431/~7065)
# [youtube] Downloading comment API JSON page 187 (4435/~7065)
# [youtube]     Downloading comment API JSON reply thread 1 (4436/~7065)
# [youtube]     Downloading comment API JSON reply thread 2 (4441/~7065)
# [youtube] Downloading comment API JSON page 188 (4460/~7065)
# [youtube]     Downloading comment API JSON reply thread 1 (4476/~7065)
# [youtube] Downloading comment API JSON page 189 (4482/~7065)
# [youtube]     Downloading comment API JSON reply thread 1 (4499/~7065)
# [youtube] Downloading comment API JSON page 190 (4503/~7065)
# [youtube]     Downloading comment API JSON reply thread 1 (4509/~7065)
# [youtube]     Downloading comment API JSON reply thread 2 (4523/~7065)
# [youtube] Downloading comment API JSON page 191 (4525/~7065)
# [youtube]     Downloading comment API JSON reply thread 1 (4528/~7065)
# [youtube] Downloading comment API JSON page 192 (4546/~7065)
# [youtube] Downloading comment API JSON page 193 (4566/~7065)
# [youtube]     Downloading comment API JSON reply thread 1 (4577/~7065)
# [youtube]     Downloading comment API JSON reply thread 2 (4579/~7065)
# [youtube]     Downloading comment API JSON reply thread 3 (4581/~7065)
# [youtube]     Downloading comment API JSON reply thread 4 (4584/~7065)
# [youtube]     Downloading comment API JSON reply thread 5 (4588/~7065)
# [youtube] Downloading comment API JSON page 194 (4595/~7065)
# [youtube]     Downloading comment API JSON reply thread 1 (4602/~7065)
# [youtube] Downloading comment API JSON page 195 (4618/~7065)
# [youtube]     Downloading comment API JSON reply thread 1 (4625/~7065)
# [youtube] Downloading comment API JSON page 196 (4643/~7065)
# [youtube]     Downloading comment API JSON reply thread 1 (4658/~7065)
# [youtube] Downloading comment API JSON page 197 (4664/~7065)
# [youtube]     Downloading comment API JSON reply thread 1 (4671/~7065)
# [youtube]     Downloading comment API JSON reply thread 2 (4680/~7065)
# [youtube]     Downloading comment API JSON reply thread 3 (4684/~7065)
# [youtube] Downloading comment API JSON page 198 (4687/~7065)
# [youtube] Downloading comment API JSON page 199 (4707/~7065)
# [youtube] Downloading comment API JSON page 200 (4727/~7065)
# [youtube]     Downloading comment API JSON reply thread 1 (4732/~7065)
# [youtube] Downloading comment API JSON page 201 (4752/~7065)
# [youtube]     Downloading comment API JSON reply thread 1 (4754/~7065)
# [youtube] Downloading comment API JSON page 202 (4773/~7065)
# [youtube]     Downloading comment API JSON reply thread 1 (4774/~7065)
# [youtube]        Downloading comment replies API JSON page 1 (4784/~7065)
# [youtube]        Downloading comment replies API JSON page 2 (4834/~7065)
# [youtube]        Downloading comment replies API JSON page 3 (4884/~7065)
# [youtube]     Downloading comment API JSON reply thread 2 (4916/~7065)
# [youtube]     Downloading comment API JSON reply thread 3 (4926/~7065)
# [youtube] Downloading comment API JSON page 203 (4933/~7065)
# [youtube]     Downloading comment API JSON reply thread 1 (4951/~7065)
# [youtube] Downloading comment API JSON page 204 (4954/~7065)
# [youtube]     Downloading comment API JSON reply thread 1 (4961/~7065)
# [youtube]     Downloading comment API JSON reply thread 2 (4973/~7065)
# [youtube] Downloading comment API JSON page 205 (4978/~7065)
# [youtube]     Downloading comment API JSON reply thread 1 (4997/~7065)
# [youtube] Downloading comment API JSON page 206 (4999/~7065)
# [youtube]     Downloading comment API JSON reply thread 1 (5018/~7065)
# [youtube] Downloading comment API JSON page 207 (5020/~7065)
# [youtube]     Downloading comment API JSON reply thread 1 (5037/~7065)
# [youtube] Downloading comment API JSON page 208 (5041/~7065)
# [youtube] Downloading comment API JSON page 209 (5061/~7065)
# [youtube]     Downloading comment API JSON reply thread 1 (5071/~7065)
# [youtube]     Downloading comment API JSON reply thread 2 (5078/~7065)
# [youtube] Downloading comment API JSON page 210 (5088/~7065)
# [youtube] Downloading comment API JSON page 211 (5108/~7065)
# [youtube]     Downloading comment API JSON reply thread 1 (5116/~7065)
# [youtube]        Downloading comment replies API JSON page 1 (5126/~7065)
# [youtube] Downloading comment API JSON page 212 (5144/~7065)
# [youtube]     Downloading comment API JSON reply thread 1 (5161/~7065)
# [youtube] Downloading comment API JSON page 213 (5166/~7065)
# [youtube]     Downloading comment API JSON reply thread 1 (5170/~7065)
# [youtube]     Downloading comment API JSON reply thread 2 (5174/~7065)
# [youtube]        Downloading comment replies API JSON page 1 (5184/~7065)
# [youtube] Downloading comment API JSON page 214 (5232/~7065)
# [youtube]     Downloading comment API JSON reply thread 1 (5234/~7065)
# [youtube]     Downloading comment API JSON reply thread 2 (5237/~7065)
# [youtube]     Downloading comment API JSON reply thread 3 (5241/~7065)
# [youtube] Downloading comment API JSON page 215 (5256/~7065)
# [youtube] Downloading comment API JSON page 216 (5276/~7065)
# [youtube] Downloading comment API JSON page 217 (5296/~7065)
# [youtube]     Downloading comment API JSON reply thread 1 (5300/~7065)
# [youtube]     Downloading comment API JSON reply thread 2 (5315/~7065)
# [youtube] Downloading comment API JSON page 218 (5319/~7065)
# [youtube] Downloading comment API JSON page 219 (5339/~7065)
# [youtube]     Downloading comment API JSON reply thread 1 (5343/~7065)
# [youtube] Downloading comment API JSON page 220 (5360/~7065)
# [youtube]     Downloading comment API JSON reply thread 1 (5379/~7065)
# [youtube] Downloading comment API JSON page 221 (5388/~7065)
# [youtube]     Downloading comment API JSON reply thread 1 (5406/~7065)
# [youtube] Downloading comment API JSON page 222 (5410/~7065)
# [youtube] Downloading comment API JSON page 223 (5430/~7065)
# [youtube] Downloading comment API JSON page 224 (5450/~7065)
# [youtube]     Downloading comment API JSON reply thread 1 (5460/~7065)
# [youtube]        Downloading comment replies API JSON page 1 (5470/~7065)
# [youtube] Downloading comment API JSON page 225 (5497/~7065)
# [youtube]     Downloading comment API JSON reply thread 1 (5514/~7065)
# [youtube]     Downloading comment API JSON reply thread 2 (5521/~7065)
# [youtube] Downloading comment API JSON page 226 (5523/~7065)
# [youtube]     Downloading comment API JSON reply thread 1 (5539/~7065)
# [youtube] Downloading comment API JSON page 227 (5545/~7065)
# [youtube]     Downloading comment API JSON reply thread 1 (5550/~7065)
# [youtube] Downloading comment API JSON page 228 (5566/~7065)
# [youtube]     Downloading comment API JSON reply thread 1 (5581/~7065)
# [youtube] Downloading comment API JSON page 229 (5587/~7065)
# [youtube]     Downloading comment API JSON reply thread 1 (5588/~7065)
# [youtube]     Downloading comment API JSON reply thread 2 (5598/~7065)
# [youtube]     Downloading comment API JSON reply thread 3 (5604/~7065)
# [youtube] Downloading comment API JSON page 230 (5610/~7065)
# [youtube]     Downloading comment API JSON reply thread 1 (5618/~7065)
# [youtube]     Downloading comment API JSON reply thread 2 (5623/~7065)
# [youtube]        Downloading comment replies API JSON page 1 (5633/~7065)
# [youtube]     Downloading comment API JSON reply thread 3 (5676/~7065)
# [youtube] Downloading comment API JSON page 231 (5680/~7065)
# [youtube]     Downloading comment API JSON reply thread 1 (5699/~7065)
# [youtube] Downloading comment API JSON page 232 (5701/~7065)
# [youtube]     Downloading comment API JSON reply thread 1 (5705/~7065)
# [youtube]     Downloading comment API JSON reply thread 2 (5709/~7065)
# [youtube] Downloading comment API JSON page 233 (5723/~7065)
# [youtube]     Downloading comment API JSON reply thread 1 (5729/~7065)
# [youtube] Downloading comment API JSON page 234 (5745/~7065)
# [youtube]     Downloading comment API JSON reply thread 1 (5765/~7065)
# [youtube] Downloading comment API JSON page 235 (5766/~7065)
# [youtube]     Downloading comment API JSON reply thread 1 (5782/~7065)
# [youtube] Downloading comment API JSON page 236 (5788/~7065)
# [youtube]     Downloading comment API JSON reply thread 1 (5794/~7065)
# [youtube]     Downloading comment API JSON reply thread 2 (5802/~7065)
# [youtube]     Downloading comment API JSON reply thread 3 (5808/~7065)
# [youtube]        Downloading comment replies API JSON page 1 (5818/~7065)
# [youtube] Downloading comment API JSON page 237 (5838/~7065)
# [youtube]     Downloading comment API JSON reply thread 1 (5846/~7065)
# [youtube]     Downloading comment API JSON reply thread 2 (5848/~7065)
# [youtube] Downloading comment API JSON page 238 (5860/~7065)
# [youtube]     Downloading comment API JSON reply thread 1 (5879/~7065)
# [youtube] Downloading comment API JSON page 239 (5881/~7065)
# [youtube]     Downloading comment API JSON reply thread 1 (5883/~7065)
# [youtube]     Downloading comment API JSON reply thread 2 (5896/~7065)
# [youtube] Downloading comment API JSON page 240 (5905/~7065)
# [youtube]     Downloading comment API JSON reply thread 1 (5912/~7065)
# [youtube]     Downloading comment API JSON reply thread 2 (5915/~7065)
# [youtube]     Downloading comment API JSON reply thread 3 (5919/~7065)
# [youtube] Downloading comment API JSON page 241 (5931/~7065)
# [youtube]     Downloading comment API JSON reply thread 1 (5934/~7065)
# [youtube]        Downloading comment replies API JSON page 1 (5944/~7065)
# [youtube]     Downloading comment API JSON reply thread 2 (5969/~7065)
# [youtube]     Downloading comment API JSON reply thread 3 (5975/~7065)
# [youtube]     Downloading comment API JSON reply thread 4 (5979/~7065)
# [youtube]     Downloading comment API JSON reply thread 5 (5984/~7065)
# [youtube] Downloading comment API JSON page 242 (5990/~7065)
# [youtube]     Downloading comment API JSON reply thread 1 (6000/~7065)
# [youtube]     Downloading comment API JSON reply thread 2 (6003/~7065)
# [youtube]     Downloading comment API JSON reply thread 3 (6006/~7065)
# [youtube]     Downloading comment API JSON reply thread 4 (6010/~7065)
# [youtube]     Downloading comment API JSON reply thread 5 (6014/~7065)
# [youtube]     Downloading comment API JSON reply thread 6 (6018/~7065)
# [youtube] Downloading comment API JSON page 243 (6020/~7065)
# [youtube]     Downloading comment API JSON reply thread 1 (6021/~7065)
# [youtube]     Downloading comment API JSON reply thread 2 (6023/~7065)
# [youtube]     Downloading comment API JSON reply thread 3 (6029/~7065)
# [youtube]     Downloading comment API JSON reply thread 4 (6033/~7065)
# [youtube] Downloading comment API JSON page 244 (6049/~7065)
# [youtube]     Downloading comment API JSON reply thread 1 (6052/~7065)
# [youtube]     Downloading comment API JSON reply thread 2 (6064/~7065)
# [youtube]     Downloading comment API JSON reply thread 3 (6066/~7065)
# [youtube]     Downloading comment API JSON reply thread 4 (6072/~7065)
# [youtube]     Downloading comment API JSON reply thread 5 (6078/~7065)
# [youtube]        Downloading comment replies API JSON page 1 (6088/~7065)
# [youtube] Downloading comment API JSON page 245 (6092/~7065)
# [youtube]     Downloading comment API JSON reply thread 1 (6094/~7065)
# [youtube]     Downloading comment API JSON reply thread 2 (6098/~7065)
# [youtube]     Downloading comment API JSON reply thread 3 (6107/~7065)
# [youtube]     Downloading comment API JSON reply thread 4 (6115/~7065)
# [youtube] Downloading comment API JSON page 246 (6120/~7065)
# [youtube]     Downloading comment API JSON reply thread 1 (6121/~7065)
# [youtube]        Downloading comment replies API JSON page 1 (6131/~7065)
# [youtube]     Downloading comment API JSON reply thread 2 (6150/~7065)
# [youtube]     Downloading comment API JSON reply thread 3 (6166/~7065)
# [youtube]        Downloading comment replies API JSON page 1 (6176/~7065)
# [youtube] Downloading comment API JSON page 247 (6198/~7065)
# [youtube]     Downloading comment API JSON reply thread 1 (6200/~7065)
# [youtube]        Downloading comment replies API JSON page 1 (6210/~7065)
# [youtube]     Downloading comment API JSON reply thread 2 (6230/~7065)
# [youtube]     Downloading comment API JSON reply thread 3 (6234/~7065)
# [youtube]        Downloading comment replies API JSON page 1 (6244/~7065)
# [youtube]     Downloading comment API JSON reply thread 4 (6258/~7065)
# [youtube]        Downloading comment replies API JSON page 1 (6268/~7065)
# [youtube]     Downloading comment API JSON reply thread 5 (6282/~7065)
# [youtube] Downloading comment API JSON page 248 (6288/~7065)
# [youtube]     Downloading comment API JSON reply thread 1 (6296/~7065)
# [youtube]     Downloading comment API JSON reply thread 2 (6300/~7065)
# [youtube]     Downloading comment API JSON reply thread 3 (6306/~7065)
# [youtube]     Downloading comment API JSON reply thread 4 (6317/~7065)
# [youtube]     Downloading comment API JSON reply thread 5 (6319/~7065)
# [youtube]     Downloading comment API JSON reply thread 6 (6329/~7065)
# [youtube] Downloading comment API JSON page 249 (6331/~7065)
# [youtube] Downloading comment API JSON page 250 (6351/~7065)
# [youtube]     Downloading comment API JSON reply thread 1 (6353/~7065)
# [youtube]     Downloading comment API JSON reply thread 2 (6357/~7065)
# [youtube]        Downloading comment replies API JSON page 1 (6367/~7065)
# [youtube] Downloading comment API JSON page 251 (6419/~7065)
# [youtube]     Downloading comment API JSON reply thread 1 (6420/~7065)
# [youtube]     Downloading comment API JSON reply thread 2 (6424/~7065)
# [youtube]     Downloading comment API JSON reply thread 3 (6429/~7065)
# [youtube]     Downloading comment API JSON reply thread 4 (6436/~7065)
# [youtube]        Downloading comment replies API JSON page 1 (6446/~7065)
# [youtube] Downloading comment API JSON page 252 (6466/~7065)
# [youtube]     Downloading comment API JSON reply thread 1 (6476/~7065)
# [youtube]     Downloading comment API JSON reply thread 2 (6481/~7065)
# [youtube] Downloading comment API JSON page 253 (6488/~7065)
# [youtube]     Downloading comment API JSON reply thread 1 (6498/~7065)
# [youtube]     Downloading comment API JSON reply thread 2 (6502/~7065)
# [youtube]        Downloading comment replies API JSON page 1 (6512/~7065)
# [youtube]        Downloading comment replies API JSON page 2 (6562/~7065)
# [youtube]        Downloading comment replies API JSON page 3 (6612/~7065)
# [youtube]     Downloading comment API JSON reply thread 3 (6623/~7065)
# [youtube]     Downloading comment API JSON reply thread 4 (6626/~7065)
# [youtube]     Downloading comment API JSON reply thread 5 (6629/~7065)
# [youtube]        Downloading comment replies API JSON page 1 (6639/~7065)
# [youtube]        Downloading comment replies API JSON page 2 (6689/~7065)
# [youtube]        Downloading comment replies API JSON page 3 (6739/~7065)
# [youtube]        Downloading comment replies API JSON page 4 (6789/~7065)
# [youtube]        Downloading comment replies API JSON page 5 (6839/~7065)
# [youtube]        Downloading comment replies API JSON page 6 (6889/~7065)
# [youtube]        Downloading comment replies API JSON page 7 (6939/~7065)
# [youtube]        Downloading comment replies API JSON page 8 (6989/~7065)
# [youtube] Downloading comment API JSON page 254 (7003/~7065)
# [youtube]     Downloading comment API JSON reply thread 1 (7008/~7065)
# [youtube]     Downloading comment API JSON reply thread 2 (7020/~7065)
# [youtube] Downloading comment API JSON page 255 (7027/~7065)
# [youtube]     Downloading comment API JSON reply thread 1 (7031/~7065)
# [youtube]     Downloading comment API JSON reply thread 2 (7049/~7065)
# [youtube]     Downloading comment API JSON reply thread 3 (7053/~7065)
# [youtube] Downloading comment API JSON page 256 (7056/~7065)
# [youtube] Extracted 7065 comments
# output/Snow White (2025) - Movie Review_RUHDbqkiwdE.json: 5109 comments, 1956 replies, 5869 unique authors
