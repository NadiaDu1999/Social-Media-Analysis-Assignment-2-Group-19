# %%
import json
import httpx

client = httpx.Client(
    headers={
        # this is internal ID of an instegram backend app. It doesn't change often.
        "x-ig-app-id": "936619743392459",
        # use browser-like features
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/62.0.3202.94 Safari/537.36",
        "Accept-Language": "en-US,en;q=0.9,ru;q=0.8",
        "Accept-Encoding": "gzip, deflate, br",
        "Accept": "*/*",
    }
)


def scrape_user(username: str):
    """Scrape Instagram user's data"""
    result = client.get(
        f"https://i.instagram.com/api/v1/users/web_profile_info/?username={username}",
    )
    data = json.loads(result.content)
    return data["data"]["user"]

print(scrape_user("google"))
# Out:
# {'ai_agent_owner_username': None, 'ai_agent_type': None, 'biography': 'Google unfiltered—sometimes with filters.', 'bio_links': [{'title': '', 'lynx_url': 'https://l.instagram.com/?u=https%3A%2F%2Flinkin.bio%2Fgoogle&e=AT0J5EEqgmsOW_-TZ_ty3ZTXmSy25o5z755gRGtrCSmJ-aCf2yv5gCnSKmOn3XhKi3NNfCNxdK7SqJbcNbNuXK5DBZd6rG9O', 'url': 'https://linkin.bio/google', 'link_type': 'external'}], 'fb_profile_biolink': None, 'biography_with_entities': {'raw_text': 'Google unfiltered—sometimes with filters.', 'entities': []}, 'blocked_by_viewer': False, 'restricted_by_viewer': None, 'country_block': False, 'eimu_id': '101735994563732', 'external_url': 'https://linkin.bio/google', 'external_url_linkshimmed': 'https://l.instagram.com/?u=https%3A%2F%2Flinkin.bio%2Fgoogle&e=AT3t2uoMgCrPqEx7gMSJ74cbMz1j-IBMxi6GG_JcU0tu39mZjE_w0qODnxvqox5Tu36xYbwKzUnoqIjpXaxCIertROjNGEbV', 'edge_followed_by': {'count': 15293519}, 'fbid': '17841401778116675', 'followed_by_viewer': False, 'edge_follow': {'count': 35}, 'follows_viewer': False, 'full_name': 'Google', 'group_metadata': None, 'has_ar_effects': False, 'has_clips': True, 'has_guides': False, 'has_channel': False, 'has_blocked_viewer': False, 'highlight_reel_count': 3, 'has_onboarded_to_text_post_app': True, 'has_requested_viewer': False, 'hide_like_and_view_counts': False, 'id': '1067259270', 'is_business_account': True, 'is_professional_account': True, 'is_supervision_enabled': False, 'is_guardian_of_viewer': False, 'is_supervised_by_viewer': False, 'is_supervised_user': False, 'is_embeds_disabled': False, 'is_joined_recently': False, 'guardian_id': None, 'business_address_json': '{"city_name": "Mountain View, California", "city_id": 108212625870265, "latitude": 37.4221, "longitude": -122.08432, "street_address": "1600 Amphitheatre Pkwy", "zip_code": "94043"}', 'business_contact_method': 'UNKNOWN', 'business_email': None, 'business_phone_number': None, 'business_category_name': 'None', 'overall_category_name': None, 'category_enum': 'INTERNET_COMPANY', 'category_name': 'Internet company', 'is_private': False, 'is_verified': True, 'is_verified_by_mv4b': False, 'is_regulated_c18': False, 'edge_mutual_followed_by': {'count': 0, 'edges': []}, 'pinned_channels_list_count': 0, 'profile_pic_url': 'https://instagram.fcbr1-1.fna.fbcdn.net/v/t51.2885-19/425391724_2454717941393726_7200817596193793590_n.jpg?stp=dst-jpg_s150x150_tt6&_nc_ht=instagram.fcbr1-1.fna.fbcdn.net&_nc_cat=1&_nc_oc=Q6cZ2QHnBl2PB93o1SKceV5f-TpemOVKxY2Y8o-3xSXlJzeRn6N3b-KIcccX0iEwIfi5H4M&_nc_ohc=AeKSvKDsqEMQ7kNvwENqtzY&_nc_gid=NvRbjp-H5J84hx4vB4ls3A&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfLhrxYyGQNFksA2epWIOr-nA5OG4svA4islPxy49h2xyg&oe=68233A5C&_nc_sid=8b3546', 'profile_pic_url_hd': 'https://instagram.fcbr1-1.fna.fbcdn.net/v/t51.2885-19/425391724_2454717941393726_7200817596193793590_n.jpg?stp=dst-jpg_s320x320_tt6&_nc_ht=instagram.fcbr1-1.fna.fbcdn.net&_nc_cat=1&_nc_oc=Q6cZ2QHnBl2PB93o1SKceV5f-TpemOVKxY2Y8o-3xSXlJzeRn6N3b-KIcccX0iEwIfi5H4M&_nc_ohc=AeKSvKDsqEMQ7kNvwENqtzY&_nc_gid=NvRbjp-H5J84hx4vB4ls3A&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfI8-SKvf6J2NT7-XjSu-rLvZlBiUjeRgymzmKZsbHFgwA&oe=68233A5C&_nc_sid=8b3546', 'requested_by_viewer': False, 'should_show_category': True, 'should_show_public_contacts': True, 'show_account_transparency_details': True, 'show_text_post_app_badge': True, 'remove_message_entrypoint': False, 'transparency_label': None, 'transparency_product': None, 'username': 'google', 'connected_fb_page': None, 'pronouns': [], 'edge_felix_video_timeline': {'count': 107, 'page_info': {'has_next_page': True, 'end_cursor': 'QVFBcXhHQTd0VE5QbEk0bGRUeGhuUjktakFYUmN3UUdJS3RHc0l1RFVRUjZGNW9fUGhaWHR5RkVENmI5ZTZtbzNqSmJMdE5YLU9qbU93STZza3o0M0d0Yw=='}, 'edges': [{'node': {'__typename': 'GraphVideo', 'id': '2892596643067882496', 'shortcode': 'CgkkVI8jGwA', 'dimensions': {'height': 995, 'width': 640}, 'display_url': 'https://instagram.fcbr1-1.fna.fbcdn.net/v/t51.2885-15/296019923_384320173831087_3211224126120508155_n.jpg?stp=dst-jpg_e15_tt6&_nc_ht=instagram.fcbr1-1. ...
